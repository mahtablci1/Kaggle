# %% [markdown]
# # Abstract
# The objective of this notebook will be to perform keyword analysis on the papers for Covid-19 risk factors.

# %%
import re
from datetime import datetime
import pandas as np
import pandas as pd

# %%
papers_df = pd.read_csv('output/papers_df.csv', 
                        index_col=0, 
                        keep_default_na=False,
                       parse_dates=['publish_time'])

# %%
papers_df.head(2)
# Out:
#                                      doc_id  \
# 0  0015023cc06b5362d332b3baf348d11567ca2fbb
# 1  00340eea543336d54adda18236424de6a5e91c9d
#
#                                                title  \
# 0  The RNA pseudoknots in foot-and-mouth disease ...
# 1  Analysis Title: Regaining perspective on SARS-...
#
#                                             abstract  \
# 0  word count: 194 22 Text word count: 5168 23 24...
# 1  During the past three months, a new coronaviru...
#
#                                            text_body publish_time  \
# 0  VP3, and VP0 (which is further processed to VP...   2020-01-11
# 1  In December 2019, a novel coronavirus, SARS-Co...   2020-03-20
#
#                                              authors journal  \
# 0  Joseph C. Ward; Lidia Lasecka-Dykes; Chris Nei...
# 1  Carla Mavian; Simone Marini; Costanza Manes; I...
#
#                            doi Title H index
# 0    10.1101/2020.01.10.901801
# 1  10.1101/2020.03.16.20034470

# %%
transmission_keywords = ['transmi', 'sneez', 'contact trac', 'reproduc', 'environ']

# %%
smoke_keywords = ['smok']

# %%
covid_keywords = ['COVID-19', 'HCoV-19', 'CORD-19' ,'2019-nCoV', 'Wuhan coronavirus', 'SARS-CoV-2', 'SARS-COV-2']
covid_keywords = [word.lower() for word in covid_keywords]

# %%
covid_papers = papers_df[papers_df['text_body'].apply(lambda x : 
                                                any(key in x.lower() for
                                                    key in covid_keywords)
                                               )]

# %%
covid_papers = covid_papers[covid_papers['publish_time'] >= datetime(2019,1,1)]

# %%
covid_papers.shape
# Out:
# (1241, 10)

# %%
sample_df = covid_papers.sort_values(by='publish_time', ascending = True)

# %%
for sample in sample_df.iterrows():
    sample = sample[1]
    print(sample['publish_time'], sample['title'])
    matches = []
    for key in covid_keywords:
        match = re.search(key.lower(), sample['text_body'].lower())
        if match:
            print(match)
            matches.append(match)
    for match in matches:
        print(sample['text_body'][match.start()-20:match.end() + 20])
# Out:
# 2019-08-27 00:00:00 A molecular cell atlas of the human lung from single cell RNA sequencing
# <re.Match object; span=(30102, 30110), match='covid-19'>
# 2, used by SARS and COVID-19 coronaviruses, and
# 2019-11-22 00:00:00 VADR: validation and annotation of virus sequence submissions to GenBank
# <re.Match object; span=(48307, 48315), match='covid-19'>
# <re.Match object; span=(48461, 48471), match='sars-cov-2'>
# <re.Match object; span=(48461, 48471), match='sars-cov-2'>
# riction. Due to the COVID-19 outbreak beginning
# sequences including SARS-CoV-2, even though VADR w
# sequences including SARS-CoV-2, even though VADR w
# 2019-12-31 00:00:00
# <re.Match object; span=(262, 270), match='covid-19'>
#  for as long as the COVID-19 resource centre rem
# 2020-01-01 00:00:00 The novel coronavirus outbreak in Wuhan, China
# <re.Match object; span=(87, 95), match='covid-19'>
# <re.Match object; span=(73, 82), match='2019-ncov'>
# irus (2019-nCoV, or COVID-19) was identified in
#  novel coronavirus (2019-nCoV, or COVID-19) was i
# 2020-01-01 00:00:00 A new coronavirus associated with human respiratory disease in China
# <re.Match object; span=(14950, 14958), match='covid-19'>
# <re.Match object; span=(1061, 1070), match='2019-ncov'>
# <re.Match object; span=(14836, 14846), match='sars-cov-2'>
# <re.Match object; span=(14836, 14846), match='sars-cov-2'>
# his virus, which is COVID-19 31 .
#  Any methods,
# een referred to as '2019-nCoV'). Phylogenetic ana
# gnated the virus as SARS-CoV-2 30 ; in addition, t
# gnated the virus as SARS-CoV-2 30 ; in addition, t
# 2020-01-01 00:00:00 Cell Discovery Comparative genetic analysis of the novel coronavirus (2019-nCoV/SARS-CoV-2) receptor ACE2 in different populations
# <re.Match object; span=(55, 64), match='2019-ncov'>
# <re.Match object; span=(65, 75), match='sars-cov-2'>
# <re.Match object; span=(65, 75), match='sars-cov-2'>
#  novel coronavirus (2019-nCoV/SARS-CoV-2) recepto
# onavirus (2019-nCoV/SARS-CoV-2) receptor ACE2 in d
# onavirus (2019-nCoV/SARS-CoV-2) receptor ACE2 in d
# 2020-01-01 00:00:00 Consensus statement The species Severe acute respiratory syndrome- related coronavirus: classifying 2019-nCoV and naming it SARS-CoV-2 Coronaviridae Study Group of the International Committee on Taxonomy of Viruses*
# <re.Match object; span=(19553, 19561), match='covid-19'>
# <re.Match object; span=(1126, 1135), match='2019-ncov'>
# <re.Match object; span=(1257, 1267), match='sars-cov-2'>
# <re.Match object; span=(1257, 1267), match='sars-cov-2'>
# e 19, also known as COVID-19 (ref. 36 )) to deno
# provisionally named 2019-nCoV, to known coronavir
# rome coronavirus 2 (SARS-CoV-2), which will be use
# rome coronavirus 2 (SARS-CoV-2), which will be use
# 2020-01-01 00:00:00 STATISTICS-BASED PREDICTIONS OF CORONAVIRUS EPIDEMIC SPREADING IN MAINLAND CHINA
# <re.Match object; span=(80, 88), match='covid-19'>
# <re.Match object; span=(112, 121), match='2019-ncov'>
# used by coronavirus COVID-19 (the previous name
# e previous name was 2019-nCoV) (see e.g., [1] [2]
# 2020-01-01 00:00:00 First two months of the 2019 Coronavirus Disease (COVID-19) epidemic in China: real- time surveillance and evaluation with a second derivative model
# <re.Match object; span=(16, 24), match='covid-19'>
# <re.Match object; span=(119, 128), match='2019-ncov'>
#
# previously named as 2019-nCoV and it is a positiv
# 2020-01-01 00:00:00 Clinical Medicine The Rate of Underascertainment of Novel Coronavirus (2019-nCoV) Infection: Estimation Using Japanese Passengers Data on Evacuation Flights
# <re.Match object; span=(38, 47), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) unfolded, the gove
# 2020-01-01 00:00:00 viruses Return of the Coronavirus: 2019-nCoV
# <re.Match object; span=(1117, 1126), match='2019-ncov'>
# 2] . The novel CoV (2019-nCoV) was isolated from
# 2020-01-01 00:00:00 Clinical Medicine Incubation Period and Other Epidemiological Characteristics of 2019 Novel Coronavirus Infections with Right Truncation: A Statistical Analysis of Publicly Available Case Data
# <re.Match object; span=(574, 582), match='covid-19'>
#  natural history of COVID-19 infection, as these
# 2020-01-01 00:00:00
# <re.Match object; span=(2930, 2938), match='covid-19'>
# <re.Match object; span=(919, 928), match='2019-ncov'>
# <re.Match object; span=(887, 897), match='sars-cov-2'>
# <re.Match object; span=(887, 897), match='sars-cov-2'>
# present epidemic of COVID-19.
#  It has been note
# previously known as 2019-nCoV), in Wuhan, China.
# outbreak, caused by SARS-CoV-2 (previously known a
# outbreak, caused by SARS-CoV-2 (previously known a
# 2020-01-01 00:00:00 Subunit Vaccines Against Emerging Pathogenic Human Coronaviruses
# <re.Match object; span=(1421, 1430), match='2019-ncov'>
# merged coronavirus (2019-nCoV), which are known t
# 2020-01-01 00:00:00 Clinical Medicine Optimization Method for Forecasting Confirmed Cases of COVID-19 in China
# <re.Match object; span=(732, 740), match='covid-19'>
# <re.Match object; span=(768, 777), match='2019-ncov'>
# coronavirus, called COVID-19 (previously, it was
# usly, it was called 2019-nCoV). In [6] , the auth
# 2020-01-01 00:00:00 COVID-19 in the Shadows of MERS-CoV in the Kingdom of Saudi Arabia
# <re.Match object; span=(1623, 1631), match='covid-19'>
# <re.Match object; span=(910, 920), match='sars-cov-2'>
# <re.Match object; span=(910, 920), match='sars-cov-2'>
# a confirmed case of COVID-19 infection.
#  As it
# spiratory Syndrome (SARS-CoV-2) [8, 9] . To date,
# spiratory Syndrome (SARS-CoV-2) [8, 9] . To date,
# 2020-01-01 00:00:00 REVISTA PERUANA DE INVESTIGACIÓN EN SALUD
# <re.Match object; span=(159, 168), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) originado en Wuhan
# 2020-01-01 00:00:00
# <re.Match object; span=(357, 365), match='covid-19'>
# <re.Match object; span=(208, 215), match='hcov-19'>
# <re.Match object; span=(676, 685), match='2019-ncov'>
# <re.Match object; span=(228, 238), match='sars-cov-2'>
# <re.Match object; span=(228, 238), match='sars-cov-2'>
# name of the disease COVID-19.
#  Medical Sciences
# n coronavirus 2019 (HCoV-19) instead of SARS-Co
# novel coronavirus" (2019-nCoV) . Discussions are
# HCoV-19) instead of SARS-CoV-2. The name HCoV-19 e
# HCoV-19) instead of SARS-CoV-2. The name HCoV-19 e
# 2020-01-01 00:00:00
# <re.Match object; span=(257, 265), match='covid-19'>
# <re.Match object; span=(152, 161), match='2019-ncov'>
# <re.Match object; span=(175, 185), match='sars-cov-2'>
# <re.Match object; span=(175, 185), match='sars-cov-2'>
# current outbreak of COVID-19 in China as a Publi
#  novel coronavirus (2019-nCoV, later named SARS-C
# 9-nCoV, later named SARS-CoV-2). 1 The World Healt
# 9-nCoV, later named SARS-CoV-2). 1 The World Healt
# 2020-01-01 00:00:00 Chest Radiographic and CT Findings of the 2019 Novel Coronavirus Disease (COVID-19): Analysis of Nine Patients Treated in Korea
# <re.Match object; span=(52, 60), match='covid-19'>
# .0132 kjronline.org COVID-19 patient was identif
# 2020-01-01 00:00:00 Viewpoint Personal knowledge on novel coronavirus pneumonia
# <re.Match object; span=(39, 48), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) infection in some
# 2020-01-01 00:00:00 A pneumonia outbreak associated with a new coronavirus of probable bat origin
# <re.Match object; span=(13358, 13366), match='covid-19'>
# <re.Match object; span=(392, 401), match='2019-ncov'>
# <re.Match object; span=(13244, 13254), match='sars-cov-2'>
# <re.Match object; span=(13244, 13254), match='sars-cov-2'>
# his virus, which is COVID-19 16 .
#  Any methods,
#  a new coronavirus (2019-nCoV), which caused an e
# gnated the virus as SARS-CoV-2 15 ; in addition, t
# gnated the virus as SARS-CoV-2 15 ; in addition, t
# 2020-01-01 00:00:00 Preliminary Identification of Potential Vaccine Targets for the COVID-19 Coronavirus (SARS-CoV-2) Based on SARS-CoV Immunological Studies
# <re.Match object; span=(24, 32), match='covid-19'>
# <re.Match object; span=(633, 642), match='2019-ncov'>
# <re.Match object; span=(592, 602), match='sars-cov-2'>
# <re.Match object; span=(592, 602), match='sars-cov-2'>
# ongoing outbreak of COVID-19 in the Chinese city
# y tentatively named 2019-nCoV), and to develop ef
# auses this disease, SARS-CoV-2 (originally tentati
# auses this disease, SARS-CoV-2 (originally tentati
# 2020-01-01 00:00:00 Genome Detective Coronavirus Typing Tool for rapid identification and characterization of novel coronavirus genomes
# <re.Match object; span=(644, 652), match='covid-19'>
# <re.Match object; span=(275, 285), match='sars-cov-2'>
# <re.Match object; span=(275, 285), match='sars-cov-2'>
#  WHO recently named COVID-19 disease. It has hig
#  novel coronavirus (SARS-CoV-2), first isolated in
#  novel coronavirus (SARS-CoV-2), first isolated in
# 2020-01-01 00:00:00 Conflicts of interest
# <re.Match object; span=(2718, 2726), match='covid-19'>
# as officially named COVID-19.
# 2020-01-01 00:00:00 Backcalculating the Incidence of Infection with COVID-19 on the Diamond Princess
# <re.Match object; span=(42, 50), match='covid-19'>
# oronavirus disease (COVID-19) has occurred on a
# 2020-01-01 00:00:00 Rapid communication
# <re.Match object; span=(39, 48), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) infection cases is
# 2020-01-01 00:00:00
# <re.Match object; span=(594, 602), match='covid-19'>
# <re.Match object; span=(2506, 2516), match='sars-cov-2'>
# <re.Match object; span=(2506, 2516), match='sars-cov-2'>
# s "recommended" for COVID-19 treatment based on
# fectively inhibited SARS-CoV-2 in vitro. 3 If thes
# fectively inhibited SARS-CoV-2 in vitro. 3 If thes
# 2020-01-01 00:00:00 A mathematical model for simulating the phase-based transmissibility of a novel coronavirus
# <re.Match object; span=(2138, 2146), match='covid-19'>
# <re.Match object; span=(241, 250), match='2019-ncov'>
# <re.Match object; span=(321, 331), match='sars-cov-2'>
# <re.Match object; span=(321, 331), match='sars-cov-2'>
#  have been named as COVID-19, were collected for
#  novel coronavirus (2019-nCoV), which was named a
# rome coronavirus 2 (SARS-CoV-2) by International C
# rome coronavirus 2 (SARS-CoV-2) by International C
# 2020-01-01 00:00:00 Potential Factors Influencing Repeated SARS Outbreaks in China
# <re.Match object; span=(2462, 2470), match='covid-19'>
# <re.Match object; span=(2671, 2680), match='2019-ncov'>
# <re.Match object; span=(267, 277), match='sars-cov-2'>
# <re.Match object; span=(267, 277), match='sars-cov-2'>
# virus disease 2019 (COVID-19)", we feel that it
#  been changed from "2019-nCoV" to "SARS-CoV-2". A
# amely, SARS-CoV and SARS-CoV-2 ( Figure 1 ), respe
# amely, SARS-CoV and SARS-CoV-2 ( Figure 1 ), respe
# 2020-01-01 00:00:00 Num 2
# <re.Match object; span=(550, 559), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) has emerged in Wuh
# 2020-01-01 00:00:00
# <re.Match object; span=(821, 830), match='2019-ncov'>
# y identification of 2019-nCoV infection presents
# 2020-01-01 00:00:00 Cell Discovery Phase-adjusted estimation of the number of Coronavirus Disease 2019 cases in Wuhan, China
# <re.Match object; span=(1815, 1823), match='covid-19'>
# <re.Match object; span=(24, 33), match='2019-ncov'>
# <re.Match object; span=(34, 44), match='sars-cov-2'>
# <re.Match object; span=(34, 44), match='sars-cov-2'>
# ed estimated R 0 of COVID-19 and generated valua
#  Novel coronavirus (2019-nCoV/SARS-CoV-2) has giv
# onavirus (2019-nCoV/SARS-CoV-2) has given rise to
# onavirus (2019-nCoV/SARS-CoV-2) has given rise to
# 2020-01-01 00:00:00
# <re.Match object; span=(46, 55), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) was discovered and
# 2020-01-01 00:00:00 Frontiers in antiviral therapy and immunotherapy
# <re.Match object; span=(6748, 6756), match='covid-19'>
# coronavirus (nCoV / COVID-19) outbreaks, enablin
# 2020-01-01 00:00:00 Systematic Comparison of Two Animal-to-Human Transmitted Human Coronaviruses: SARS-CoV-2 and SARS-CoV
# <re.Match object; span=(862, 870), match='covid-19'>
# <re.Match object; span=(773, 782), match='2019-ncov'>
# <re.Match object; span=(546, 556), match='sars-cov-2'>
# <re.Match object; span=(546, 556), match='sars-cov-2'>
# irus disease 2019" (COVID-19) [7] . According to
#  "SARS-CoV-2" from "2019-nCoV" [6] . The disease
# n in Dec, 2019, and SARS-CoV-2, a new coronavirus,
# n in Dec, 2019, and SARS-CoV-2, a new coronavirus,
# 2020-01-01 00:00:00 Clinical Medicine Estimation of the Transmission Risk of the 2019-nCoV and Its Implication for Public Health Interventions
# <re.Match object; span=(642, 651), match='2019-ncov'>
# aboratory-confirmed 2019-nCoV cases which occurre
# 2020-01-01 00:00:00
# <re.Match object; span=(37, 46), match='2019-ncov'>
# er, the outbreak of 2019-nCoV in Wuhan has caused
# 2020-01-01 00:00:00 Clinical Medicine Editorial Initial Cluster of Novel Coronavirus (2019-nCoV) Infections in Wuhan, China Is Consistent with Substantial Human-to-Human Transmission
# <re.Match object; span=(70, 79), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) infections in Wuha
# 2020-01-01 00:00:00 pathogens Emergence of Novel Coronavirus 2019-nCoV: Need for Rapid Vaccine and Biologics Development
# <re.Match object; span=(864, 873), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) has recently added
# 2020-01-01 00:00:00
# <re.Match object; span=(1597, 1605), match='covid-19'>
# <re.Match object; span=(1702, 1711), match='2019-ncov'>
# he right lesson for COVID-19. The quick release
# nity to compare the 2019-nCoVs with the SARS viru
# 2020-01-01 00:00:00 Clinical Medicine Estimating the Unreported Number of Novel Coronavirus (2019-nCoV) Cases in China in the First Half of January 2020: A Data-Driven Modelling Analysis of the Early Outbreak
# <re.Match object; span=(21, 30), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) infected pneumonia
# 2020-01-01 00:00:00
# <re.Match object; span=(58, 67), match='2019-ncov'>
# <re.Match object; span=(7569, 7586), match='wuhan coronavirus'>
# genome sequences of 2019-nCoV have been submitted
# ission of the novel Wuhan Coronavirus, which is a Bats-Ho
# 2020-01-01 00:00:00 Molecular Diagnosis of a Novel Coronavirus (2019-nCoV) Causing an Outbreak of Pneumonia
# <re.Match object; span=(2596, 2605), match='2019-ncov'>
# -novel coronavirus (2019-nCoV) has been identifie
# 2020-01-01 00:00:00 Clinical Medicine Assessing the Impact of Reduced Travel on Exportation Dynamics of Novel Coronavirus Infection (COVID-19)
# <re.Match object; span=(865, 873), match='covid-19'>
# <re.Match object; span=(23185, 23195), match='sars-cov-2'>
# <re.Match object; span=(23185, 23195), match='sars-cov-2'>
# r spatial spread of COVID-19. To our knowledge,
#  contingency of the SARS-CoV-2, and also that the
#  contingency of the SARS-CoV-2, and also that the
# 2020-01-01 00:00:00 Distribution of the COVID-19 Epidemic and Correlation with Population Emigration from Wuhan, China
# <re.Match object; span=(276, 284), match='covid-19'>
# Virus Disease 2019, COVID-19) outbreak is becomi
# 2020-01-01 00:00:00 Potential Rapid Diagnostics, Vaccine and Therapeutics for 2019 Novel Coronavirus (2019-nCoV): A Systematic Review
# <re.Match object; span=(83, 92), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) originating from W
# 2020-01-01 00:00:00 Transmission routes of 2019-nCoV and controls in dental practice
# <re.Match object; span=(11073, 11081), match='covid-19'>
# <re.Match object; span=(1228, 1237), match='2019-ncov'>
# <re.Match object; span=(1516, 1526), match='sars-cov-2'>
# <re.Match object; span=(1516, 1526), match='sars-cov-2'>
# a suspected case of COVID-19. To date that this
#  novel coronavirus (2019-nCOV), the seventh membe
# oronavirus name as "SARS-CoV-2" due to the phyloge
# oronavirus name as "SARS-CoV-2" due to the phyloge
# 2020-01-01 00:00:00 Clinical Medicine The Extent of Transmission of Novel Coronavirus in
# <re.Match object; span=(314, 323), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) of the same lineag
# 2020-01-01 00:00:00 On the Coronavirus (COVID-19) Outbreak and the Smart City Network: Universal Data Sharing Standards Coupled with Artificial Intelligence (AI) to Benefit Urban Health Monitoring and Management
# <re.Match object; span=(85, 93), match='covid-19'>
# <re.Match object; span=(57, 66), match='2019-ncov'>
# V and later renamed COVID-19 during the writing
# iously known as the 2019-nCoV and later renamed C
# 2020-01-01 00:00:00 President, World Organisation of Family Doctors (WONca)
# <re.Match object; span=(683, 692), match='2019-ncov'>
# <re.Match object; span=(511, 528), match='wuhan coronavirus'>
# referring to it as '2019-nCov'.
#  At the time of
# ms and signs of the Wuhan coronavirus include fever, with
# 2020-01-01 00:00:00 Identification of COVID-19 Can be Quicker through Artificial Intelligence framework using a Mobile Phone-Based Survey in the Populations when Cities/Towns Are Under Quarantine
# <re.Match object; span=(689, 697), match='covid-19'>
# <re.Match object; span=(2880, 2889), match='2019-ncov'>
#  2666 deaths due to COVID-19, including cases in
#  recommendation for 2019-nCoV (MHCRC). If a respo
# 2020-01-01 00:00:00 Epidemiological Identification of A Novel Pathogen in Real Time: Analysis of the Atypical Pneumonia Outbreak in Wuhan
# <re.Match object; span=(652, 662), match='sars-cov-2'>
# <re.Match object; span=(652, 662), match='sars-cov-2'>
# rome coronavirus 2 (SARS-CoV-2) [7, 8] .
#  While e
# rome coronavirus 2 (SARS-CoV-2) [7, 8] .
#  While e
# 2020-01-01 00:00:00 Revisiting the dangers of the coronavirus in the ophthalmology practice
# <re.Match object; span=(270, 279), match='2019-ncov'>
#  novel coronavirus (2019-nCoV), which caused an o
# 2020-01-01 00:00:00 Outbreak 2019-nCoV (Wuhan virus), a novel Coronavirus: human-to-human transmission, travel-related cases, and vaccine readiness
# <re.Match object; span=(118, 127), match='2019-ncov'>
# <re.Match object; span=(23606, 23623), match='wuhan coronavirus'>
# s that support that 2019-nCoV is capable of human
# and OC43. The novel Wuhan coronavirus envelope protein sh
# 2020-01-01 00:00:00 Outbreak of Novel Coronavirus (SARS-Cov-2): First Evidences From International Scientific Literature and Pending Questions
# <re.Match object; span=(765, 773), match='covid-19'>
# <re.Match object; span=(657, 667), match='sars-cov-2'>
# <re.Match object; span=(657, 667), match='sars-cov-2'>
# r a disease defined COVID-19 (novel coronavirus
# rus, recently named SARS-CoV-2 (severe acute respi
# rus, recently named SARS-CoV-2 (severe acute respi
# 2020-01-01 00:00:00 Clinical Medicine Communicating the Risk of Death from Novel Coronavirus Disease (COVID-19)
# <re.Match object; span=(58, 66), match='covid-19'>
# <re.Match object; span=(9545, 9555), match='sars-cov-2'>
# <re.Match object; span=(9545, 9555), match='sars-cov-2'>
# eared in late 2019 (COVID-19) has spread to the
# cases infected with SARS-CoV-2 causing COVID-19 is
# cases infected with SARS-CoV-2 causing COVID-19 is
# 2020-01-01 00:00:00 viruses Perspective Potential Maternal and Infant Outcomes from Coronavirus 2019-nCoV (SARS-CoV-2) Infecting Pregnant Women: Lessons from SARS, MERS, and Other Human Coronavirus Infections
# <re.Match object; span=(4584, 4592), match='covid-19'>
# <re.Match object; span=(2397, 2406), match='2019-ncov'>
# <re.Match object; span=(38750, 38767), match='wuhan coronavirus'>
# hat has been termed COVID-19, is rapidly spreadi
# ven the designation 2019-nCoV (for 2019 novel cor
# e against the novel Wuhan coronavirus. The Chief Executiv
# 2020-01-01 00:00:00 Editor-in-Chief
# <re.Match object; span=(566, 575), match='2019-ncov'>
# navirus, designated 2019-nCoV, was found to be as
# 2020-01-01 00:00:00 Quantifying the association between domestic travel and the exportation of novel coronavirus (2019-nCoV) cases from Wuhan, China in 2020: a correlational analysis
# <re.Match object; span=(41, 50), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) emerged in Wuhan,
# 2020-01-01 00:00:00
# <re.Match object; span=(1974, 1983), match='2019-ncov'>
# ppropriate to treat 2019-nCoV-infected patients i
# 2020-01-01 00:00:00 Clinical Medicine Intense Surveillance Is Vital for Preventing Sustained Transmission in New Locations
# <re.Match object; span=(65, 74), match='2019-ncov'>
# monia outbreak (the 2019-nCoV) appears to have tr
# 2020-01-01 00:00:00
# <re.Match object; span=(283, 291), match='covid-19'>
# <re.Match object; span=(3938, 3947), match='2019-ncov'>
# han 68,000 cases of COVID-19 pneumonia had been
#  the infectivity of 2019-nCoV, ECMO poses a high
# 2020-01-01 00:00:00 -NC-ND 4.0 license
# <re.Match object; span=(1644, 1652), match='covid-19'>
# current outbreak of COVID-19.
# 2020-01-01 00:00:00
# <re.Match object; span=(2077, 2086), match='2019-ncov'>
# n testing (NAT) for 2019-nCoV would most likely u
# 2020-01-01 00:00:00 Angiotensin-converting enzyme 2 (ACE2) as a SARS-CoV-2 receptor: molecular mechanisms and potential therapeutic target
# <re.Match object; span=(4484, 4492), match='covid-19'>
# <re.Match object; span=(0, 10), match='sars-cov-2'>
# <re.Match object; span=(0, 10), match='sars-cov-2'>
# er a person can get COVID-19 by touching surface
#
#
# 2020-01-01 00:00:00 The outbreak of COVID-19: An overview
# <re.Match object; span=(2465, 2473), match='covid-19'>
# <re.Match object; span=(1218, 1227), match='2019-ncov'>
# for SARS, MERS, and COVID-19. 5, [8] [9] [10] [1
#  novel coronavirus (2019-nCoV) and recalled to ou
# 2020-01-01 00:00:00
# <re.Match object; span=(74, 82), match='covid-19'>
# oronavirus disease (COVID-19) 1 has fast spread
# 2020-01-01 00:00:00 From SARS-CoV to SARS-CoV-2 Outbreak: Similarities in the Early Epidemics and Prediction of Future Trends
# <re.Match object; span=(1066, 1076), match='sars-cov-2'>
# <re.Match object; span=(1066, 1076), match='sars-cov-2'>
# V) [5] . . Although SARS-CoV-2 and SARS-CoV belong
# V) [5] . . Although SARS-CoV-2 and SARS-CoV belong
# 2020-01-01 00:00:00 Nepal's First Case of COVID-19 and public health response Nepal's First Case of COVID-19 and public health response
# <re.Match object; span=(1093, 1101), match='covid-19'>
# <re.Match object; span=(131, 140), match='2019-ncov'>
# ary and December. 6 COVID-19 outbreak coincides
#  novel coronavirus (2019-nCov) with 2129 deaths.
# 2020-01-01 00:00:00 Perspective Non-invasive respiratory support for patients with novel coronavirus pneumonia: clinical efficacy and reduction in risk of infection transmission
# <re.Match object; span=(805, 813), match='covid-19'>
# imilarities between COVID-19 pneumonia and Sever
# 2020-01-01 00:00:00
# <re.Match object; span=(298, 306), match='covid-19'>
#  with patients with COVID-19 infection.
#  At adm
# 2020-01-01 00:00:00 COVID-19 R0: Magic number or conundrum?
# <re.Match object; span=(37, 45), match='covid-19'>
# <re.Match object; span=(130, 140), match='sars-cov-2'>
# <re.Match object; span=(130, 140), match='sars-cov-2'>
# asing concern about COVID-19 worldwide. This is
#  novel coronavirus (SARS-CoV-2), which recently br
#  novel coronavirus (SARS-CoV-2), which recently br
# 2020-01-01 00:00:00 Clinical findings in a group of patients infected with the 2019 novel coronavirus (SARS-Cov-2) outside of Wuhan, China: retrospective case series
# <re.Match object; span=(1375, 1383), match='covid-19'>
# <re.Match object; span=(134, 143), match='2019-ncov'>
# <re.Match object; span=(503, 513), match='sars-cov-2'>
# <re.Match object; span=(503, 513), match='sars-cov-2'>
# virus disease 2019 (covid-19) soon drew global a
# ronavirus, known as 2019-nCoV, in Wuhan, Hubei pr
# ubsequently renamed SARS-Cov-2 as it is similar to
# ubsequently renamed SARS-Cov-2 as it is similar to
# 2020-01-01 00:00:00 COVID-19 outbreak on the Diamond Princess cruise ship: estimating the epidemic potential and effectiveness of public health countermeasures
# <re.Match object; span=(2140, 2148), match='covid-19'>
# <re.Match object; span=(1794, 1804), match='sars-cov-2'>
# <re.Match object; span=(1794, 1804), match='sars-cov-2'>
#  cruise ship with a COVID-19 index case onboard
#  novel coronavirus, SARS-CoV-2, emerged in Wuhan,
#  novel coronavirus, SARS-CoV-2, emerged in Wuhan,
# 2020-01-01 00:00:00 HRCT imaging features in representative imported cases of 2019 novel coronavirus pneumonia
# <re.Match object; span=(40, 49), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) was firstly identi
# 2020-01-01 00:00:00 The reproductive number of COVID-19 is higher compared to SARS coronavirus
# <re.Match object; span=(229, 237), match='covid-19'>
# ronavirus and named COVID-19. As of 8 February 2
# 2020-01-01 00:00:00 Clinical characteristics of novel coronavirus cases in tertiary hospitals in Hubei Province
# <re.Match object; span=(227, 236), match='2019-ncov'>
#  novel coronavirus (2019-nCoV). [1] As of 6:00 PM
# 2020-01-01 00:00:00
# <re.Match object; span=(264, 273), match='2019-ncov'>
# <re.Match object; span=(3216, 3233), match='wuhan coronavirus'>
#  novel coronavirus (2019-nCoV), whose genetic seq
# pproach to managing Wuhan coronavirus pneumonia, starting
# 2020-01-01 00:00:00 Analysis of factors associated with disease outcomes in hospitalized patients with 2019 novel coronavirus disease
# <re.Match object; span=(862, 870), match='covid-19'>
# re in patients with COVID-19. [4] Therefore, it
# 2020-01-01 00:00:00 The outbreak of COVID-19: An overview
# <re.Match object; span=(2465, 2473), match='covid-19'>
# <re.Match object; span=(1218, 1227), match='2019-ncov'>
# for SARS, MERS, and COVID-19. 5, [8] [9] [10] [1
#  novel coronavirus (2019-nCoV) and recalled to ou
# 2020-01-01 00:00:00 Science in the fight against the novel coronavirus disease
# <re.Match object; span=(2186, 2194), match='covid-19'>
# <re.Match object; span=(499, 508), match='2019-ncov'>
# oronavirus disease (COVID-19) is the most severe
#  coronavirus, named 2019-nCoV by the WHO, was swi
# 2020-01-01 00:00:00 Single-cell RNA sequencing data suggest a role for angiotensin- converting enzyme 2 in kidney impairment in patients infected with 2019-nCoV
# <re.Match object; span=(101, 111), match='sars-cov-2'>
# <re.Match object; span=(101, 111), match='sars-cov-2'>
# rome coronavirus 2 (SARS-CoV-2) a global public he
# rome coronavirus 2 (SARS-CoV-2) a global public he
# 2020-01-19 00:00:00 A mathematical model for simulating the transmission of Wuhan novel Coronavirus
# <re.Match object; span=(241, 250), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) was identified as
# 2020-01-22 00:00:00 Functional assessment of cell entry and receptor usage for lineage B β- coronaviruses, including 2019-nCoV
# <re.Match object; span=(2526, 2535), match='2019-ncov'>
# ceptor usage of the 2019-nCoV spike, which emerge
# 2020-01-23 00:00:00 Eurosurveillance editorial team
# <re.Match object; span=(299, 308), match='2019-ncov'>
# us, currently named 2019-nCoV, was officially ann
# 2020-01-23 00:00:00
# <re.Match object; span=(21, 30), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) causing severe acu
# 2020-01-24 00:00:00 The 2019-new coronavirus epidemic: evidence for virus evolution
# <re.Match object; span=(2940, 2949), match='2019-ncov'>
# i: bioRxiv preprint 2019-nCoV zoonotic transmissi
# 2020-01-24 00:00:00 Host and infectivity prediction of Wuhan 2019 novel coronavirus using deep learning algorithm
# <re.Match object; span=(332, 341), match='2019-ncov'>
# lly infected by the 2019-nCoV viruses.
#  Large am
# 2020-01-24 00:00:00 Preliminary estimation of the basic reproduction number of novel coronavirus (2019-nCoV) in China, from 2019 to 2020: A data-driven analysis in the early phase of the outbreak
# <re.Match object; span=(60, 69), match='2019-ncov'>
#  novel coronavirus (2019-nCoV), was first reporte
# 2020-01-24 00:00:00
# <re.Match object; span=(994, 1003), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) in Wuhan, China, h
# 2020-01-24 00:00:00 A PREPRINT
# <re.Match object; span=(247, 256), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) as the causative a
# 2020-01-25 00:00:00 Modelling the epidemic trend of the 2019 novel coronavirus outbreak in China
# <re.Match object; span=(421, 430), match='2019-ncov'>
# hich was then named 2019-nCoV by WHO on 12 th Jan
# 2020-01-25 00:00:00
# <re.Match object; span=(1037, 1046), match='2019-ncov'>
# smissibility of the 2019-nCoV 59 is similar to th
# 2020-01-25 00:00:00 Complete genome characterisation of a novel coronavirus 4 associated with severe human respiratory disease in Wuhan
# <re.Match object; span=(978, 987), match='2019-ncov'>
#  referred 99 to as '2019-nCoV') and its whole gen
# 2020-01-26 00:00:00 Time-varying transmission dynamics of Novel Coronavirus Pneumonia in China At a Glance Commentary Scientific Knowledge on the Subject: Since
# <re.Match object; span=(197, 206), match='2019-ncov'>
# onia infection with 2019-nCoV, which was now name
# 2020-01-26 00:00:00 Single-cell RNA expression profiling of ACE2, the putative receptor of Wuhan 2019-nCov
# <re.Match object; span=(625, 634), match='2019-ncov'>
# nvestigation of the 2019-nCov infection disease,
# 2020-01-28 00:00:00 Breaking down of healthcare system: Mathematical modelling for controlling the novel coronavirus (2019-nCoV) outbreak in Wuhan, China
# <re.Match object; span=(93, 102), match='2019-ncov'>
# na and now named as 2019-nCoV [1] , has surged in
# 2020-01-28 00:00:00 Genomic characterization of the 2019 novel human-pathogenic coronavirus isolated from a patient with atypical pneumonia after visiting Wuhan
# <re.Match object; span=(2773, 2782), match='2019-ncov'>
# familial cluster of 2019-nCoV infection in a Shen
# 2020-01-28 00:00:00 Beware of asymptomatic transmission: Study on 2019-nCoV prevention and control measures based on extended SEIR model
# <re.Match object; span=(27, 36), match='2019-ncov'>
# 9 new coronavirus, "2019-nCoV", was discovered fr
# 2020-01-28 00:00:00 Nelfinavir was predicted to be a potential inhibitor of 2019-nCov main protease by an integrative approach combining homology modelling, molecular docking and binding free energy calculation
# <re.Match object; span=(150, 159), match='2019-ncov'>
# s, temporally named 2019-nCov, was identified to
# 2020-01-28 00:00:00 Incubation Period and Other Epidemiological Characteristics of 2019 Novel Coronavirus Infections with Right Truncation: A Statistical Analysis of Publicly Available Case Data
# <re.Match object; span=(587, 595), match='covid-19'>
#  natural history of COVID-19 infection, as these
# 2020-01-28 00:00:00 Title: The incubation period of 2019-nCoV infections among travellers from Wuhan, China
# <re.Match object; span=(40, 49), match='2019-ncov'>
# a novel coronavirus 2019-nCoV, has been identifie
# 2020-01-29 00:00:00 Potential inhibitors for 2019-nCoV coronavirus M protease from clinically approved medicines
# <re.Match object; span=(325, 334), match='2019-ncov'>
# ich was later named 2019-nCoV ('n' stands for nov
# 2020-01-29 00:00:00 Therapeutic Drugs Targeting 2019-nCoV Main Protease by High-Throughput Screening
# <re.Match object; span=(272, 281), match='2019-ncov'>
#  was later named as 2019-nCoV [1, 2] . By Jan 28,
# 2020-01-30 00:00:00 Evolution and variation of 2019-novel coronavirus
# <re.Match object; span=(780, 789), match='2019-ncov'>
# (novel coronavirus, 2019-nCoV), which was isolate
# 2020-01-30 00:00:00
# <re.Match object; span=(45, 54), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) cases were confirm
# 2020-01-30 00:00:00 Insights into Cross-species Evolution of Novel Human Coronavirus 2019-nCoV and Defining Immune Determinants for Vaccine Development
# <re.Match object; span=(255, 264), match='2019-ncov'>
#  novel Coronavirus (2019-nCoV) outbreak in China
# 2020-01-30 00:00:00 Title: Risk for Transportation of 2019 Novel Coronavirus (COVID-19) from Wuhan to Cities in China
# <re.Match object; span=(39, 47), match='covid-19'>
#  novel coronavirus (COVID-19) emerged in Wuhan,
# 2020-01-30 00:00:00 Journal Pre-proof Identification of potential cross-protective epitope between 2019-nCoV and SARS virus
# <re.Match object; span=(842, 851), match='2019-ncov'>
# ype of coronavirus (2019-nCoV) by WHO (WHO, 2020a
# 2020-01-30 00:00:00 Rapid communication
# <re.Match object; span=(90, 99), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) which can cause re
# 2020-01-30 00:00:00 Interpretable detection of novel human viruses from genome sequencing data
# <re.Match object; span=(746, 756), match='sars-cov-2'>
# <re.Match object; span=(746, 756), match='sars-cov-2'>
# ven pandemics (e.g. SARS-CoV-2 and the "swine flu"
# ven pandemics (e.g. SARS-CoV-2 and the "swine flu"
# 2020-01-30 00:00:00
# <re.Match object; span=(691, 700), match='2019-ncov'>
#  animal market. The 2019-nCoV is rapidly spreadin
# 2020-01-31 00:00:00 Nucleotide Analogues as Inhibitors of Viral Polymerases
# <re.Match object; span=(1347, 1356), match='2019-ncov'>
# aviruses, including 2019-nCoV and those responsib
# 2020-01-31 00:00:00 An emerging coronavirus causing pneumonia outbreak in Wuhan, China: calling for developing therapeutic and prophylactic strategies
# <re.Match object; span=(286, 295), match='2019-ncov'>
# the seafood market, 2019-nCoV may be originated f
# 2020-01-31 00:00:00 The 2019 Novel Coronavirus: A Crown Jewel of Pandemics?
# <re.Match object; span=(78, 87), match='2019-ncov'>
#  novel coronavirus (2019-nCoV), an overwhelming s
# 2020-01-31 00:00:00
# <re.Match object; span=(1726, 1735), match='2019-ncov'>
# e of eruption), and 2019-nCoV, a novel corona vir
# 2020-01-31 00:00:00 ACE2 and the cellular protease TMPRSS2 for entry into target cells 2 3
# <re.Match object; span=(67, 76), match='2019-ncov'>
# ogenic coronavirus, 2019-nCoV, in China, 24 and i
# 2020-01-31 00:00:00 2019-nCoV: The Identify-Isolate-Inform (3I) Tool Applied to a Novel Emerging Coronavirus
# <re.Match object; span=(24, 33), match='2019-ncov'>
#  Novel Coronavirus (2019-nCoV) is a novel respira
# 2020-02-02 00:00:00 Potent neutralization of 2019 novel coronavirus by recombinant ACE2-Ig
# <re.Match object; span=(6, 15), match='2019-ncov'>
#
# 2020-02-02 00:00:00 China through a drug-target interaction deep learning model
# <re.Match object; span=(1130, 1139), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) in Wuhan, China (5
# 2020-02-02 00:00:00 Transmission and epidemiological characteristics of Severe Acute Respiratory Syndrome Coronavirus 2 (SARS-CoV-2) infected Pneumonia (COVID-19): preliminary evidence obtained in comparison with 2003-SARS
# <re.Match object; span=(424, 432), match='covid-19'>
# <re.Match object; span=(249, 258), match='2019-ncov'>
# <re.Match object; span=(336, 346), match='sars-cov-2'>
# <re.Match object; span=(336, 346), match='sars-cov-2'>
# virus disease 2019 (COVID-19), also known as SAR
#  novel coronavirus (2019-nCoV) [1] , which was re
# rome Coronavirus 2 (SARS-CoV-2) on February 12 th
# rome Coronavirus 2 (SARS-CoV-2) on February 12 th
# 2020-02-02 00:00:00 Title: Genome Detective Coronavirus Typing Tool for rapid identification and characterization of novel coronavirus genomes Short title: Automated tool for phylogenetic and mutational analysis of coronaviruses genomes
# <re.Match object; span=(264, 273), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) has already caused
# 2020-02-02 00:00:00 Effectiveness of airport screening at detecting travellers infected with 2019-nCoV
# <re.Match object; span=(69, 78), match='2019-ncov'>
# still infected with 2019-nCoV on arrival at their
# 2020-02-02 00:00:00 Real-Time Estimation of the Risk of Death from Novel Coronavirus (COVID-19) Infection: Inference Using Exported Cases
# <re.Match object; span=(233, 241), match='covid-19'>
#  novel coronavirus (COVID-19) [3] . As of 27 Jan
# 2020-02-02 00:00:00 Reconciling early-outbreak estimates of the basic reproductive number and its uncertainty: framework and applications to the novel coronavirus (SARS-CoV-2) outbreak
# <re.Match object; span=(42, 52), match='sars-cov-2'>
# <re.Match object; span=(42, 52), match='sars-cov-2'>
#  novel coronavirus (SARS-CoV-2) has been spreading
#  novel coronavirus (SARS-CoV-2) has been spreading
# 2020-02-02 00:00:00 Early dynamics of transmission and control of COVID-19: a mathematical modelling study
# <re.Match object; span=(42, 50), match='covid-19'>
# <re.Match object; span=(2102, 2111), match='2019-ncov'>
# <re.Match object; span=(1651, 1661), match='sars-cov-2'>
# <re.Match object; span=(1651, 1661), match='sars-cov-2'>
# 020, an outbreak of COVID-19 has resulted in 46,
# using the keywords "2019-nCoV", "novel coronaviru
# thematical model of SARS-CoV-2 transmission with f
# thematical model of SARS-CoV-2 transmission with f
# 2020-02-02 00:00:00 A Novel Coronavirus Outbreak from Wuhan City in China, Rapid Need for Emergency Departments Preparedness and Response; a Letter to Editor
# <re.Match object; span=(448, 457), match='2019-ncov'>
#  temporarily named "2019-nCoV". Wuhan city is a m
# 2020-02-03 00:00:00 Molecular Modeling Evaluation of the Binding Effect of Ritonavir, Lopinavir and Darunavir to Severe Acute Respiratory Syndrome Coronavirus 2 Proteases
# <re.Match object; span=(44, 52), match='covid-19'>
# <re.Match object; span=(113, 123), match='sars-cov-2'>
# <re.Match object; span=(113, 123), match='sars-cov-2'>
# virus disease 2019 (COVID-19) caused by severe a
# rome coronavirus 2 (SARS-CoV-2) occurred in Wuhan,
# rome coronavirus 2 (SARS-CoV-2) occurred in Wuhan,
# 2020-02-03 00:00:00
# <re.Match object; span=(1951, 1960), match='2019-ncov'>
# 20, the outbreak of 2019-nCoV is still progressin
# 2020-02-03 00:00:00 Fast assessment of human receptor-binding capability of 2019 novel coronavirus (2019-nCoV)
# <re.Match object; span=(1080, 1089), match='2019-ncov'>
#  2019, a novel CoV (2019-nCoV) emerged from Wuhan
# 2020-02-03 00:00:00
# <re.Match object; span=(488, 497), match='2019-ncov'>
# ical to that of the 2019-nCoV isolated from the W
# 2020-02-04 00:00:00 Preliminary identification of potential vaccine targets for the COVID-19 coronavirus (SARS-CoV-2) based on SARS- CoV immunological studies
# <re.Match object; span=(24, 32), match='covid-19'>
# <re.Match object; span=(837, 846), match='2019-ncov'>
# <re.Match object; span=(796, 806), match='sars-cov-2'>
# <re.Match object; span=(796, 806), match='sars-cov-2'>
# ongoing outbreak of COVID-19 in the Chinese city
# y tentatively named 2019-nCoV), and to develop ef
# auses this disease, SARS-CoV-2 (originally tentati
# auses this disease, SARS-CoV-2 (originally tentati
# 2020-02-04 00:00:00 Specific ACE2 Expression in Cholangiocytes May Cause Liver Damage After 2019-nCoV Infection
# <re.Match object; span=(59, 68), match='2019-ncov'>
# temporally named as 2019-nCoV by the World Health
# 2020-02-04 00:00:00 Travel Medicine and Infectious Disease xxx (xxxx) xxxx
# <re.Match object; span=(494, 503), match='2019-ncov'>
#  recent outbreak of 2019-nCoV has been reported i
# 2020-02-04 00:00:00 Machine learning using intrinsic genomic signatures for rapid classification of novel pathogens: COVID-19 case study
# <re.Match object; span=(42, 50), match='covid-19'>
# the hypothesis that COVID-19 originated from bat
# 2020-02-04 00:00:00 Machine intelligence design of 2019-nCoV drugs
# <re.Match object; span=(357, 366), match='2019-ncov'>
# <re.Match object; span=(4355, 4372), match='wuhan coronavirus'>
# ovel coronavirus as 2019-nCoV on January 10. By J
#  pandemic, like the Wuhan coronavirus outbreak, causes th
# 2020-02-05 00:00:00 Forecasting the Wuhan coronavirus (2019-nCoV) epidemics using a simple (simplistic) model
# <re.Match object; span=(51, 60), match='2019-ncov'>
# navirus (designated 2019-nCoV) originated in Wuha
# 2020-02-05 00:00:00 Population movement, city closure and spatial transmission of the 2019-nCoV 1 infection in China 2
# <re.Match object; span=(87, 96), match='2019-ncov'>
# onavirus, 33 namely 2019-nCoV, emerged in Wuhan,
# 2020-02-05 00:00:00 Integrative Bioinformatics Analysis Provides Insight into the Molecular Mechanisms of 2019-nCoV
# <re.Match object; span=(142, 151), match='2019-ncov'>
#  novel coronavirus, 2019-nCoV was identified base
# 2020-02-05 00:00:00
# <re.Match object; span=(408, 417), match='2019-ncov'>
# A novel coronavirus 2019-nCoV has been identified
# 2020-02-05 00:00:00 Epidemiological parameter review and comparative dynamics of influenza, respiratory syncytial virus, rhinovirus, human coronavirus, and adenovirus
# <re.Match object; span=(2337, 2346), match='2019-ncov'>
# f novel coronavirus 2019-nCoV, and given the need
# 2020-02-05 00:00:00 Network-based Drug Repurposing for Human Coronavirus
# <re.Match object; span=(859, 868), match='2019-ncov'>
#  novel coronavirus (2019-nCoV), was found in Wuha
# 2020-02-05 00:00:00 Risk Assessment of Novel Coronavirus COVID-19 Outbreaks Outside China
# <re.Match object; span=(299, 307), match='covid-19'>
# <re.Match object; span=(223, 232), match='2019-ncov'>
# <re.Match object; span=(254, 264), match='sars-cov-2'>
# <re.Match object; span=(254, 264), match='sars-cov-2'>
# coronavirus disease COVID-19). The first patient
#  novel coronavirus (2019-nCoV, recently renamed a
# recently renamed as SARS-CoV-2, the cause of coron
# recently renamed as SARS-CoV-2, the cause of coron
# 2020-02-05 00:00:00 RNA based mNGS approach identifies a novel human coronavirus from two individual pneumonia cases in 2019 Wuhan outbreak
# <re.Match object; span=(2397, 2406), match='2019-ncov'>
# mapping, identified 2019-nCoV as sole pathogen, a
# 2020-02-05 00:00:00 Assessing spread risk of Wuhan novel coronavirus within and beyond China, January-April 2020: a travel network-based modelling study
# <re.Match object; span=(317, 326), match='2019-ncov'>
#  a new coronavirus (2019-nCoV) [1, 3] . The patho
# 2020-02-05 00:00:00 Epidemiology and Infection SARS to novel coronavirus -old lessons and new lessons
# <re.Match object; span=(1783, 1792), match='2019-ncov'>
# l of 2798 confirmed 2019-nCoV cases have been rep
# 2020-02-05 00:00:00 Getting to zero quickly in the 2019-nCov epidemic with vaccines or rapid testing
# <re.Match object; span=(34, 43), match='2019-ncov'>
# topping the ongoing 2019-nCov epidemic must be ba
# 2020-02-05 00:00:00 The impact of traffic isolation in Wuhan on the spread of 2019-nCov
# <re.Match object; span=(302, 311), match='2019-ncov'>
# he proliferation of 2019-nCov 4 .
#  In addition,
# 2020-02-05 00:00:00 Environmental Research and Public Health Editorial Does Wuhan Need to be in Lockdown during the Chinese Lunar New Year?
# <re.Match object; span=(1413, 1422), match='2019-ncov'>
# ation period of the 2019-nCoV at around 14 days,
# 2020-02-06 00:00:00 Epidemic doubling time of the COVID-19 epidemic by Chinese province 1
# <re.Match object; span=(743, 751), match='covid-19'>
# ubling times of the COVID-19 epidemic in mainlan
# 2020-02-06 00:00:00
# <re.Match object; span=(897, 906), match='2019-ncov'>
# the 2019 novel CoV (2019-nCoV) have led to more t
# 2020-02-07 00:00:00 Preparedness and vulnerability of African countries against introductions of 2019-nCoV
# <re.Match object; span=(97, 106), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) epidemic a Public
# 2020-02-07 00:00:00 ACE2 expression by colonic epithelial cells is associated with viral infection, immunity and energy metabolism
# <re.Match object; span=(811, 820), match='2019-ncov'>
# ity and immunity of 2019-nCoV infection.
#  Patien
# 2020-02-07 00:00:00 Travel Medicine and Infectious Disease xxx (xxxx) xxxx
# <re.Match object; span=(64, 73), match='2019-ncov'>
# arrier. Coronavirus 2019-nCoV emerged apparently
# 2020-02-07 00:00:00 Morbidity and Mortality Weekly Report
# <re.Match object; span=(416, 425), match='2019-ncov'>
# better characterize 2019-nCoV infection to guide
# 2020-02-08 00:00:00 Emerging novel coronavirus (2019-nCoV)-current scenario, evolutionary perspective based on genome analysis and recent developments
# <re.Match object; span=(2491, 2500), match='2019-ncov'>
# <re.Match object; span=(19692, 19709), match='wuhan coronavirus'>
#  coronavirus, named 2019-nCoV, has been noted in
# sful in growing the Wuhan coronavirus in cell culture. Fu
# 2020-02-08 00:00:00 Protein structure and sequence re-analysis of 2019-nCoV genome does not indicate snakes as its intermediate host or the unique similarity between its spike protein insertions and HIV-1
# <re.Match object; span=(32, 41), match='2019-ncov'>
# el conronavirus, or 2019-nCoV, recently caused a
# 2020-02-09 00:00:00 Title: Incorporating Human Movement Data to Improve Epidemiological Estimates for 2019-nCoV
# <re.Match object; span=(219, 228), match='2019-ncov'>
# , and the confirmed 2019-nCoV case reporting data
# 2020-02-09 00:00:00 Clinical characteristics of 2019 novel coronavirus infection in China
# <re.Match object; span=(240, 249), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) [2] , which resemb
# 2020-02-09 00:00:00 Bat origin of a new human coronavirus: there and back again
# <re.Match object; span=(191, 200), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) . Infection with 2
# 2020-02-09 00:00:00 Title Analysis of the epidemic growth of the early 2019-nCoV outbreak using internationally confirmed cases
# <re.Match object; span=(271, 280), match='2019-ncov'>
# ently designated as 2019-nCoV. Anxiety quickly gr
# 2020-02-10 00:00:00 A qualitative study of zoonotic risk factors among rural communities in southern China
# <re.Match object; span=(1389, 1398), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) emerged in Wuhan,
# 2020-02-11 00:00:00 The Essential Facts of Wuhan Novel Coronavirus Outbreak in China and Epitope-based Vaccine Designing against COVID-19
# <re.Match object; span=(26550, 26558), match='covid-19'>
# <re.Match object; span=(3214, 3224), match='sars-cov-2'>
# <re.Match object; span=(3214, 3224), match='sars-cov-2'>
# he best constructed COVID-19
#  vaccine. The vacc
# st four proteins of SARS-CoV-2 i.e., nucleocapsid
# st four proteins of SARS-CoV-2 i.e., nucleocapsid
# 2020-02-11 00:00:00 Bulk and single-cell transcriptomics identify tobacco-use disparity in lung gene expression of ACE2, the receptor of 2019-nCov
# <re.Match object; span=(290, 299), match='2019-ncov'>
#  Novel Coronavirus (2019-nCov) outbreak. They typ
# 2020-02-11 00:00:00 Severe acute respiratory syndrome-related coronavirus: The species and its viruses -a statement of the Coronavirus Study Group
# <re.Match object; span=(676, 685), match='2019-ncov'>
# <re.Match object; span=(2711, 2721), match='sars-cov-2'>
# <re.Match object; span=(2711, 2721), match='sars-cov-2'>
#  novel coronavirus, 2019-nCoV. The term "novel" m
# rome coronavirus 2, SARS-CoV-2, which will be used
# rome coronavirus 2, SARS-CoV-2, which will be used
# 2020-02-11 00:00:00 Novel coronavirus, poor quarantine, and the risk of pandemic
# <re.Match object; span=(617, 626), match='2019-ncov'>
#  novel coronavirus (2019-nCoV), antiviral treatme
# 2020-02-11 00:00:00 The lockdown of Hubei Province causing different transmission dynamics of the novel coronavirus (2019-nCoV) in Wuhan and
# <re.Match object; span=(21, 30), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) appeared in Decemb
# 2020-02-11 00:00:00
# <re.Match object; span=(637, 646), match='2019-ncov'>
# ype of coronavirus -2019-nCoV -provides plenty of
# 2020-02-11 00:00:00 Assessing the plausibility of subcritical transmission of 2019-nCoV in the United States
# <re.Match object; span=(14, 23), match='2019-ncov'>
#
# 2020-02-11 00:00:00 Spatially Explicit Modeling of 2019-nCoV Epidemic Trend Based on Mobile Phone Data in Mainland China
# <re.Match object; span=(476, 485), match='2019-ncov'>
# ch is then named as 2019-nCoV by the World Health
# 2020-02-11 00:00:00
# <re.Match object; span=(1770, 1779), match='2019-ncov'>
# ough CT findings of 2019-nCoV pneumonia were well
# 2020-02-11 00:00:00 Commentary Novel coronavirus: how things are in Wuhan
# <re.Match object; span=(6663, 6672), match='2019-ncov'>
# ory effects against 2019-nCoV. Researchers and Sc
# 2020-02-11 00:00:00
# <re.Match object; span=(271, 280), match='2019-ncov'>
#  a new coronavirus (2019-nCoV) (1) . As of Februa
# 2020-02-11 00:00:00 Diarrhea may be underestimated: a missing link in 2019 novel coronavirus
# <re.Match object; span=(86, 95), match='2019-ncov'>
# unknown coronavirus 2019-nCoV occurred in Wuhan C
# 2020-02-11 00:00:00 Assessing the Tendency of 2019-nCoV (COVID-19) Outbreak in China
# <re.Match object; span=(763, 771), match='covid-19'>
# <re.Match object; span=(10170, 10180), match='sars-cov-2'>
# <re.Match object; span=(10170, 10180), match='sars-cov-2'>
# , they compared the COVID-19 with SARS and MERS.
# he epidemic and the SARS-CoV-2 was in a state of n
# he epidemic and the SARS-CoV-2 was in a state of n
# 2020-02-11 00:00:00 Estimation of the Time-Varying Reproduction Number of COVID-19 Outbreak in China
# <re.Match object; span=(450, 458), match='covid-19'>
# <re.Match object; span=(358, 367), match='2019-ncov'>
# navirus was renamed COVID-19 by WHO on February
#  novel coronavirus (2019-nCoV), and its gene sequ
# 2020-02-11 00:00:00
# <re.Match object; span=(940, 949), match='2019-ncov'>
#  was diagnosed with 2019-nCoV based on the real-t
# 2020-02-11 00:00:00 Title: The Novel Coronavirus, 2019-nCoV, is Highly Contagious and More Infectious Than Initially Estimated
# ...
#  Although e
# rome coronavirus-2 (SARS-CoV-2) [3] .
#  Although e
# 2020-03-31 00:00:00
# <re.Match object; span=(1227, 1236), match='2019-ncov'>
# 6] . In the case of 2019-nCoV, viral research ins
# 2020-03-31 00:00:00 Letters to the Editor Emergence of a novel coronavirus causing respiratory illness from Wuhan, China Declaration of Competing Interest
# <re.Match object; span=(332, 341), match='2019-ncov'>
# entatively named as 2019-nCoV by The World Health
# 2020-03-31 00:00:00
# <re.Match object; span=(1786, 1795), match='2019-ncov'>
# l media response to 2019-nCoV remains unbalanced,
# 2020-03-31 00:00:00 Letters to the Editor Emergence of a novel coronavirus causing respiratory illness from Wuhan, China Declaration of Competing Interest
# <re.Match object; span=(332, 341), match='2019-ncov'>
# entatively named as 2019-nCoV by The World Health
# 2020-03-31 00:00:00 Highlights Risk factors control in atherosclerotic cardio- vascular disease patients
# <re.Match object; span=(12507, 12515), match='covid-19'>
# <re.Match object; span=(12291, 12301), match='sars-cov-2'>
# <re.Match object; span=(12291, 12301), match='sars-cov-2'>
# virus Disease 2019 (COVID-19) in Taiwan. In this
#  novel coronavirus (SARS-CoV-2) infection occurred
#  novel coronavirus (SARS-CoV-2) infection occurred
# 2020-03-31 00:00:00
# <re.Match object; span=(572, 581), match='2019-ncov'>
# <re.Match object; span=(8118, 8135), match='wuhan coronavirus'>
#  novel coronavirus (2019-nCoV) disease, a respira
# nt responses to the Wuhan coronavirus will soon be appare
# 2020-03-31 00:00:00
# <re.Match object; span=(38, 46), match='covid-19'>
# <re.Match object; span=(6461, 6470), match='2019-ncov'>
# <re.Match object; span=(6499, 6509), match='sars-cov-2'>
# <re.Match object; span=(6499, 6509), match='sars-cov-2'>
# pneumonia, named as COVID-19 by the World Health
#  novel coronavirus (2019-nCoV), a new virus also
# virus also named as SARS-CoV-2 by the Internationa
# virus also named as SARS-CoV-2 by the Internationa
# 2020-03-31 00:00:00
# <re.Match object; span=(62, 71), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) in China spread pr
# 2020-03-31 00:00:00 The epidemic of 2019-novel-coronavirus (2019-nCoV) pneumonia and insights for emerging infectious diseases in the future
# <re.Match object; span=(95, 104), match='2019-ncov'>
# ich was later named 2019-nCoV. Since the first hu
# 2020-03-31 00:00:00
# <re.Match object; span=(930, 939), match='2019-ncov'>
#  been designated as 2019-nCoV by the World Health
# 2020-03-31 00:00:00 Is COVID-19 receiving ADE from other coronaviruses?
# <re.Match object; span=(59, 67), match='covid-19'>
# <re.Match object; span=(285, 295), match='sars-cov-2'>
# <re.Match object; span=(285, 295), match='sars-cov-2'>
# garding the current COVID-19 coronavirus epidemi
# nhancement (ADE) of SARS-CoV-2 due to prior exposu
# nhancement (ADE) of SARS-CoV-2 due to prior exposu
# 2020-03-31 00:00:00 Letters to the Editor Emergence of a novel coronavirus causing respiratory illness from Wuhan, China Declaration of Competing Interest
# <re.Match object; span=(332, 341), match='2019-ncov'>
# entatively named as 2019-nCoV by The World Health
# 2020-03-31 00:00:00 International Journal of Antimicrobial Agents
# <re.Match object; span=(263, 273), match='sars-cov-2'>
# <re.Match object; span=(263, 273), match='sars-cov-2'>
#  novel coronavirus (SARS-CoV-2) emergence [2] , we
#  novel coronavirus (SARS-CoV-2) emergence [2] , we
# 2020-03-31 00:00:00
# <re.Match object; span=(390, 398), match='covid-19'>
# <re.Match object; span=(147, 157), match='sars-cov-2'>
# <re.Match object; span=(147, 157), match='sars-cov-2'>
# oronavirus disease (COVID-19), caused by SARS-Co
# ome corona virus 2 (SARS-CoV-2). 1 By Feb 12, 2020
# ome corona virus 2 (SARS-CoV-2). 1 By Feb 12, 2020
# 2020-03-31 00:00:00
# <re.Match object; span=(1112, 1121), match='2019-ncov'>
# sido designado como 2019-nCoV por la Organización
# 2020-03-31 00:00:00 Persistence of coronaviruses on inanimate surfaces and their inactivation with biocidal agents
# <re.Match object; span=(21, 31), match='sars-cov-2'>
# <re.Match object; span=(21, 31), match='sars-cov-2'>
#  novel coronavirus (SARS-CoV-2) has recently emerg
#  novel coronavirus (SARS-CoV-2) has recently emerg
# 2020-03-31 00:00:00
# <re.Match object; span=(39, 48), match='2019-ncov'>
#  novel coronavirus, 2019-nCoV, has dominated head
# 2020-03-31 00:00:00
# <re.Match object; span=(823, 832), match='2019-ncov'>
# <re.Match object; span=(804, 821), match='wuhan coronavirus'>
#  Wuhan coronavirus [2019-nCoV} epidemic [1] illus
# nal travel. The new Wuhan coronavirus [2019-nCoV} epidemi
# 2020-04-15 00:00:00 New regulatory strategies to manage medicines shortages in Europe
# <re.Match object; span=(776, 784), match='covid-19'>
# oronavirus disease (COVID-19) outbreak in China]
# 2020-04-30 00:00:00 2019-novel Coronavirus severe adult respiratory distress syndrome in two cases in Italy: An uncommon radiological presentation
# <re.Match object; span=(1743, 1751), match='covid-19'>
# aboratory confirmed COVID-19 in Italy, who progr
# 2020-04-30 00:00:00 Comment
# <re.Match object; span=(102, 110), match='covid-19'>
# <re.Match object; span=(518, 527), match='2019-ncov'>
# <re.Match object; span=(377, 387), match='sars-cov-2'>
# <re.Match object; span=(377, 387), match='sars-cov-2'>
# For more on the WHO COVID-19 situation report-28
# previously known as 2019-nCoV, has spread to more
# rome coronavirus 2 (SARS-CoV-2), which caused an o
# rome coronavirus 2 (SARS-CoV-2), which caused an o
# 2020-04-30 00:00:00
# <re.Match object; span=(791, 799), match='covid-19'>
# <re.Match object; span=(756, 766), match='sars-cov-2'>
# <re.Match object; span=(756, 766), match='sars-cov-2'>
# e disease was named COVID-19 by the World Health
# rome Coronavirus 2 (SARS-CoV-2). The disease was n
# rome Coronavirus 2 (SARS-CoV-2). The disease was n
# 2020-04-30 00:00:00
# <re.Match object; span=(914, 922), match='covid-19'>
# rrent shortage with COVID-19, levels around the
# 2020-04-30 00:00:00
# <re.Match object; span=(91, 99), match='covid-19'>
# virus disease 2019 (COVID-19) epidemic, with mos
# 2020-04-30 00:00:00
# <re.Match object; span=(238, 246), match='covid-19'>
#  novel coronavirus (COVID-19) in Wuhan, Hubei, C
# 2020-04-30 00:00:00 Comment Comment e453
# <re.Match object; span=(311, 319), match='covid-19'>
# uccessfully contain COVID-19 outbreaks after imp
# 2020-04-30 00:00:00 Invited Commentary An Invited Commentary on "World Health Organization declares global emergency: A review of the 2019 novel Coronavirus (COVID-19)": Emergency or new reality?
# <re.Match object; span=(49, 57), match='covid-19'>
# virus Disease 2019 (COVID-19) outbreak in Wuhan,
# 2020-04-30 00:00:00
# <re.Match object; span=(60, 69), match='2019-ncov'>
# firmed or suspected 2019-nCoV (new coronavirus di
# 2020-04-30 00:00:00 Journal Pre-proof What are we doing in the dermatology outpatient department amidst the raging of 2019-nCoV?
# <re.Match object; span=(219, 228), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) [1] . As of Feb 10
# 2020-04-30 00:00:00 The spike glycoprotein of the new coronavirus 2019-nCoV contains a furin- like cleavage site absent in CoV of the same clade
# <re.Match object; span=(28, 37), match='2019-ncov'>
#  a new coronavirus (2019-nCoV) infecting Humans h
# 2020-04-30 00:00:00 Comment
# <re.Match object; span=(454, 463), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) was considered to
# 2020-04-30 00:00:00
# <re.Match object; span=(3934, 3942), match='covid-19'>
# <re.Match object; span=(3700, 3709), match='2019-ncov'>
# <re.Match object; span=(3905, 3915), match='sars-cov-2'>
# <re.Match object; span=(3905, 3915), match='sars-cov-2'>
# 2, and the disease, COVID-19 (COron-aVIrus Disea
# provisionally named 2019-nCoV (nCoV for new coron
# his new coronavirus SARS-CoV-2, and the disease, C
# his new coronavirus SARS-CoV-2, and the disease, C
# 2020-04-30 00:00:00 Predicting the impacts of epidemic outbreaks on global supply chains: A simulation-based analysis on the coronavirus outbreak (COVID-19/SARS-CoV-2) case
# <re.Match object; span=(1383, 1391), match='covid-19'>
# <re.Match object; span=(1392, 1402), match='sars-cov-2'>
# <re.Match object; span=(1392, 1402), match='sars-cov-2'>
# ently, coronavirus (COVID-19/SARS-CoV-2).
#  The
# ronavirus (COVID-19/SARS-CoV-2).
#  The recent coro
# ronavirus (COVID-19/SARS-CoV-2).
#  The recent coro
# 2020-04-30 00:00:00 Full-genome evolutionary analysis of the novel corona virus (2019-nCoV) rejects the hypothesis of emergence as a result of a recent recombination event
# <re.Match object; span=(33, 42), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) associated with hu
# 2020-04-30 00:00:00
# <re.Match object; span=(18, 26), match='covid-19'>
# <re.Match object; span=(123, 133), match='sars-cov-2'>
# <re.Match object; span=(123, 133), match='sars-cov-2'>
#
# deemed as potential SARS-CoV-2 carriers. 1 Some me
# deemed as potential SARS-CoV-2 carriers. 1 Some me
# 2020-04-30 00:00:00
# <re.Match object; span=(41, 50), match='2019-ncov'>
# and Transmission of 2019-nCoV Yifei Xu 1, * A nov
# 2020-04-30 00:00:00 A disconnected policy network: The UK's response to the Sierra Leone Ebola epidemic
# <re.Match object; span=(366, 374), match='covid-19'>
# hinese Coronavirus (Covid-19) outbreak seems to
# 2020-04-30 00:00:00 Psychological crisis intervention during the outbreak period of new coronavirus pneumonia from experience in Shanghai
# <re.Match object; span=(60, 68), match='covid-19'>
# a (NCP, also called COVID-19) since January 2020
# 2020-04-30 00:00:00 Journal Pre-proof Is the Africa prepared for tackling the COVID-19 (SARS-CoV-2) epidemic? -lessons from past outbreaks, ongoing pan-African public health efforts, and implications for the future Invited Fastrack Editorial for IJID Title: Is the Africa prepared for tackling the COVID-19 (SARS-CoV-2) epidemic? -lessons from past outbreaks, ongoing pan-African public health efforts, and implications for the future Authors
# <re.Match object; span=(167, 175), match='covid-19'>
# <re.Match object; span=(280, 289), match='2019-ncov'>
# <re.Match object; span=(177, 187), match='sars-cov-2'>
# <re.Match object; span=(177, 187), match='sars-cov-2'>
# words: Coronavirus; COVID-19: SARS-CoV-2; Epidem
# avirus, SARS-CoV-2 (2019-nCoV), was first identif
# onavirus; COVID-19: SARS-CoV-2; Epidemic; Africa;
# onavirus; COVID-19: SARS-CoV-2; Epidemic; Africa;
# 2020-04-30 00:00:00
# <re.Match object; span=(173, 181), match='covid-19'>
# sease, named as the COVID-19. World Health Organ
# 2020-04-30 00:00:00 Letter to the editor
# <re.Match object; span=(56, 65), match='2019-ncov'>
# <re.Match object; span=(33, 43), match='sars-cov-2'>
# <re.Match object; span=(33, 43), match='sars-cov-2'>
# S-CoV-2, previously 2019-nCoV) can cause severe l
# SARS-coronavirus-2 (SARS-CoV-2, previously 2019-nC
# SARS-coronavirus-2 (SARS-CoV-2, previously 2019-nC
# 2020-04-30 00:00:00 Opinion Novel coronavirus: From discovery to clinical diagnostics
# <re.Match object; span=(697, 706), match='2019-ncov'>
# virus designated as 2019-nCoV is another human pa
# 2020-05-01 00:00:00 Anti-HCV, nucleotide inhibitors, repurposing against COVID-19
# <re.Match object; span=(284, 292), match='covid-19'>
# s suspected to be a COVID-19 patient [1, 3] . Ad
# 2020-05-31 00:00:00 CT manifestations of coronavirus disease-2019: A retrospective analysis of 73 cases by disease severity
# <re.Match object; span=(26, 34), match='covid-19'>
# virus Disease-2019 (COVID-19) is an acute infect
# 2020-05-31 00:00:00 Viroporins and inflammasomes: a key to understand virus-induced inflammation
# <re.Match object; span=(9537, 9545), match='covid-19'>
# he current outbreak COVID-19 [49] . HCV p7 was s
# 2020-05-31 00:00:00 Commentary Of chloroquine and COVID-19
# <re.Match object; span=(5100, 5108), match='covid-19'>
# <re.Match object; span=(4475, 4484), match='2019-ncov'>
# <re.Match object; span=(189, 199), match='sars-cov-2'>
# <re.Match object; span=(189, 199), match='sars-cov-2'>
# in the treatment of COVID-19 ("Chinese Clinical
# e in the control of 2019-nCoV infection in vitro"
# merged coronavirus (SARS-CoV-2) (Colson et al., 20
# merged coronavirus (SARS-CoV-2) (Colson et al., 20
# 2020-05-31 00:00:00 First respiratory transmitted food borne outbreak?
# <re.Match object; span=(184, 194), match='sars-cov-2'>
# <re.Match object; span=(184, 194), match='sars-cov-2'>
#  novel coronavirus (SARS-CoV-2) until February 10,
#  novel coronavirus (SARS-CoV-2) until February 10,
# 2020-05-31 00:00:00 Traditional Chinese medicine for COVID-19 treatment 1. Summary
# <re.Match object; span=(39, 47), match='covid-19'>
# rate of QPD against COVID-19 is over 90 %. Accor
# 2020-05-31 00:00:00 New thinking in the treatment of 2019 novel coronavirus pneumonia
# <re.Match object; span=(83, 92), match='2019-ncov'>
#  of transmission of 2019-nCoV was via large dropl
# 2020-05-31 00:00:00 Analysis and forecast of COVID-19 spreading in China, Italy and France
# <re.Match object; span=(43, 51), match='covid-19'>
# virus disease 2019 (COVID-19) emerged in Wuhan,
# 2020-06-30 00:00:00 Clinical considerations for patients with diabetes in times of COVID-19 epidemic
# <re.Match object; span=(0, 8), match='covid-19'>
# <re.Match object; span=(6580, 6589), match='2019-ncov'>
# <re.Match object; span=(73, 83), match='sars-cov-2'>
# <re.Match object; span=(73, 83), match='sars-cov-2'>
#
#  has been reported. 2019-nCoV receptor binding si
#  by the coronavirus SARS-CoV-2 (Severe Acute Respi
#  by the coronavirus SARS-CoV-2 (Severe Acute Respi
# 2020-06-30 00:00:00
# <re.Match object; span=(841, 849), match='covid-19'>
# <re.Match object; span=(1015, 1024), match='2019-ncov'>
# <re.Match object; span=(75, 85), match='sars-cov-2'>
# <re.Match object; span=(75, 85), match='sars-cov-2'>
# h or without severe COVID-19.
#  We carried out a
# el coronavirus" OR "2019-nCoV" OR "COVID-19" with
# rome coronavirus 2 (SARS-CoV-2), is now producing
# rome coronavirus 2 (SARS-CoV-2), is now producing
# 2020-06-30 00:00:00 Journal Pre-proofs Positive rate of RT-PCR detection of SARS-CoV-2 infection in 4880 cases from one hospital in
# <re.Match object; span=(613, 621), match='covid-19'>
# <re.Match object; span=(1487, 1496), match='2019-ncov'>
# <re.Match object; span=(44, 54), match='sars-cov-2'>
# <re.Match object; span=(44, 54), match='sars-cov-2'>
# ic, just as in this COVID-19 outbreak.
#  patient
# pneumonia caused by 2019-nCoV (the 5th edition) a
#  novel coronavirus (SARS-CoV-2) infection since De
#  novel coronavirus (SARS-CoV-2) infection since De
# 2020-07-31 00:00:00 Genetic diversity and evolution of SARS-CoV-2
# <re.Match object; span=(18, 28), match='sars-cov-2'>
# <re.Match object; span=(18, 28), match='sars-cov-2'>
#
#
# 2020-07-31 00:00:00 Pathogenic viruses: Molecular detection and characterization
# <re.Match object; span=(24215, 24224), match='2019-ncov'>
#  novel coronavirus (2019-nCoV) which emerged in W
# 2020-07-31 00:00:00 Cardiothoracic Imaging Asymptomatic novel coronavirus pneumonia patient outside Wuhan: The value of CT images in the course of the disease
# <re.Match object; span=(239, 247), match='covid-19'>
# <re.Match object; span=(194, 203), match='2019-ncov'>
# ly officially named COVID-19 by the WHO on Febru
#  novel coronavirus (2019-nCoV) and subsequently o
# 2020-07-31 00:00:00 Severe air pollution events not avoided by reduced anthropogenic activities during COVID-19 outbreak
# <re.Match object; span=(3184, 3192), match='covid-19'>
# virus disease 2019 (COVID-19) is an infectious d
# 2020-08-31 00:00:00
# <re.Match object; span=(823, 831), match='covid-19'>
# <re.Match object; span=(89, 99), match='sars-cov-2'>
# <re.Match object; span=(89, 99), match='sars-cov-2'>
# pread and impact of COVID-19 to very high at a g
# rome coronavirus 2 (SARS-CoV-2), is a Public Healt
# rome coronavirus 2 (SARS-CoV-2), is a Public Healt
# 2020-12-31 00:00:00 Prospect and application of Internet of Things technology for prevention of SARIs
# <re.Match object; span=(46, 55), match='2019-ncov'>
# which is known as ''2019-nCoV" (nCoV), 1 was disc
# 2020-12-31 00:00:00
# <re.Match object; span=(23, 31), match='covid-19'>
# <re.Match object; span=(510, 519), match='2019-ncov'>
#  aim is to diagnose COVID-19 earlier and to impr
#  novel coronavirus (2019-nCoV) infection. It clas

# %%
sample_df.iloc[1]['text_body']
# Out:
# 'As of September 2019, GenBank [1] contained more than 3 million viral sequences totaling over 4 billion nucleotides in length and including over 180,000 complete genomes for viruses other than influenza. More than 250,000 of these sequences were submitted in 2018. All sequence submissions are validated prior to deposition in GenBank. Automated validation and annotation methods become increasingly important as sequence submission numbers grow. Table 1 shows the number of sequences for the 16 virus species with the most sequences in GenBank. Influenza sequences are the second most abundant and the National Center of Biotechnology Information (NCBI), where GenBank is housed, has expended considerable effort to organize flu sequences and streamline the submission of new influenza virus sequences, including a tool to validate and annotate flu submissions called FLAN [2] . The influenza virus sequence submission tool (https://www.ncbi.nlm.nih.gov/ genome/viruses/variation/help/flu-help-center/submitflu-sequences/) is implemented specifically for influenza with many hard-coded features. It has proven [3] (https:// www.ncbi.nlm.nih.gov/genome/viruses/variation) includes specialized components that attempt to normalize annotation of previously submitted sequences for rotaviruses, dengue virus, West Nile virus, ebolaviruses, Zika virus, and MERS coronavirus. The resulting standardized annotation supports virus-specific searches using gene and protein names. However, the Virus Variation Resource does not support the submission of new sequences, and its tools are not generalizable, such that creating components for additional virus species is laborious.\r\n Early in the history of GenBank, Michael Waterman presciently wrote that "Entering new sequences into the databases requires the database staff to analyze and interpret the sequences and the associated scientific literature [4] ." Even earlier, Margaret Dayhoff had justified her enormous efforts at sequence database curation reasoning that "a carefully verified collection [of sequences] was more economical in the long run than a quick and dirty collection" [5] . At NCBI, sequence submissions have been checked by indexers since NCBI began operating GenBank, but over the years, limitations to this arrangment have become apparent. First, the number and size of sequence submissions has grown much faster than the NCBI budget and the capability to hire more indexers. Second, although GenBank indexers are trained rigorously and homogeneously and use the same software, there is no formal mechanism to enforce "inter-observer agreement", meaning that all GenBank indexers would be guaranteed to give the same evaluation of the same submission. Third, researchers who wish to submit their sequences cannot reproduce all the checks that GenBank indexers do. Consequently, problematic sequences cause delays and e-mail interactions between submitters and indexers that might be avoidable using a more deterministic and open system of checks. The importance of transparency in curatorial analysis was emphasized by Walter Goad, one of the founders of GenBank: "It is important that we be perceived by the molecular biology community as offering free and open access to the information and programs we will be collecting" [5] .\r\n For bacterial genomes, these limitations have been addressed by the release of NCBI\'s Prokaryotic Genome Annotation Pipeline (PGAP) [6] , which is now available for download as a standalone package (https://github.com/ncbi/pgap/releases). For influenza virus, the limitations were addressed first by FLAN [2] and then by the influenza virus submission tools provided by GenBank [3] . Tools for checking submissions of non-influenza viruses have lagged but in the work described herein we describe new software that begins to close the gap. Importantly, our new software can already be used for many viruses (currently excluding circular genome and segmented viruses) breaking from the paradigm ...

# %%
matches = []
for key in covid_keywords:
    match = re.search(key.lower(), sample['text_body'].lower())
    if match:
        print(match)
        matches.append(match)
# Out:
# <re.Match object; span=(27, 44), match='novel coronavirus'>

# %%
for match in matches:
    print(sample['text_body'][match.start()-20:match.end() + 20])
# Out:
#  coronavirus 229E (HcoV-229E) (Sanchez et al.
