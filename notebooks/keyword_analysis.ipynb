# %% [markdown]
# # Abstract
# The objective of this notebook will be to perform keyword analysis on the papers for Covid-19 risk factors.

# %%
import re
import glob
import json
from os import path
import pandas as np
import pandas as pd
from datetime import datetime

# %%
papers_df = pd.read_csv('../output/papers_df.csv', 
                        index_col=0, 
                        keep_default_na=False,
                       parse_dates=['publish_time'])

# %%
transmission_keywords = ['transmi', 'sneez', 'contact trac', 'reproduc', 'environ']

# %%
smoke_keywords = ['smok']

# %%
covid_keywords = ['COVID-19', 'HCoV-19', 'CORD-19' ,'2019-nCoV', 'Wuhan coronavirus', 'SARS-CoV-2', 'SARS-COV-2']
covid_keywords = [word.lower() for word in covid_keywords]

# %%
# covid_papers = papers_df[papers_df['text_body'].apply(lambda x : 
#                                                 any(key in x.lower() for
#                                                     key in covid_keywords)
#                                                )]

# %%
json_files = glob.glob(f'../data/**/*.json', recursive=True)

# %%
paper_dicts = []
for file in json_files:
    name = path.basename(file)
    with open(file) as f:
        data = json.load(f)
    paper_obj = {'id':name,
                 'data':data}
    paper_dicts.append(paper_obj)

# %%
def tokenize(text):
    text = text.lower().strip()
    if text[-1] == 's':
        text = text[:-1]
    return text

# %%
sections = {}
for paper in paper_dicts:
    body = paper['data']['body_text']
    paper_sections = set()
    for paragraph in body:
        if 'section' in paragraph:
            paper_sections.add(paragraph['section'])
    for section in paper_sections:
        if len
        section = tokenize(section)
        if section in sections:
            sections[section] += 1
        else:
            sections[section] = 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-59-8110e36f2e14> in <module>
#       7             paper_sections.add(paragraph['section'])
#       8     for section in paper_sections:
# ----> 9         section = tokenize(section)
#      10         if section in sections:
#      11             sections[section] += 1
#
# <ipython-input-58-1e7dd242f05c> in tokenize(text)
#       1 def tokenize(text):
#       2     text = text.lower().strip()
# ----> 3     if text[-1] == 's':
#       4         text = text[:-1]
#       5     return text
#
# IndexError: string index out of range

# %%
sorted(sections.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('Introduction', 22693),
#  ('Discussion', 19468),
#  ('', 11778),
#  ('Conclusions', 7052),
#  ('Conclusion', 5688),
#  ('Results', 5605),
#  ('INTRODUCTION', 4455),
#  ('DISCUSSION', 4052),
#  ('Background', 3997),
#  ('Statistical analysis', 3376),
#  ('Methods', 1971),
#  ('1. Introduction', 1383),
#  ('RESULTS', 1360),
#  ('Competing interests', 1182),
#  ('Materials and methods', 1000),
#  ('Statistical Analysis', 970),
#  ('CONCLUSION', 778),
#  ('Materials and Methods', 742),
#  ("Authors' contributions", 739),
#  ('CONCLUSIONS', 715),
#  ('MATERIALS AND METHODS', 711),
#  ('Results and discussion', 706),
#  ('Statistical analysis ::: Methods', 674),
#  ('Summary', 600),
#  ('Funding', 582),
#  ('Ethics statement', 549),
#  ('4. Discussion', 528),
#  ('Data analysis', 504),
#  ('Statistical analysis ::: Materials and methods', 489),
#  ('Statistics', 484),
#  ('SUMMARY', 479),
#  ('Animals', 474),
#  ('Author Contributions', 471),
#  ('Concluding remarks', 469),
#  ('Statistical analyses', 439),
#  ('Abbreviations', 430),
#  ('Ethics Statement', 393),
#  ('The Study', 393),
#  ('Conflicts of interest', 390),
#  ('Viruses', 389),
#  ('Results and Discussion', 382),
#  ('Study design', 377),
#  ('AUTHOR CONTRIBUTIONS', 374),
#  ('Western blot analysis', 369),
#  ('Conflict of interest', 368),
#  ('ACKNOWLEDGMENTS', 362),
#  ('Statistical analysis ::: Materials and Methods', 359),
#  ('Data collection', 354),
#  ('Authors’ contributions', 354),
#  ('Limitations', 352),
#  ('Cells and viruses', 349),
#  ('Conflict of Interest Statement', 344),
#  ('METHODS', 343),
#  ('Supporting Information', 336),
#  ('Diagnosis', 334),
#  ('Treatment', 327),
#  ('5. Conclusions', 321),
#  ('Supplementary Material', 309),
#  ('Flow cytometry', 289),
#  ('Materials', 279),
#  ('Pre-publication history', 276),
#  ('Study population', 275),
#  ('Mice', 272),
#  ('Author Summary', 272),
#  ('Statistical Analysis ::: Materials and Methods', 271),
#  ('Virus', 264),
#  ('Concluding Remarks', 260),
#  ('Epidemiology', 256),
#  ('Western blotting', 251),
#  ('Phylogenetic analysis', 246),
#  ('ELISA', 244),
#  ('Ethical approval', 241),
#  ('Acknowledgments', 228),
#  ('Sample collection', 227),
#  ('Patients', 226),
#  ('Cell culture', 223),
#  ('Additional Information', 218),
#  ('Antibodies', 217),
#  ('2.', 207),
#  ('Data', 206),
#  ('Ethics statement ::: Materials and Methods', 206),
#  ('a b s t r a c t', 200),
#  ('Plasmids', 198),
#  ('FUNDING', 195),
#  ('Declaration of Competing Interest', 192),
#  ('Cells', 189),
#  ('Main', 186),
#  ('Author contributions', 185),
#  ('Statistical Analyses', 185),
#  ('Immunohistochemistry', 183),
#  ('Conflict of interest statement', 182),
#  ('Objectives', 181),
#  ('(which was not peer-reviewed)', 178),
#  ('Experimental design', 178),
#  ('4. Conclusions', 178),
#  ('Participants', 176),
#  ('Ethics Statement ::: Materials and Methods', 168),
#  ('Contributors', 157),
#  ('Statistical methods', 157),
#  ('Histopathology', 157),
#  ('Immunofluorescence', 157),
#  ('Western blot', 156),
#  ('Data Analysis', 155),
#  ('Prevention', 154),
#  ('Sequence analysis', 153),
#  ('Influenza', 152),
#  ('Electron microscopy', 152),
#  ('Reagents', 151),
#  ('Serology', 150),
#  ('Definitions', 149),
#  ('Ethics statement ::: Methods', 149),
#  ('RNA extraction', 148),
#  ('ARTICLE IN PRESS', 146),
#  ('Data analysis ::: Methods', 144),
#  ('Ethics', 141),
#  ('Conflicts of Interest:', 139),
#  ('Pathogenesis', 137),
#  ('Virus isolation', 135),
#  ('Cells and virus', 135),
#  ('I. INTRODUCTION', 134),
#  ('Declaration of interests', 134),
#  ('SUPPLEMENTAL MATERIAL', 134),
#  ('Plasmid construction', 132),
#  ('Subjects', 129),
#  ('Analysis', 129),
#  ('Ethics statement ::: Materials and methods', 128),
#  ('Role of the funding source', 126),
#  ('Case report', 123),
#  ('Contents lists available at ScienceDirect', 122),
#  ('Statistical analysis ::: MATERIALS AND METHODS', 122),
#  ('A B', 121),
#  ('Study Design', 120),
#  ('Samples', 119),
#  ('4.', 119),
#  ('Review', 119),
#  ('Data availability', 118),
#  ('5.', 118),
#  ('Additional file', 118),
#  ('Chemistry', 118),
#  ('RESULTS AND DISCUSSION', 117),
#  ('Viruses and cells', 116),
#  ('DIAGNOSIS', 116),
#  ('Data Availability', 115),
#  ('Outcomes', 115),
#  ('Histology', 114),
#  ('Table 2', 114),
#  ('3.', 111),
#  ('Statistical Analysis ::: Methods', 111),
#  ('Perspectives', 110),
#  ('RT-PCR', 110),
#  ('Ethical considerations', 108),
#  ('Additional files', 108),
#  ('Conflicts of Interest', 107),
#  ('CONCLUDING REMARKS', 107),
#  ('Virus and cells', 106),
#  ('Bacteria', 106),
#  ('Discussion and conclusions', 104),
#  ('Material and methods', 103),
#  ('Data sources', 103),
#  ('Data collection ::: Methods', 103),
#  ('Introducción', 103),
#  ('1.', 102),
#  ('Conflict of Interest Statement ::: Author Contributions', 102),
#  ('Flow Cytometry', 101),
#  ('Acknowledgements', 101),
#  ('EPIDEMIOLOGY', 101),
#  ('Method', 100),
#  ('Sampling', 100),
#  ('Protein expression and purification', 100),
#  ('TREATMENT', 100),
#  ('Study design ::: Methods', 100),
#  ('Statistical analyses ::: Methods', 100),
#  ('Vaccines', 99),
#  ('Methodology', 99),
#  ('Vaccination', 99),
#  ('3. Discussion', 99),
#  ('Findings', 97),
#  ('Declaration of competing interest', 96),
#  ('Data Collection', 95),
#  ('Cell viability assay', 95),
#  ('Clinical signs', 94),
#  ('Tuberculosis', 93),
#  ('Adenovirus', 93),
#  ('Immunoblotting', 92),
#  ('ETHICS STATEMENT', 92),
#  ('Western Blot Analysis', 92),
#  ('Etiology', 92),
#  ('Prognosis', 92),
#  ('SUPPLEMENTARY DATA', 91),
#  ('Discussion and conclusion', 90),
#  ('•', 90),
#  ('Disclaimer', 89),
#  ('Study Population', 89),
#  ('CONFLICT OF INTEREST', 88),
#  ('Limitations ::: Discussion', 88),
#  ('Conflict of interest statement ::: Author contributions', 88),
#  ('Setting', 86),
#  ('Rotavirus', 86),
#  ('Enzyme-linked immunosorbent assay (ELISA)', 86),
#  ('Future directions', 86),
#  ('Management', 86),
#  ('Cell lines', 85),
#  ('Sensitivity analysis', 85),
#  ('Virus titration', 85),
#  ('Figure 2.', 84),
#  ('Patient characteristics', 84),
#  ('Statistics ::: Methods', 84),
#  ('Real-time PCR', 83),
#  ('Figure 2', 83),
#  ('Procedures', 83),
#  ('Literature review', 83),
#  ('3. Results', 83),
#  ('Conflict of Interest', 82),
#  ('Cell Culture', 82),
#  ('Chemicals', 82),
#  ('Cytotoxicity assay', 82),
#  ('Search strategy and selection criteria', 81),
#  ('Discussions', 79),
#  ('Malaria', 79),
#  ('Transmission', 79),
#  ('EXPERIMENTAL PROCEDURES', 78),
#  ('Coronaviruses', 78),
#  ('Table 1', 78),
#  ('SUPPLEMENTARY MATERIAL', 77),
#  ('Highlights', 77),
#  ('I. Introduction', 76),
#  ('Compliance with ethical standards', 76),
#  ('Electron Microscopy', 76),
#  ('Animals ::: Materials and Methods', 76),
#  ('Nucleic acid extraction', 75),
#  ('Conclusions and perspectives', 75),
#  ('Cells and Viruses', 75),
#  ('Confocal microscopy', 75),
#  ('Fig. 2.', 75),
#  ('Plaque assay', 74),
#  ('Sequencing', 73),
#  ('Clinical samples', 72),
#  ('Coronavirus', 72),
#  ('Expert commentary', 72),
#  ('Five-year view', 72),
#  ('Animals ::: Methods', 72),
#  ('Added value of this study', 71),
#  ('Phylogenetic Analysis', 71),
#  ('Search strategy', 71),
#  ('Clinical features', 71),
#  ('Pathology', 71),
#  ('Case presentation', 71),
#  ('Measures', 70),
#  ('Nucleotide sequence accession numbers', 70),
#  ('6. Conclusions', 70),
#  ('Immunofluorescence assay', 69),
#  ('Data Availability Statement', 69),
#  ('References', 69),
#  ('Microbiology', 69),
#  ('Disclosure', 68),
#  ('Case Report', 68),
#  ('Model', 67),
#  ('BACKGROUND', 67),
#  ('Objective', 67),
#  ('DATA AVAILABILITY STATEMENT', 67),
#  ('Recommendations', 67),
#  ('SUPPLEMENTAL INFORMATION', 67),
#  ('5. Conclusion', 67),
#  ('Conflicto de intereses', 67),
#  ('Phylogenetic analyses', 66),
#  ('Consent for publication', 66),
#  ('General', 66),
#  ('Figure 1.', 66),
#  ('Pathophysiology', 66),
#  ('Study population ::: Methods', 66),
#  ('11', 65),
#  ('Availability of data and materials', 65),
#  ('Patients and methods', 65),
#  ('Design', 65),
#  ('Quantitative real-time PCR', 65),
#  ('Future perspectives', 65),
#  ('PREVENTION', 65),
#  ('Statistics ::: Materials and Methods', 65),
#  ('Mice ::: Materials and Methods', 65),
#  ('Statistical analysis. ::: MATERIALS AND METHODS', 65),
#  ('5', 64),
#  ('Material and Methods', 64),
#  ('Ethics approval and consent to participate', 64),
#  ('Implications of all the available evidence', 64),
#  ('Sample preparation', 64),
#  ('Clinical Signs', 64),
#  ('Table 3', 64),
#  ('Ethical statement', 62),
#  ('Real-time RT-PCR', 62),
#  ('Participants ::: Methods', 62),
#  ('Transmission electron microscopy', 61),
#  ('Parasites', 61),
#  ('ELISA ::: Materials and Methods', 61),
#  ('Abstract', 60),
#  ('Clinical specimens', 60),
#  ('Ethics Statement ::: Methods', 60),
#  ('Key issues', 60),
#  ('PATHOGENESIS', 60),
#  ('Study design and participants', 59),
#  ('Accession numbers', 59),
#  ('Western Blotting', 59),
#  ('Immunofluorescence microscopy', 59),
#  ('Experimental animals', 59),
#  ('Virology', 59),
#  ('History', 59),
#  ('Flow cytometry ::: Materials and Methods', 59),
#  ('Western blot analysis ::: Materials and Methods', 59),
#  ('Western blot analysis ::: Materials and methods', 59),
#  ('Conflict of Interest ::: Author Contributions', 59),
#  ('SARS', 58),
#  ('Compounds', 58),
#  ('Antiviral activity', 58),
#  ('Case description', 58),
#  ('In Brief', 58),
#  ('DATA AVAILABILITY', 57),
#  ('Conclusion:', 57),
#  ('Research in context', 57),
#  ('7.', 57),
#  ('STAR+METHODS', 57),
#  ('Ethics ::: Methods', 57),
#  ('Western blotting ::: Materials and methods', 57),
#  ('Specimens', 56),
#  ('ACCESSION NUMBERS', 56),
#  ('Disclosures', 55),
#  ('Discussion and Conclusions', 55),
#  ('Flow cytometry analysis', 55),
#  ('Statistical Methods', 55),
#  ('Cell cultures', 55),
#  ('Future Directions', 55),
#  ('Sample collection ::: Materials and methods', 55),
#  ('Results:', 54),
#  ('Figure 3', 54),
#  ('Demographics', 54),
#  ('Clinical Features', 54),
#  ('Construction of plasmids', 54),
#  ('6.', 54),
#  ('Analysis ::: Methods', 54),
#  ('Data ::: Methods', 54),
#  ('Statistics ::: Materials and methods', 54),
#  ('Data availability ::: Methods', 54),
#  ('3', 53),
#  ('Differential diagnosis', 53),
#  ('Supplementary Data', 53),
#  ('Primers', 53),
#  ('Western blot analysis ::: Methods', 53),
#  ('Cells and viruses ::: Materials and Methods', 53),
#  ('Cell culture ::: Materials and Methods', 53),
#  ('Statistical analyses ::: Materials and methods', 53),
#  ('4', 52),
#  ('Western Blot', 52),
#  ('CASE REPORT', 52),
#  ('Antibiotics', 52),
#  ('Data analysis ::: Materials and methods', 52),
#  ('Statistical analyses ::: Materials and Methods', 52),
#  ('Flow cytometry ::: Methods', 52),
#  ('Notes', 51),
#  ('Outlook', 51),
#  ('Experimental', 51),
#  ('DIFFERENTIAL DIAGNOSIS', 51),
#  ('Respiratory Syncytial Virus', 51),
#  ('Primer design', 51),
#  ('Therapy', 51),
#  ('Conclusions and future perspectives', 51),
#  ('Statistical methods ::: Methods', 51),
#  ('Statistical Analyses ::: Materials and Methods', 51),
#  ('10', 50),
#  ('Microscopy', 50),
#  ('Strengths and limitations', 50),
#  ('Challenges', 50),
#  ('Quantitative RT-PCR', 50),
#  ('Immunization', 50),
#  ('Key messages', 50),
#  ('Cytomegalovirus', 50),
#  ('Plasmids ::: Materials and Methods', 50),
#  ('Cells and viruses ::: Materials and methods', 50),
#  ('Conclusions ::: Discussion', 50),
#  ('Neoplasia', 50),
#  ('Overview', 49),
#  ('QUANTIFICATION AND STATISTICAL ANALYSIS', 49),
#  ('Virus Isolation', 49),
#  ('Immunofluorescence assay (IFA)', 49),
#  ('Fungi', 49),
#  ('Western blotting ::: Methods', 49),
#  ('Data source', 48),
#  ('Measles', 48),
#  ('Neutralization assay', 48),
#  ('Flow cytometry ::: Materials and methods', 48),
#  ('Sample Collection', 47),
#  ('Definition', 47),
#  ('Cell culture and transfection', 47),
#  ('Escherichia coli', 47),
#  ('Flow cytometric analysis', 47),
#  ('Cell culture ::: Materials and methods', 47),
#  ('Cells and viruses ::: Methods', 47),
#  ('Cells ::: Materials and Methods', 47),
#  ('Confl icts of interest', 47),
#  ('Availability and requirements', 46),
#  ('9', 46),
#  ('Methods:', 46),
#  ('Implementation', 46),
#  ('List of abbreviations', 46),
#  ('Laboratory methods', 46),
#  ('Consent', 46),
#  ('Virus infection', 46),
#  ('Viruses ::: Materials and Methods', 46),
#  ('Animals ::: Materials and methods', 46),
#  ('Statistical analysis ::: Material and methods', 46),
#  ('Table 4', 46),
#  ('Keywords', 45),
#  ('Interventions', 45),
#  ('Case 2', 45),
#  ('Peptide synthesis', 45),
#  ('Additional information', 45),
#  ('Immunoprecipitation', 45),
#  ('PCR', 45),
#  ('Differential Diagnosis', 45),
#  ('Ribavirin', 45),
#  ('Ethics approval', 44),
#  ('DNA extraction', 44),
#  ('Rabies', 44),
#  ('Experimental Design', 44),
#  ('Specimen collection', 44),
#  ('Safety', 44),
#  ('Sample', 44),
#  ('Rhinovirus', 44),
#  ('Sample collection ::: Methods', 44),
#  ('Result', 43),
#  ('Quantitative PCR', 43),
#  ('Procedure', 43),
#  ('DNA sequencing', 43),
#  ('Clinical presentation', 43),
#  ('Western blotting analysis', 43),
#  ('Mice ::: Methods', 43),
#  ('Phylogenetic analysis ::: Results', 43),
#  ('7. Conclusions', 43),
#  ('7', 42),
#  ('Conclusions:', 42),
#  ('Mass spectrometry', 42),
#  ('Ethical Considerations', 42),
#  ('Recombination analysis', 42),
#  ('Bioinformatics', 42),
#  ('Additional material', 42),
#  ('Antibodies and reagents', 42),
#  ('statistical analysis', 42),
#  ('Dear Editor,', 42),
#  ('Norovirus', 42),
#  ('Miscellaneous', 42),
#  ('CLINICAL FEATURES', 42),
#  ('Viruses ::: Materials and methods', 42),
#  ('Western blotting ::: Materials and Methods', 42),
#  ('Tratamiento', 42),
#  ('6', 41),
#  ('19', 41),
#  ('Gene', 41),
#  ('Disclosure statement', 41),
#  ('Clinical characteristics', 41),
#  ('Interpretation', 41),
#  ('Figure 4', 41),
#  ('Indirect immunofluorescence assay (IFA)', 41),
#  ('Disclosure of Potential Conflicts of Interest', 41),
#  ('Complications', 41),
#  ('Influenza virus', 41),
#  ('Patient characteristics ::: Results', 41),
#  ('Phylogenetic analysis ::: Materials and methods', 41),
#  ('Inclusion and exclusion criteria', 40),
#  ('Sample size', 40),
#  ('Study participants', 40),
#  ('Histopathology and immunohistochemistry', 40),
#  ('Adenoviruses', 40),
#  ('Future perspective', 40),
#  ('Antibodies ::: Materials and Methods', 40),
#  ('15', 39),
#  ('Crystallization', 39),
#  ('Study area', 39),
#  ('Specificity', 39),
#  ('| Statistical analysis', 39),
#  ('Microarray analysis', 39),
#  ('MTT assay', 39),
#  ('Northern blot analysis', 39),
#  ('Questionnaire', 39),
#  ('Study subjects', 39),
#  ('Staphylococcus aureus', 39),
#  ('Patients ::: Methods', 39),
#  ('1', 38),
#  ('Conflict of interests', 38),
#  ('Sequence Analysis', 38),
#  ('Clinical manifestations', 38),
#  ('Perspective', 38),
#  ('Transfection', 38),
#  ('Virus detection', 38),
#  ('Classification', 38),
#  ('Clostridium difficile', 38),
#  ('Pneumonia', 38),
#  ('Conclusions and future directions', 38),
#  ('Corticosteroids', 38),
#  ('Clinical Presentation', 38),
#  ('Data sharing', 37),
#  ('Figure 1', 37),
#  ('Immunocytochemistry', 37),
#  ('Declaration of interest', 37),
#  ('Measurements', 37),
#  ('Cells and Virus', 37),
#  ('Compliance with Ethical Standards', 37),
#  ('Luciferase assay', 37),
#  ('Editorial', 37),
#  ('Glossary', 37),
#  ('Hepatitis B', 37),
#  ('Conclusiones', 37),
#  ('Study selection', 36),
#  ('Acknowledgement', 36),
#  ('Site-directed mutagenesis', 36),
#  ('Data extraction', 36),
#  ('Indirect immunofluorescence assay', 36),
#  ('DiscUssiOn', 36),
#  ('Viral infections', 36),
#  ('Conclusions and Perspectives', 36),
#  ('Necropsy', 36),
#  ('Data collection and analysis', 36),
#  ('Cancer', 36),
#  ('A B S T R A C T', 36),
#  ('Viral Infections', 36),
#  ('FUTURE DIRECTIONS', 36),
#  ('Results and discussions', 36),
#  ('Protozoa', 36),
#  ('Conclusion ::: Discussion', 36),
#  ('Diagnóstico', 36),
#  ('8', 35),
#  ('Introduction:', 35),
#  ('The model', 35),
#  ('Animal experiments', 35),
#  ('Supplementary Materials:', 35),
#  ('Case 1', 35),
#  ('Transmission electron microscopy (TEM)', 35),
#  ('HIV', 35),
#  ('Herpesviruses', 35),
#  ('Statistical Analysis.', 35),
#  ('Reagents and antibodies', 35),
#  ('West Nile Virus', 35),
#  ('Open Access', 35),
#  ('Bioinformatics analysis', 35),
#  ('Prevention and Control', 35),
#  ('Supplementary data', 35),
#  ('Declarations of interest', 35),
#  ('Cell culture ::: Methods', 35),
#  ('Materials ::: Materials and Methods', 35),
#  ('Statistical analysis ::: METHODS', 35),
#  ('13', 34),
#  ('Plasmid Construction', 34),
#  ('Supplementary information', 34),
#  ('Patients and samples', 34),
#  ('Availability of supporting data', 34),
#  ('RNA isolation', 34),
#  ('Cytotoxicity Assay', 34),
#  ('J o u r n a l P r e -p r o o f', 34),
#  ('Competing interest', 34),
#  ('Immunofluorescence staining', 34),
#  ('Infections', 34),
#  ('Surveillance', 34),
#  ('Monoclonal antibodies', 34),
#  ('Anthrax', 34),
#  ('Study population ::: Results', 34),
#  ('Viruses ::: Methods', 34),
#  ('ELISA ::: Materials and methods', 34),
#  ('Physical Examination', 34),
#  ('Bacterial Infections', 34),
#  ('Mycobacterium tuberculosis', 34),
#  ('Age', 33),
#  ('Implications', 33),
#  ('Transparency declaration', 33),
#  ('Other Viruses', 33),
#  ('| D ISCUSS I ON', 33),
#  ('Serum samples', 33),
#  ('Disclosure of potential conflicts of interest', 33),
#  ('Future Perspectives', 33),
#  ('Study limitations', 33),
#  ('| INTRODUCTION', 33),
#  ('Human Immunodeficiency Virus', 33),
#  ('Salmonellosis', 33),
#  ('Outstanding Questions', 33),
#  ('Clinical observations', 33),
#  ('Influenza Virus', 33),
#  ('Summary and conclusions', 33),
#  ('Risk factors', 33),
#  ('CLINICAL MANIFESTATIONS', 33),
#  ('Respiratory syncytial virus', 33),
#  ('ELISA ::: Methods', 33),
#  ('Data Analysis ::: Methods', 33),
#  ('Flow Cytometry ::: Materials and Methods', 33),
#  ('Ethical considerations ::: Methods', 33),
#  ('Ethical approval ::: Materials and Methods', 33),
#  ('Traitement', 33),
#  ('Experimental Procedures', 32),
#  ('qRT-PCR', 32),
#  ('8.', 32),
#  ('CONFLICTS OF INTEREST', 32),
#  ('Primer', 32),
#  ('Leptospirosis', 32),
#  ('Immunofluorescence analysis', 32),
#  ('Infection', 32),
#  ('Plasmid constructs', 32),
#  ('ETIOLOGY', 32),
#  ('Funding source', 32),
#  ('RNA interference', 32),
#  ('Bacterial infections', 32),
#  ('MERS-CoV', 32),
#  ('Antibodies ::: Materials and methods', 32),
#  ('Immunofluorescence ::: Materials and Methods', 32),
#  ('Data analysis ::: Materials and Methods', 32),
#  ('Western Blot Analysis ::: Materials and Methods', 32),
#  ('4. Conclusion', 32),
#  ('■ INTRODUCTION', 32),
#  ('Fig. 5.', 32),
#  ('KEY POINTS', 32),
#  ('Expert opinion', 32),
#  ('ACKNOWLEDGMENT', 31),
#  ('Synthesis', 31),
#  ('Mortality', 31),
#  ('| DISCUSSION', 31),
#  ('Ethical Approval', 31),
#  ('Symptoms', 31),
#  ('Vaccine', 31),
#  ('Outcome measures', 31),
#  ('Conclusions and Future Perspectives', 31),
#  ('RSV', 31),
#  ('Cell Lines', 31),
#  ('Inclusion criteria', 31),
#  ('Laboratory diagnosis', 31),
#  ('Multilingual abstracts', 31),
#  ('Phylogenetic analysis ::: Methods', 31),
#  ('8. Conclusions', 31),
#  ('CLINICAL SIGNS', 31),
#  ('Acknowledgment', 30),
#  ('Name', 30),
#  ('Funding sources', 30),
#  ('Laboratory testing', 30),
#  ('Viral infection', 30),
#  ('| INTRODUC TI ON', 30),
#  ('Asthma', 30),
#  ('Others', 30),
#  ('Culture', 30),
#  ('Immunoblot analysis', 30),
#  ('Dengue', 30),
#  ('DATA AND SOFTWARE AVAILABILITY', 30),
#  ('RNA extraction and cDNA synthesis', 30),
#  ('Polymerase chain reaction', 30),
#  ('Molecular analysis', 30),
#  ('Patients and Methods', 30),
#  ('Hepatitis C', 30),
#  ('Immunohistochemistry ::: Methods', 30),
#  ('Phylogenetic analysis ::: Materials and Methods', 30),
#  ('5. Discussion', 30),
#  ('Ethical approval ::: Methods', 30),
#  ('Epidemiología', 30),
#  ('18', 29),
#  ('21', 29),
#  ('Analyses', 29),
#  ('Strengths and limitations of this study', 29),
#  ('Key points', 29),
#  ('Control', 29),
#  ('Simulations', 29),
#  ("Authors' Contributions", 29),
#  ('Exclusion criteria', 29),
#  ('RNA Extraction', 29),
#  ('Sequence and phylogenetic analysis', 29),
#  ('Imaging', 29),
#  ('Structure', 29),
#  ('Bacteriology', 29),
#  ('Instruments', 29),
#  ('Virus strains', 29),
#  ('Indirect immunofluorescence', 29),
#  ('10.', 29),
#  ('9.', 29),
#  ('Toxoplasmosis', 29),
#  ('Materials ::: Materials and methods', 29),
#  ('Subjects ::: Methods', 29),
#  ('Plasmids ::: Methods', 29),
#  ('Study design ::: Materials and methods', 29),
#  ('Immunoblotting ::: Materials and Methods', 29),
#  ('Disclosure of interest', 29),
#  ('Western blot ::: Materials and methods', 29),
#  ('Ethics statement ::: MATERIALS AND METHODS', 29),
#  ('I N T R O D U C T I O N', 29),
#  ('MANAGEMENT', 29),
#  ('16', 28),
#  ('12', 28),
#  ('22', 28),
#  ('Sensitivity Analysis', 28),
#  ('Case definition', 28),
#  ('SARS-CoV', 28),
#  ('Cell viability', 28),
#  ('Fluorescence microscopy', 28),
#  ('Clinical data', 28),
#  ('Peptides', 28),
#  ('Statistical', 28),
#  ('Conclusions and Future Directions', 28),
#  ('CLINICAL PRESENTATION', 28),
#  ('Antiviral assays', 28),
#  ('Salmonella', 28),
#  ('ELISPOT assay', 28),
#  ('Cats', 28),
#  ('Setting ::: Methods', 28),
#  ('Cells ::: Materials and methods', 28),
#  ('Data sources ::: Methods', 28),
#  ('1. Background', 28),
#  ('Cell Culture ::: Materials and Methods', 28),
#  ('2. Materials and Methods', 28),
#  ('Manifestaciones clínicas', 28),
#  ('Chemicals and reagents', 27),
#  ('Statistical analysis.', 27),
#  ('3.2.', 27),
#  ('Patient and public involvement', 27),
#  ('Intervention', 27),
#  ('Author contribution', 27),
#  ('AUTHOR CONTRiBUTiONS', 27),
#  ('Coronaviridae', 27),
#  ('Hematology', 27),
#  ('Viruses and Cells', 27),
#  ('Immunohistochemistry (IHC)', 27),
#  ('Immunofluorescence Microscopy', 27),
#  ('Influenza Viruses', 27),
#  ('Western blot assay', 27),
#  ('Immunization of mice', 27),
#  ('Plaque reduction assay', 27),
#  ('Infectious Diseases', 27),
#  ('Replication', 27),
#  ('Immunity', 27),
#  ('Retroviruses', 27),
#  ('Trauma', 27),
#  ('Statistical analysis ::: Patients and methods', 27),
#  ('Data Collection ::: Methods', 27),
#  ('Immunohistochemistry ::: Materials and Methods', 27),
#  ('Plasmids ::: Materials and methods', 27),
#  ('Experimental design ::: Materials and methods', 27),
#  ('Strengths and limitations ::: Discussion', 27),
#  ('Protein purification', 26),
#  ('RT-qPCR', 26),
#  ('Co-immunoprecipitation', 26),
#  ('Molecular docking', 26),
#  ('Clinical Findings', 26),
#  ('Western blots', 26),
#  ('Viruses and cell lines', 26),
#  ('Flaviviruses', 26),
#  ('Cytotoxicity', 26),
#  ('Plasmid constructions', 26),
#  ('Virus neutralization assay', 26),
#  ('Luciferase reporter assay', 26),
#  ('Cytotoxicity assays', 26),
#  ('Genotyping', 26),
#  ('Inflammation', 26),
#  ('Herpes Simplex Virus', 26),
#  ('Antivirals', 26),
#  ('Case', 26),
#  ('SDS-PAGE and Western blot analysis', 26),
#  ('Key Points', 26),
#  ('Conclusions and outlook', 26),
#  ('Human immunodeficiency virus', 26),
#  ('Clinical Manifestations', 26),
#  ('Search strategy ::: Methods', 26),
#  ('Nucleic acid extraction ::: Methods', 26),
#  ('Statistical analysis ::: Material and Methods', 26),
#  ('Nucleotide sequence accession number. ::: GENOME ANNOUNCEMENT', 26),
#  ('Cells and viruses. ::: MATERIALS AND METHODS', 26),
#  ('Authors’ Contributions', 26),
#  ('Discusión', 26),
#  ('PROGNOSIS', 26),
#  ('Severe Acute Respiratory Syndrome', 26),
#  ('17', 25),
#  ('Discussion and Conclusion', 25),
#  ('2', 25),
#  ('Bioinformatic analysis', 25),
#  ('Clinical findings', 25),
#  ('Drugs', 25),
#  ('Reverse transcription', 25),
#  ('Ferrets', 25),
#  ('Paramyxoviridae', 25),
#  ('Sensitivity', 25),
#  ('Bacterial strains', 25),
#  ('Study setting', 25),
#  ('Herpesviridae', 25),
#  ('Seasonality', 25),
#  ('Cytokines', 25),
#  ('Interferons', 25),
#  ('Other viruses', 25),
#  ('Risk Factors', 25),
#  ('PATHOPHYSIOLOGY', 25),
#  ('Enteroviruses', 25),
#  ('Financial support', 25),
#  ('NMR spectroscopy', 25),
#  ('Study Design ::: Methods', 25),
#  ('Statistical Analyses ::: Methods', 25),
#  ('Mice ::: Materials and methods', 25),
#  ('3. Results and Discussion', 25),
#  ('Ethics statement. ::: MATERIALS AND METHODS', 25),
#  ('PATHOLOGY', 25),
#  ('Related work', 24),
#  ('Image analysis', 24),
#  ('Study design and patients', 24),
#  ('Main text', 24),
#  ('In vitro transcription', 24),
#  ('Eligibility criteria', 24),
#  ('Species', 24),
#  ('13.', 24),
#  ('Demographic characteristics', 24),
#  ('Immunostaining', 24),
#  ('Sequence data', 24),
#  ('CONTACT FOR REAGENT AND RESOURCE SHARING', 24),
#  ('Nucleotide sequence accession number', 24),
#  ('Cell lines and viruses', 24),
#  ('Sequencing and phylogenetic analysis', 24),
#  ('Infection control', 24),
#  ('Confocal Microscopy', 24),
#  ('Animals and experimental design', 24),
#  ('Plaque Assay', 24),
#  ('Population', 24),
#  ('Viral RNA extraction', 24),
#  ('SUMMARY AND CONCLUSIONS', 24),
#  ('Hantavirus', 24),
#  ('Helicobacter pylori', 24),
#  ('Dogs', 24),
#  ('Genetics', 24),
#  ('Virus preparation', 24),
#  ('Applications', 24),
#  ('Proteins', 24),
#  ('Incidence', 24),
#  ('Listeria monocytogenes', 24),
#  ('Study population ::: Materials and methods', 24),
#  ('Western blot ::: Methods', 24),
#  ('Electron microscopy ::: Materials and Methods', 24),
#  ('Cells and Viruses ::: Materials and Methods', 24),
#  ('6. Conclusion', 24),
#  ('2.9. Statistical Analysis ::: 2. Materials and Methods', 24),
#  ('Nutrition', 24),
#  ('Transparency document', 24),
#  ('Author Manuscript', 24),
#  ('Discussion:', 23),
#  ('Conflict of Interests', 23),
#  ('Funding information', 23),
#  ('Transmission Electron Microscopy', 23),
#  ('Outcome', 23),
#  ('Data Sources', 23),
#  ('Reference', 23),
#  ('Subcellular fractionation', 23),
#  ('Variables', 23),
#  ('Immunofluorescence Assay', 23),
#  ('Indirect ELISA', 23),
#  ('Human metapneumovirus', 23),
#  ('Influenza viruses', 23),
#  ('Neutrophils', 23),
#  ('Primer and probe design', 23),
#  ('Patient Characteristics', 23),
#  ('RNA Viruses', 23),
#  ('Intracellular cytokine staining', 23),
#  ('Animal studies', 23),
#  ('Smallpox', 23),
#  ('Astrovirus', 23),
#  ('Materials and reagents', 23),
#  ('Housing', 23),
#  ('VIRUSES', 23),
#  ('Interferon', 23),
#  ('Radiology', 23),
#  ('Polymerase chain reaction (PCR)', 23),
#  ('Cells ::: Methods', 23),
#  ('Samples ::: Methods', 23),
#  ('Definitions ::: Methods', 23),
#  ('Data Analysis ::: Materials and Methods', 23),
#  ('Electron microscopy ::: Materials and methods', 23),
#  ('Reagents ::: Materials and methods', 23),
#  ('Virus titration ::: Materials and methods', 23),
#  ('Funding statement', 23),
#  ('Sequence analysis ::: Materials and methods', 23),
#  ('Reporting summary ::: Methods', 23),
#  ('Feline Infectious Peritonitis', 23),
#  ('■ CONCLUSIONS', 23),
#  ('Brucellosis', 23),
#  ('D I S C U S S I O N', 23),
#  ("Déclaration d'intérêts", 23),
#  ('27', 22),
#  ('Parameter', 22),
#  ('Animal models', 22),
#  ('MATERIAL AND METHODS', 22),
#  ('Communication', 22),
#  ('Antibody detection', 22),
#  ('Sample processing', 22),
#  ('Plant material', 22),
#  ('Flaviviridae', 22),
#  ('Limitations of the study', 22),
#  ('Probiotics', 22),
#  ('Laboratory Testing', 22),
#  ('Methods and Findings', 22),
#  ('Group', 22),
#  ('Enzyme-linked immunosorbent assay', 22),
#  ('Diagnostics', 22),
#  ('GenBank accession numbers', 22),
#  ('Clinical evaluation', 22),
#  ('Pigs', 22),
#  ('METHOD DETAILS', 22),
#  ('Liposomes', 22),
#  ('Plaque assays', 22),
#  ('Financial & competing interests disclosure', 22),
#  ('12.', 22),
#  ('Prevalence', 22),
#  ('Streptococcus pneumoniae', 22),
#  ('Preparation', 22),
#  ('KEYWORDS', 22),
#  ('Viruses and cells ::: Methods', 22),
#  ('Accession numbers ::: Materials and Methods', 22),
#  ('Virus ::: Methods', 22),
#  ('Western Blotting ::: Materials and Methods', 22),
#  ('Reagents ::: Materials and Methods', 22),
#  ('Histopathology ::: Materials and Methods', 22),
#  ('Sample collection ::: Materials and Methods', 22),
#  ('RNA extraction ::: Materials and methods', 22),
#  ('REVIEWS', 22),
#  ('Future prospects', 22),
#  ('Conclusión', 22),
#  ('FIG. 2.', 22),
#  ('Resultados', 22),
#  ('Surgery', 22),
#  ('Mathematical model', 21),
#  ('Supplementary', 21),
#  ('As shown in', 21),
#  ('Pharmacokinetics', 21),
#  ('Histological analysis', 21),
#  ('Laboratory findings', 21),
#  ('Monitoring', 21),
#  ('Experimental procedures', 21),
#  ('Structure determination', 21),
#  ('Virus Titration', 21),
#  ('Accession Numbers', 21),
#  ('Autophagy', 21),
#  ('Study Limitations', 21),
#  ('Quantitative real-time RT-PCR', 21),
#  ('Study design and population', 21),
#  ('Sample collection and processing', 21),
#  ('Macrophages', 21),
#  ('CONCLUSIONS AND PERSPECTIVES', 21),
#  ('(DOC)', 21),
#  ('Luciferase assays', 21),
#  ('Cell proliferation assay', 21),
#  ('Genome sequencing', 21),
#  ('RNA extraction and RT-PCR', 21),
#  ('Purpose', 21),
#  ('Data analyses', 21),
#  ('Immunizations', 21),
#  ('Histopathological examination', 21),
#  ('Patients and specimens', 21),
#  ('Future Prospects', 21),
#  ('Viral', 21),
#  ('DNA Viruses', 21),
#  ('Laboratory Diagnosis', 21),
#  ('Toxicity', 21),
#  ('Rhinoviruses', 21),
#  ('Executive summary', 21),
#  ('Sepsis', 21),
#  ('Cholera', 21),
#  ('Cryptosporidiosis', 21),
#  ('Measures ::: Methods', 21),
#  ('Phylogenetic Analysis ::: Materials and Methods', 21),
#  ('Clinical samples ::: Methods', 21),
#  ('Sensitivity analysis ::: Results', 21),
#  ('Sampling ::: Methods', 21),
#  ('Reagents ::: Methods', 21),
#  ('3. Conclusions', 21),
#  ('Authors’ information', 21),
#  ('Immunofluorescence ::: Materials and methods', 21),
#  ('Accession number(s). ::: MATERIALS AND METHODS', 21),
#  ('Etiología', 21),
#  ('Bibliografía', 21),
#  ('Table 6', 21),
#  ('Appendix A. Supplementary data', 21),
#  ('20', 20),
#  ('Numerical simulations', 20),
#  ('Clinical outcomes', 20),
#  ('Limitation', 20),
#  ('Follow-up', 20),
#  ('Keywords:', 20),
#  ('Patient population', 20),
#  ('Contributions', 20),
#  ('Circular dichroism spectroscopy', 20),
#  ('Picornaviridae', 20),
#  ('CO N FLI C T O F I NTE R E S T', 20),
#  ('Environment', 20),
#  ('Descriptive statistics', 20),
#  ('DNA vaccines', 20),
#  ('Survey', 20),
#  ('Microarray', 20),
#  ('Adjuvants', 20),
#  ('Morphology', 20),
#  ('Radiography', 20),
#  ('Experimental infection', 20),
#  ('Advantages', 20),
#  ('SDS-PAGE', 20),
#  ('Histopathology and Immunohistochemistry', 20),
#  ('Gene expression analysis', 20),
#  ('Simulation results', 20),
#  ('Cell and virus', 20),
#  ('Epstein-Barr Virus', 20),
#  ('Virus identification', 20),
#  ('Study design and setting', 20),
#  ('LIMITATIONS', 20),
#  ...]

# %%
# Out:
# 52097

# %%
class Paper:
    def __init__(self, )
