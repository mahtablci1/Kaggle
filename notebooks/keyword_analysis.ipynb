# %% [markdown]
# # Abstract
# The objective of this notebook will be to perform keyword analysis on the papers for Covid-19 risk factors.

# %%
import re
import glob
import json
from os import path
import pandas as np
import pandas as pd
from datetime import datetime

# %%
papers_df = pd.read_csv('../output/papers_df.csv', 
                        index_col=0, 
                        keep_default_na=False,
                       parse_dates=['publish_time'])

# %%
transmission_keywords = ['transmi', 'sneez', 'contact trac', 'reproduc', 'environ']

# %%
smoke_keywords = ['smok']

# %%
covid_keywords = ['COVID-19', 'HCoV-19', 'CORD-19' ,'2019-nCoV', 'Wuhan coronavirus', 'SARS-CoV-2', 'SARS-COV-2']
covid_keywords = [word.lower() for word in covid_keywords]

# %%
design_list = [ 'retrospective cohort', 'cross-sectional case-control','prevalence survey', 
               'systematic review , meta-analysis','matched case-control',
               'medical records review', 'observational case series','time series analysis',
               'pseudo-randomized controlled trials' ,'randomized controlled trials']

# %%
# covid_papers = papers_df[papers_df['text_body'].apply(lambda x : 
#                                                 any(key in x.lower() for
#                                                     key in covid_keywords)
#                                                )]

# %%
def tokenize(text):
    text = text.lower().strip()
    if len(text) == 0:
        return ''
    if text[-1] == 's':
        text = text[:-1]
    return text

# %% [markdown]
# ## Creating a list of paper dictionaries

# %%
json_files = glob.glob(f'../data/**/*.json', recursive=True)

# %%
paper_dicts = []
for file in json_files:
    name = path.basename(file)
    with open(file) as f:
        data = json.load(f)
    paper_obj = {'id':name,
                 'data':data}
    paper_dicts.append(paper_obj)

# %% [markdown]
# ### Filtering for covid related papers

# %%
covid_papers = []
for paper in papers:
    body = paper['data']['body_text']
    for paragraph in body:
        text = paragraph['text']
        match = any(key.lower() in text.lower()
                   for key in covid_keywords)
        if match:
            covid_papers.append(paper)
            break

# %%
len(covid_papers)
# Out:
# 2160

# %% [markdown]
# ## Analysis for different sections in the papers

# %%
sections = {}
for paper in covid_papers:
    body = paper['data']['body_text']
    paper_sections = set()
    for paragraph in body:
        if 'section' in paragraph:
            paper_sections.add(paragraph['section'])
    
    for section in paper_sections:
        section = tokenize(section)
        if section in sections:
            sections[section] += 1
        else:
            sections[section] = 1

# %%
sorted(sections.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('introduction', 883),
#  ('', 821),
#  ('discussion', 699),
#  ('conclusion', 372),
#  ('result', 331),
#  ('statistical analysi', 195),
#  ('(which was not peer-reviewed)', 169),
#  ('method', 168),
#  ('declaration of competing interest', 118),
#  ('declaration of interest', 88),
#  ('data collection', 82),
#  ('funding', 59),
#  ('background', 58),
#  ('results and discussion', 51),
#  ('acknowledgment', 50),
#  ('contributor', 50),
#  ('role of the funding source', 50),
#  ('added value of this study', 42),
#  ('data', 41),
#  ('conflicts of interest', 41),
#  ('conflict of interest', 39),
#  ('study design and participant', 39),
#  ('implications of all the available evidence', 38),
#  ('data source', 37),
#  ('data sharing', 36),
#  ('materials and method', 36),
#  ('research in context', 36),
#  ('11', 35),
#  ('acknowledgement', 35),
#  ('author contribution', 31),
#  ('patient', 31),
#  ('5', 30),
#  ('model', 28),
#  ('j o u r n a l p r e -p r o o f', 27),
#  ('ethical approval', 25),
#  ('limitation', 25),
#  ('15', 24),
#  ('data analysi', 23),
#  ('summary', 23),
#  ('outcome', 22),
#  ('9', 21),
#  ('discussion and conclusion', 21),
#  ('methods:', 21),
#  ('10', 20),
#  ('7', 20),
#  ('conflicts of interest:', 19),
#  ('4', 19),
#  ('dear editor,', 19),
#  ('6', 18),
#  ('procedure', 18),
#  ('study design', 18),
#  ('treatment', 18),
#  ('data availability', 18),
#  ('results:', 17),
#  ('introduction:', 17),
#  ('discussion:', 17),
#  ('16', 17),
#  ('i. introduction', 16),
#  ('ethics approval and consent to participate', 16),
#  ('definition', 16),
#  ('19', 16),
#  ('18', 16),
#  ('17', 16),
#  ('8', 16),
#  ('abstract', 16),
#  ('contents lists available at sciencedirect', 16),
#  ('statistic', 15),
#  ('consent for publication', 14),
#  ('availability of data and material', 14),
#  ('13', 14),
#  ('funding source', 14),
#  ('clinical manifestation', 14),
#  ('study design and patient', 13),
#  ('supplementary material', 13),
#  ('study population', 13),
#  ("authors' contribution", 13),
#  ('ethic', 13),
#  ('participant', 13),
#  ('case report', 13),
#  ('phylogenetic analysi', 12),
#  ('ethics statement', 12),
#  ('reference', 12),
#  ('sensitivity analysi', 12),
#  ('interpretation', 12),
#  ('cc-by-nc-nd 4.0 international license', 12),
#  ('ethical consideration', 12),
#  ('1. introduction', 12),
#  ('ethical statement', 11),
#  ('finding', 11),
#  ('conclusion:', 11),
#  ('prevention', 11),
#  ('article in pres', 11),
#  ('figure', 10),
#  ('figure 2', 10),
#  ('ethics approval', 10),
#  ('statistical analyse', 10),
#  ('1', 10),
#  ('20', 10),
#  ('sars-cov', 10),
#  ('figure 3', 9),
#  ('disclaimer', 9),
#  ('sample collection', 9),
#  ('competing interest', 9),
#  ('incubation period', 9),
#  ('12', 9),
#  ('clinical feature', 9),
#  ('declaration', 9),
#  ('conflict of interest statement', 9),
#  ('case 2', 9),
#  ('editorial', 9),
#  ('parameter', 8),
#  ('disclosure statement', 8),
#  ('123', 8),
#  ('figure legend', 8),
#  ('epidemiological characteristic', 8),
#  ('22', 8),
#  ('covid-19', 8),
#  ('epidemiological data', 8),
#  ('vaccine', 8),
#  ('2.', 8),
#  ('patient and public involvement', 8),
#  ('diagnosi', 8),
#  ('data and code availability', 7),
#  ('material and method', 7),
#  ('parameter estimation', 7),
#  ('inclusion and exclusion criteria', 7),
#  ('literature search', 7),
#  ('27', 7),
#  ('main text', 7),
#  ('eligibility criteria', 7),
#  ('abstract:', 7),
#  ('demographic and clinical characteristic', 7),
#  ('laboratory examination', 7),
#  ('3', 7),
#  ('molecular docking', 7),
#  ('statistical model', 7),
#  ('statistical method', 7),
#  ('a b s t r a c t', 7),
#  ('epidemiology', 7),
#  ('data availability statement', 6),
#  ('objective', 6),
#  ('2', 6),
#  ('case definition', 6),
#  ('clinical characteristic', 6),
#  ('172', 6),
#  ('study selection', 6),
#  ('table', 6),
#  ('76', 6),
#  ('21', 6),
#  ('funding statement', 6),
#  ('supplementary information', 6),
#  ('data description', 6),
#  ('methodology', 6),
#  ('concluding remark', 6),
#  ('116', 6),
#  ('case 1', 6),
#  ('epidemiological incidence case', 6),
#  ('statistical analysis ::: method', 6),
#  ('letter to the editor', 6),
#  ('table 1', 6),
#  ('conclusions and future direction', 5),
#  ('incubation period distribution', 5),
#  ('france', 5),
#  ('south korea', 5),
#  ('the model', 5),
#  ('data extraction', 5),
#  ('conflict of interest:', 5),
#  ('30', 5),
#  ('143', 5),
#  ('26', 5),
#  ('54', 5),
#  ('67', 5),
#  ('rna extraction', 5),
#  ('model validation', 5),
#  ('125', 5),
#  ('256', 5),
#  ('158', 5),
#  ('135', 5),
#  ('laboratory testing', 5),
#  ('62', 5),
#  ('quality assessment', 5),
#  ('perspective', 5),
#  ('238', 5),
#  ('figure 4', 5),
#  ('search strategy', 5),
#  ('122', 5),
#  ('3.', 5),
#  ('132', 5),
#  ('sars-cov-2', 5),
#  ('4.', 5),
#  ('164', 5),
#  ('symptom', 5),
#  ('strengths and limitation', 5),
#  ('confirmed case', 5),
#  ('authors orcid', 5),
#  ('highlight', 5),
#  ('4. discussion', 5),
#  ('disclosure of interest', 5),
#  ('dear editor', 5),
#  ('introducción', 5),
#  ('related work', 4),
#  ('model description', 4),
#  ('sensitivity analyse', 4),
#  ('discussions and conclusion', 4),
#  ('mathematical model', 4),
#  ('disclosure', 4),
#  ('111', 4),
#  ('laboratory test', 4),
#  ('iran', 4),
#  ('united state', 4),
#  ('subject', 4),
#  ('clinical outcome', 4),
#  ('clinical classification', 4),
#  ('conclusions:', 4),
#  ('summary background', 4),
#  ('the data', 4),
#  ('laboratory finding', 4),
#  ('28', 4),
#  ('24', 4),
#  ('31', 4),
#  ('declaration of interest statement', 4),
#  ('106', 4),
#  ('119', 4),
#  ('definition of outbreak control', 4),
#  ('model structure', 4),
#  ('transmission scenario', 4),
#  ('297', 4),
#  ('funding:', 4),
#  ('94', 4),
#  ('120', 4),
#  ('99', 4),
#  ('clinical finding', 4),
#  ('real-time reverse transcription polymerase chain reaction assay for sars-cov-2',
#   4),
#  ('137', 4),
#  ('81', 4),
#  ('96', 4),
#  ('as shown in', 4),
#  ('50', 4),
#  ('23', 4),
#  ('demographic characteristic', 4),
#  ('intervention', 4),
#  ('2.2', 4),
#  ('211', 4),
#  ('105', 4),
#  ('susceptible population', 4),
#  ('route of transmission', 4),
#  ('154', 4),
#  ('55', 4),
#  ('127', 4),
#  ('social distancing', 4),
#  ('232', 4),
#  ('effect of screening on detection', 4),
#  ('1.introduction', 4),
#  ('online content', 4),
#  ('conclusion and future prospect', 4),
#  ('coronaviruse', 4),
#  ('short-term forecast', 4),
#  ('review', 4),
#  ('differential diagnosi', 4),
#  ("author's contribution", 4),
#  ('conclusions and future perspective', 4),
#  ('star+method', 4),
#  ('strain', 4),
#  ('ideas and opinion', 4),
#  ('5.', 4),
#  ('virology', 4),
#  ('fig. 2.', 4),
#  ('data, code and material', 4),
#  ('limitations of this study', 3),
#  ('what this study add', 3),
#  ('115', 3),
#  ('quantification and statistical analysi', 3),
#  ('iv. discussion', 3),
#  ('iii. results and discussion', 3),
#  ('ii. model', 3),
#  ('metapopulation model', 3),
#  ('research in context evidence before this study', 3),
#  ('170', 3),
#  ('cell-cell interaction analysi', 3),
#  ('meta-analysi', 3),
#  ('case', 3),
#  ('a b', 3),
#  ('153', 3),
#  ('presenting characteristic', 3),
#  ('figure 1', 3),
#  ('evidence before this study', 3),
#  ('statistical modelling', 3),
#  ('functional enrichment analysi', 3),
#  ('demographic', 3),
#  ('laboratory confirmation', 3),
#  ('58', 3),
#  ('33', 3),
#  ('36', 3),
#  ('25', 3),
#  ('80', 3),
#  ('152', 3),
#  ('181', 3),
#  ('14', 3),
#  ('cell culture', 3),
#  ('neonatal outcome', 3),
#  ('dataset', 3),
#  ('311', 3),
#  ('113', 3),
#  ('introduction purpose and research question', 3),
#  ('data items and data abstraction', 3),
#  ('protocol', 3),
#  ('study selection proces', 3),
#  ('synthesi', 3),
#  ('risk of bias appraisal', 3),
#  ('japan', 3),
#  ('italy', 3),
#  ('1.', 3),
#  ('acknowledgements:', 3),
#  ('original article', 3),
#  ('275', 3),
#  ('222', 3),
#  ('89', 3),
#  ('245', 3),
#  ('special population', 3),
#  ('characteristics of included studie', 3),
#  ('figures and table', 3),
#  ('147', 3),
#  ('107', 3),
#  ('156', 3),
#  ('217', 3),
#  ('112', 3),
#  ('368', 3),
#  ('261', 3),
#  ('151', 3),
#  ('prediction', 3),
#  ('follow-up', 3),
#  ('simulation', 3),
#  ('83', 3),
#  ('ct scan', 3),
#  ('supplemental material', 3),
#  ('iii. result', 3),
#  ('informed consent', 3),
#  ('culture', 3),
#  ('setting', 3),
#  ('keywords:', 3),
#  ('treatment and complication', 3),
#  ('212', 3),
#  ('personal protective equipment (ppe)', 3),
#  ('code availability', 3),
#  ('estimation', 3),
#  ('main text:', 3),
#  ('transmission model', 3),
#  ('192', 3),
#  ('reverse transcription', 3),
#  ('121', 3),
#  ('antibody measurement', 3),
#  ('china', 3),
#  ('255', 3),
#  ('91', 3),
#  ('covid-19.', 3),
#  ('229', 3),
#  ('100', 3),
#  ('comorbiditie', 3),
#  ('53', 3),
#  ('transmission cluster', 3),
#  ('cluster a', 3),
#  ('252', 3),
#  ('search strategy and selection criteria', 3),
#  ('methods and material', 3),
#  ('296', 3),
#  ('transmission of the viru', 3),
#  ('transmission dynamic', 3),
#  ('129', 3),
#  ('243', 3),
#  ('baseline characteristic', 3),
#  ('europe', 3),
#  ('model simulation', 3),
#  ('acknowledgments:', 3),
#  ('real-time reverse-transcription pcr', 3),
#  ('specimen collection', 3),
#  ('epidemic parameter', 3),
#  ('2019-ncov', 3),
#  ('main', 3),
#  ('death', 3),
#  ('authors contribution', 3),
#  ('general information', 3),
#  ('clinical symptom', 3),
#  ('note', 3),
#  ('low lym% is a predictor of prognosis in covid-19 patient', 3),
#  ('laboratory result', 3),
#  ('funding support', 3),
#  ('simulation of travellers at each stage of infection with 2019-ncov', 3),
#  ('antiviral therapy', 3),
#  ('public health response', 3),
#  ('prevention and control', 3),
#  ('action plan and discussion', 3),
#  ('travellers from wuhan with confirmed 2019 novel coronavirus infection, reported symptom onset data and reported travel history',
#   3),
#  ('general treatment', 3),
#  ('molecular assays for respiratory pathogen', 3),
#  ('diagnostic algorithm', 3),
#  ('experimental design, materials, and method', 3),
#  ('data source location university campus bio-medico of rome data accessibility',
#   3),
#  ('how are health agencies reacting?', 3),
#  ('how are infected people being treated?', 3),
#  ('why is the world health organization (who) so concerned about it?', 3),
#  ('compliance with ethical standard', 3),
#  ('genome sequence analysi', 3),
#  ('follow-up of contact', 3),
#  ('therapeutic', 3),
#  ('open acces', 3),
#  ('summary and perspective', 3),
#  ('laboratory diagnosi', 3),
#  ('diagnosis of covid-19', 3),
#  ('transmission', 3),
#  ('funding and support', 3),
#  ('3. result', 3),
#  ('clinical presentation', 3),
#  ('risk factor', 3),
#  ('reporting summary ::: method', 3),
#  ('lancet infect dis 2020', 3),
#  ('ct protocol', 3),
#  ('further perspective', 3),
#  ('chloroquine and hydroxychloroquine', 3),
#  ('recommendation', 3),
#  ('provenance and peer review', 3),
#  ('diagnosis and treatment', 3),
#  ('conflicto de interese', 3),
#  ('declarations of interest', 3),
#  ('history', 3),
#  ('inactivation of coronaviruses by biocidal agents in carrier test', 3),
#  ('time-dependent dynamic model', 3),
#  ('parameter estimation proces', 3),
#  ('process that starts with person a being infected', 3),
#  ('model calibration', 3),
#  ('10-days ahead forecast', 3),
#  ('15-days ahead forecast', 3),
#  ('5-days ahead forecast', 3),
#  ('epidemiological modeling', 3),
#  ('methods and result', 3),
#  ('data sharing statement', 2),
#  ('entity category associated genes involved in generalized interaction network',
#   2),
#  ('corpus and dictionary organization', 2),
#  ('categories of entity and their labels-human conclusion and enriched pathway',
#   2),
#  ('identification of all entities (csse) correctly related to the subject "coronavirus"',
#   2),
#  ('identification of genes precisely related to the subject "coronavirus"', 2),
#  ('construction of the data interface', 2),
#  ('203', 2),
#  ('flow cytometry', 2),
#  ('lead contact and materials availability', 2),
#  ('transmission electron microscopy', 2),
#  ('sequence identity analysi', 2),
#  ('sars-cov protease inhibitor dataset', 2),
#  ('binding affinity training set', 2),
#  ('disscussion', 2),
#  ('sar', 2),
#  ('model and method', 2),
#  ('71', 2),
#  ('sequence data collection', 2),
#  ('role of the funder/sponsor', 2),
#  ('conflict of interest: none', 2),
#  ('germany', 2),
#  ('keyword', 2),
#  ('implication of all the available evidence', 2),
#  ('settings and participant', 2),
#  ('molecular dynamic simulation', 2),
#  ('scrna-seq data alignment and sample aggregating', 2),
#  ('differential analysis for cluster', 2),
#  ('gene functional annotation', 2),
#  ('dimensionality reduction and clustering', 2),
#  ('retrieval of studie', 2),
#  ('findings:', 2),
#  ('225', 2),
#  ('statistics analysi', 2),
#  ('supplementary', 2),
#  ('introduction 32', 2),
#  ('elisa', 2),
#  ('demographic, epidemiological and clinical characteristic', 2),
#  ('method:', 2),
#  ('variable', 2),
#  ('epidemiological parameter', 2),
#  ('laboratory procedure', 2),
#  ('building the drug-target network', 2),
#  ('building the human protein-protein interactome', 2),
#  ('gene set enrichment analysi', 2),
#  ('hcov-host interactome network', 2),
#  ('network proximity measure', 2),
#  ('building the virus-host interactome', 2),
#  ('discovery of repurposable drugs for hcov', 2),
#  ('network-based drug repurposing for hcov', 2),
#  ('theoretical framework', 2),
#  ('the resampling method', 2),
#  ('basic characteristic', 2),
#  ('role of the funder/sponsor:', 2),
#  ('34', 2),
#  ('daily new case', 2),
#  ('29', 2),
#  ('32', 2),
#  ('code and data availability', 2),
#  ('cell type identification', 2),
#  ('cell type identification in 13 human tissue', 2),
#  ('cell clustering, dimensional reduction and visualization', 2),
#  ('data processing, quality control and normalization', 2),
#  ('expression atlas of ace2, ssrna viral receptors and other membrane proteins in 13 human tissue',
#   2),
#  ('reporting', 2),
#  ('funding/support', 2),
#  ('clinical sample', 2),
#  ('77', 2),
#  ('introduction 1', 2),
#  ('western blot', 2),
#  ('study outcome', 2),
#  ('maternal outcome', 2),
#  ('estimation of model parameter', 2),
#  ('179', 2),
#  ('250', 2),
#  ('178', 2),
#  ('competing interest statement', 2),
#  ('statistical inference', 2),
#  ('estimation of the delay distribution', 2),
#  ('molecular dynamics simulation', 2),
#  ('abstract background', 2),
#  ('284', 2),
#  ('236', 2),
#  ('66', 2),
#  ('funding information', 2),
#  ('study definition', 2),
#  ('timeline (from the point of official approval):', 2),
#  ('quality appraisal result', 2),
#  ('preliminary knowledge translation plan:', 2),
#  ('data items and data abstraction proces', 2),
#  ('figures caption', 2),
#  ('patients and sample', 2),
#  ('sars-cov-2 testing', 2),
#  ('248', 2),
#  ('35', 2),
#  ('robustness check', 2),
#  ('infection prevention', 2),
#  ('220', 2),
#  ('90', 2),
#  ('176', 2),
#  ('37', 2),
#  ('strengths and limitations of this study', 2),
#  ('laboratory confirmation and treatment', 2),
#  ('v. conclusion', 2),
#  ('references:', 2),
#  ('286', 2),
#  ('38', 2),
#  ('302', 2),
#  ('materials & method', 2),
#  ('control', 2),
#  ('45', 2),
#  ('role of funding source', 2),
#  ('effective distance', 2),
#  ('invasive mechanical ventilation', 2),
#  ('197', 2),
#  ('318', 2),
#  ('241', 2),
#  ('374', 2),
#  ('clinical data collection', 2),
#  ('financial disclosure', 2),
#  ('139', 2),
#  ('173', 2),
#  ('protein expression and purification', 2),
#  ('baseline data collection', 2),
#  ('screening', 2),
#  ('data extraction and analysi', 2),
#  ('epidemiological and clinical characteristic', 2),
#  ('flow cytometry data analysi', 2),
#  ('radiologic and laboratory parameters in mild and severe or critical patient',
#   2),
#  ('individual-level data on cases outside mainland china', 2),
#  ('data on aggregate cases and deaths in mainland china', 2),
#  ('data on infection in repatriated international wuhan resident', 2),
#  ('data on cases and deaths on the diamond princess cruise ship', 2),
#  ('individual-level data on early deaths from mainland china', 2),
#  ('appendice', 2),
#  ('imaging evaluation', 2),
#  ('ii. method', 2),
#  ('hydroxychloroquine dosage', 2),
#  ('effect of hydroxychloroquine on viral load', 2),
#  ('statistical analysis.', 2),
#  ('correspondence', 2),
#  ('202', 2),
#  ('103', 2),
#  ('47', 2),
#  ('65', 2),
#  ('data collection and definition', 2),
#  ('clinical characteristics of patients with covid-19', 2),
#  ('epidemiologic and clinical characteristic', 2),
#  ('genomic comparison', 2),
#  ('data processing', 2),
#  ('239', 2),
#  ('personal protective equipment', 2),
#  ('communication', 2),
#  ('glove', 2),
#  ('qrt-pcr assay for sars-cov-2', 2),
#  ('298', 2),
#  ('82', 2),
#  ('306', 2),
#  ('299', 2),
#  ('187', 2),
#  ('disclaimer:', 2),
#  ('cell culture and transfection', 2),
#  ('literature review', 2),
#  ('robustnes', 2),
#  ('conclusion and discussion', 2),
#  ('data pre-processing', 2),
#  ('parameter identification', 2),
#  ('what is already known on this topic', 2),
#  ('353', 2),
#  ('data acquisition', 2),
#  ('patient information', 2),
#  ('background:', 2),
#  ('iv. conclusion', 2),
#  ('article information', 2),
#  ('supplemental figure', 2),
#  ('laboratory and radiographic finding', 2),
#  ('104', 2),
#  ('101', 2),
#  ('protein-protein docking', 2),
#  ('materials and methods:', 2),
#  ('viral rna preparation', 2),
#  ('169', 2),
#  ('234', 2),
#  ('97', 2),
#  ('14.', 2),
#  ('figure 4:', 2),
#  ('phylogenetic analyse', 2),
#  ('sources of data', 2),
#  ('247', 2),
#  ('72', 2),
#  ('data collection and processing', 2),
#  ('testing regime changes:', 2),
#  ('295', 2),
#  ('0', 2),
#  ('seir model', 2),
#  ('social mixing and intervention', 2),
#  ('exact solution of sir-equation', 2),
#  ('128', 2),
#  ('exclusion criteria', 2),
#  ('acknowledgment:', 2),
#  ('infection-related biomarker', 2),
#  ('the simplified reservoir-people transmission network model', 2),
#  ('84', 2),
#  ('290', 2),
#  ('276', 2),
#  ('366', 2),
#  ('model prediction', 2),
#  ('radiologic and laboratory finding', 2),
#  ('study characteristic', 2),
#  ('48', 2),
#  ('imputing the date of onset', 2),
#  ('reconstructed incidence of covid-19', 2),
#  ('estimate of reproduction number from daily case incidence', 2),
#  ('effective reproduction number ( ) from daily case incidence', 2),
#  ('data and method', 2),
#  ('264', 2),
#  ('image acquisition', 2),
#  ('/ 18', 2),
#  ('flow cytometry analysi', 2),
#  ('research design', 2),
#  ('124', 2),
#  ('the simulation of daily new infection', 2),
#  ('cure the discharge proces', 2),
#  ('analysis of iranian data', 2),
#  ('simulation of the number of the average infected people', 2),
#  ('death toll', 2),
#  ('simulation of the number of infected people', 2),
#  ('the simulation test of the epidemic control', 2),
#  ('simulation comparison of epidemic model in hubei province', 2),
#  ('analysis of italian data', 2),
#  ('specific analysis of the epidemic situation model', 2),
#  ('analysis of korea data', 2),
#  ('analysi', 2),
#  ('virus isolation', 2),
#  ('data extraction and paper quality evaluation', 2),
#  ('plasmid', 2),
#  ('177', 2),
#  ('342', 2),
#  ('model equation', 2),
#  ('estimation of basic reproduction number (r0)', 2),
#  ('118', 2),
#  ('175', 2),
#  ('214', 2),
#  ('69', 2),
#  ('140', 2),
#  ('cell line', 2),
#  ('internal validation', 2),
#  ('personnel training', 2),
#  ('10)', 2),
#  ('324', 2),
#  ('estimating detection probability relative to singapore', 2),
#  ('respiratory support', 2),
#  ('patient cohort', 2),
#  ('model parameter', 2),
#  ('338', 2),
#  ('138', 2),
#  ('63', 2),
#  ('136', 2),
#  ('231', 2),
#  ('356', 2),
#  ('257', 2),
#  ('205', 2),
#  ('42', 2),
#  ('scenario', 2),
#  ('59', 2),
#  ('cluster c', 2),
#  ('cluster b', 2),
#  ('data sharing:', 2),
#  ('contribution', 2),
#  ('transparency declaration', 2),
#  ('95', 2),
#  ('350', 2),
#  ('quantitative reverse transcription polymerase chain reaction', 2),
#  ('calculation of absolute humidity', 2),
#  ('correlation between covid-19 mortality and meteorological factors and air pollutant',
#   2),
#  ('epidemiological modelling', 2),
#  ('parameter selection and estimate', 2),
#  ('state transition matrix model', 2),
#  ('114', 2),
#  ('240', 2),
#  ('clinical data', 2),
#  ('380', 2),
#  ('patient characteristic', 2),
#  ('influenza testing', 2),
#  ('rt-qpcr', 2),
#  ('endpoint', 2),
#  ('positive control', 2),
#  ('suspected patient', 2),
#  ('text', 2),
#  ('study limitation', 2),
#  ('rna library construction and sequencing', 2),
#  ('availability of data', 2),
#  ('legend', 2),
#  ('results & discussion', 2),
#  ('incidence of aki and in-hospital death', 2),
#  ('41', 2),
#  ('130', 2),
#  ('9 6', 2),
#  ('2 8', 2),
#  ('chest ct scan', 2),
#  ('measure', 2),
#  ("authors' contributions:", 2),
#  ('temporal and spatial distribution and risk analysi', 2),
#  ('sample collection and detection of sars-cov-2', 2),
#  ('the proposed method', 2),
#  ('clinical information', 2),
#  ('figures and legend', 2),
#  ('reduced number of exported case', 2),
#  ('time delay to a major epidemic gained from the reduction in travel volume',
#   2),
#  ('reduced probability of a major epidemic oversea', 2),
#  ('prediction of drug-target interactions using binding affinity score', 2),
#  ('amino acid sequences used in this study', 2),
#  ('expertise for coronavirus and other respiratory pathogen', 2),
#  ('capacity for novel coronavirus molecular diagnostic', 2),
#  ('diagnostic challenge', 2),
#  ('survey', 2),
#  ('instructions and guidelines for mental health services during the covid-19 outbreak',
#   2),
#  ('mental health issues during the covid-19 outbreak', 2),
#  ('clinical services for patients with severe mental illnesses during the covid-19 outbreak',
#   2),
#  ('specific measures in mental health services during the covid-19 outbreak',
#   2),
#  ('the covid-19 outbreak', 2),
#  ('duration of travel 12 hour', 2),
#  ('mental health care', 2),
#  ('supportive care', 2),
#  ('radiography', 2),
#  ('the outbreak', 2),
#  ('pathology', 2),
#  ('discrimination of 2019 novel coronavirus from sars coronavirus by rdrp assay',
#   2),
#  ('protocol options and application note', 2),
#  ('detection range for sars-related coronaviruses from bat', 2),
#  ('clinical samples and coronavirus cell culture supernatants for initial assay evaluation',
#   2),
#  ('cross-reactivity with other coronaviruse', 2),
#  ('exclusivity of 2019 novel coronavirus based on clinical samples pre-tested positive for other respiratory viruse',
#   2),
#  ('sensitivity based on in vitro-transcribed rna identical to 2019 novel coronavirus target sequence',
#   2),
#  ('assay sensitivity based on sars coronavirus virion', 2),
#  ('chemical stability', 2),
#  ('2019-ncov in context: lessons learned?', 2),
#  ('laboratory and diagnostic support', 2),
#  ('clinical and infection control guidance', 2),
#  ('data reporting', 2),
#  ('reporting summary', 2),
#  ('serological test', 2),
#  ('article', 2),
#  ('n/a confirmed', 2),
#  ('trends in daily laboratory-confirmed and suspected covid-19 cases and internet data',
#   2),
#  ('c o r r e s p o n d e n c e o p e n a c c e s ', 2),
#  ('geo-positioning of data', 2),
#  ('usage note', 2),
#  ('data record', 2),
#  ('background & summary', 2),
#  ('technical validation', 2),
#  ('fig. 3. a) and b) model of sars-cov-2 structure provided by swissmodel and visualized with jmol.',
#   2),
#  ('transmission characteristics of the 2019 novel coronaviru', 2),
#  ('comparison with past emergences of respiratory viruse', 2),
#  ('simulating early outbreak trajectorie', 2),
#  ('information on cases after creation of the national health commission task force on 18 january',
#   2),
#  ('early information on 2019-ncov infections as at 12 january', 2),
#  ('early outbreak of viral pneumonia of unknown aetiology as at 9 january', 2),
#  ('risk of fatality among hospitalised case', 2),
#  ('comparison of two hypothetical scenarios: one with large zoonotic spillover and one with small zoonotic spillover',
#   2),
#  ('information on exported cases identified outside mainland china as at 17 january',
#   2),
#  ('case description', 2),
#  ('detected confirmed case', 2),
#  ('negligible risk', 2),
#  ('contact and co-exposition tracing', 2),
#  ('level of risk of infection', 2),
#  ('french surveillance system', 2),
#  ('investigation team', 2),
#  ('low risk', 2),
#  ('contact and co-exposure tracing', 2),
#  ('covid-19 cases in eu/eea countries and the uk', 2),
#  ('obtaining cumulative number and cumulative incidence of covid-19 case', 2),
#  ('trends of covid-19 in eu/eea countries and the uk', 2),
#  ('take full advantage of the infection control system', 2),
#  ('avoid unnecessary contact', 2),
#  ('establish a scientific, reasonable shift schedule', 2),
#  ('provide intense education and training for nurse', 2),
#  ('provide psychological counseling', 2),
#  ('utilization of network platform', 2),
#  ('protection of medical staff', 2),
#  ('current understanding of viral induced exacerbation of chronic airway inflammatory disease',
#   2),
#  ('clinical significance of identifying additional mechanisms of acute exacerbation',
#   2),
#  ('significance of virus infection in exacerbation of chronic airway inflammatory disease',
#   2),
#  ('conclusion and future outlook', 2),
#  ('treatment strategies against 2019-ncov', 2),
#  ('amendments from version 1 introduction', 2),
#  ('proposal for new 2019-ncov therapie', 2),
#  ('ace2 immunoadhesin strategy', 2),
#  ('sequence analysi', 2),
#  ("comparison of 2019 novel coronavirus, severe acute respiratory syndrome and middle east respiratory syndrome coronaviruses' incubation period",
#   2),
#  ('expression of ace2 in human tissues and implications for virus transmission',
#   2),
#  ('unique rbd structure in 2019-ncov', 2),
#  ('distribution of ace2 in the animal kingdom and implications for virus reservoir',
#   2),
#  ('general sequence characteristics of 2019-ncov in comparison with sars-cov',
#   2),
#  ('protection and transfer', 2),
#  ('diagnostic criteria', 2),
#  ('perspectives on the development of neutralizing antibodies against sars-cov-2',
#   2),
#  ('similarity of sars-cov-2 and sars-cov in antigen and receptor recognition by host',
#   2),
#  ('innate and adaptive responses of human to sars-cov-2 and sars-cov', 2),
#  ('advances in the development of neutralizing antibodies to sars-cov', 2),
#  ('looking ahead', 2),
#  ('challenge', 2),
#  ('epidemiology summary', 2),
#  ('public datasets acquisition and analysi', 2),
#  ('cardiovascular disease', 2),
#  ('comparison of one-step rt-pcr system', 2),
#  ('timely implementation of molecular diagnostics for sars-cov-2', 2),
#  ('workflow', 2),
#  ('epidemiological description and data', 2),
#  ('asymptomatic carriers: fact or fiction?', 2),
#  ('concluding remarks and future perspective', 2),
#  ('discovery of hcov', 2),
#  ('lessons from hiv', 2),
#  ('animal hosts of hcov', 2),
#  ('bats as a reservoir of emerging viral pathogens of human', 2),
#  ('clinical presentation and laboratory confirmation of the case', 2),
#  ('sars-cov-2/finland/1/2020 virus isolation', 2),
#  ('analysis of possible reasons for lymphopenia in covid-19 patient', 2),
#  ('establishment of a time-lym% model from discharged covid-19 patient', 2),
#  ('validation of tlm in disease classification in hospitalized covid-19 patient',
#   2),
#  ('lym% indicates disease severity of covid-19 patient', 2),
#  ('limitations of the study', 2),
#  ('basic reproductive number', 2),
#  ('advances and prospects in developing vaccines and therapeutic', 2),
#  ('prevention and control measure', 2),
#  ('the emergence of novel-coronavirus (2019-ncov)', 2),
#  ('estimated importation risk from wuhan before the travel ban in hubei province',
#   2),
#  ('modelling risk of importation', 2),
#  ('estimated importation risk from considered areas of china following the travel ban in hubei province',
#   2),
#  ('tracking online heroisation and blame in epidemic', 2),
#  ('control and mitigation measure', 2),
#  ('disease severity and immunity', 2),
#  ('the possible transmission routes of 2019-ncov', 2),
#  ('characteristics of 2019 novel coronaviru', 2),
#  ('sars-cov-2 utility channel test setup', 2),
#  ('sars-cov-2 utility channel test performance evaluation', 2),
#  ('information diet in crisis condition', 2),
#  ('comment', 2),
#  ('treatment regimen and prognosi', 2),
#  ('laboratory tests and imaging examination', 2),
#  ('mers-cov', 2),
#  ('baseline situation for the scenario', 2),
#  ('potential scenarios for the progression of the covid-19 epidemic', 2),
#  ('estimation of risk of transmission', 2),
#  ('implication of autophagy in covs infection', 2),
#  ('brief introduction of the autophagy and the endocytic pathway', 2),
#  ('involvement of the endocytic pathway in covs infection', 2),
#  ('brief introduction of the new coronaviruse', 2),
#  ('data compilation', 2),
#  ('study design and chinese data source', 2),
#  ('epidemiology of first cases in the european region', 2),
#  ('surveillance in the who european region', 2),
#  ('authoritarianism, outbreaks, and information politic', 2),
#  ('previous epidemics caused by coronaviruse', 2),
#  ('a lesson for the future', 2),
#  ('chest imaging', 2),
#  ('suspected case', 2),
#  ('conventional treatment of sars-cov-2: is there a room for chinese medicine?',
#   2),
#  ('identification of anti-novel coronaviral compound from traditional chinese medicine',
#   2),
#  ('traditional chinese medicine used in the treatment of sars-cov-2-infected patients: the current situation',
#   2),
#  ('traditional chinese medicine in the treatment of patients infected with sars-cov: clinical evidence',
#   2),
#  ('closing remark', 2),
#  ('salvage corticosteroids treatment for critical patients with 2019-ncov?',
#   2),
#  ('precautions of corticosteroids treatment in patients with 2019-ncov', 2),
#  ('current evidence: clinical benefits of corticosteroids therapy for critical ncp patient',
#   2),
#  ('introduction and background', 2),
#  ('prioritize refund', 2),
#  ('move networking online', 2),
#  ('give recognition', 2),
#  ('cover remaining expense', 2),
#  ('go virtual', 2),
#  ('livestream for remote participation', 2),
#  ('pathogenic mechanism', 2),
#  ('concept', 2),
#  ('editorial note', 2),
#  ('demographics, comorbidities and outcome', 2),
#  ('host and reservoir', 2),
#  ('antibiotic therapy', 2),
#  ('ethical statement ::: method', 2),
#  ('data ::: method', 2),
#  ('limitations ::: discussion', 2),
#  ('statistical analysis ::: materials and method', 2),
#  ('5. conclusion', 2),
#  ('6. conclusion', 2),
#  ('study design ::: method', 2),
#  ('sequence analysis ::: materials and method', 2),
#  ('participants ::: method', 2),
#  ('data reporting ::: method', 2),
#  ('19.', 2),
#  ('wie schlimm wird es werden?', 2),
#  ('nimmt die infektiosität im verlauf zu?', 2),
#  ('übertragung von mensch zu mensch', 2),
#  ('was tun bei verdacht?', 2),
#  ('hohe mutationsraten und geringe wirtsspezifität', 2),
#  ('klinische manifestation der erkrankung', 2),
#  ('radiologische befunde', 2),
#  ('demographic data', 2),
#  ('take-home point', 2),
#  ('convalescent plasma therapy', 2),
#  ('monoclonal antibody', 2),
#  ('mesenchymal stem cell', 2),
#  ('■ reference', 2),
#  ('estrategia terapéutica del srni en el covid-19', 2),
#  ('recomendaciones específicas según el tipo de srni', 2),
#  ('resumen', 2),
#  ('elección del tipo de interfase:', 2),
#  ('epidemiology of covid-19', 2),
#  ('other', 2),
#  ('* sı supporting information', 2),
#  ('why africa should be prepared', 2),
#  ('preparednes', 2),
#  ('patient consent for publication', 2),
#  ('in brief', 2),
#  ('active learning (al)', 2),
#  ('multitudinal and multimodal data', 2),
#  ('cross-population train/test ai-driven model', 2),
#  ('animal models for vaccine evaluation', 2),
#  ('passive immunization', 2),
#  ('cell culture system', 2),
#  ('\uf0b7\uf020', 2),
#  ('lesion distribution', 2),
#  ('mouse coronaviruses and ocular implication', 2),
#  ('feline coronaviruses and ocular manifestation', 2),
#  ('human coronaviruses and the evidence for ocular manifestation', 2),
#  ('the coronavirus structure and host', 2),
#  ('antiviral agent', 2),
#  ('corticosteroid', 2),
#  ('develop a strategy for patient volume and complexity', 2),
#  ('develop a robust, transparent, and open communication policy', 2),
#  ('define a strategy to allocate health care resource', 2),
#  ('protect and support health care workers on the front line', 2),
#  ('early lessons from the frontline of the 2019-ncov outbreak', 2),
#  ("dé claration de liens d'inté rêt", 2),
#  ('■ introduction', 2),
#  ('sequence alignment and modeling', 2),
#  ('mechanism', 2),
#  ('lysosomotropic mechanism', 2),
#  ('species differences in metabolism', 2),
#  ('signs and symptom', 2),
#  ('management', 2),
#  ('tratamiento', 2),
#  ('epidemiología', 2),
#  ('compliance and ethic', 2),
#  ('non-invasive ventilation', 2),
#  ('2.3', 2),
#  ('2.4', 2),
#  ('confirmed covid-19 case', 2),
#  ('possible coping strategie', 2),
#  ('related risk factor', 2),
#  ('lessons to learn', 2),
#  ('quarantine', 2),
#  ('electronic supplementary material', 2),
#  ('practice points from an indian perspective', 2),
#  ('\uf0b7', 2),
#  ('nations and local institutions could better integrate human health within sustainable development planning',
#   2),
#  ('synergies, trade-offs, and leverage', 2),
#  ('environmental change, sustainable development', 2),
#  ('medical waste management', 2),
#  ('epidemiological investigation', 2),
#  ('to the editor,', 2),
#  ('to the editor', 2),
#  ('the novel covid-19 viru', 2),
#  ('the genome of the covid-19 viru', 2),
#  ('statement of conflict of interest', 2),
#  ('declaration of conflicting interest', 2),
#  ('treatment and management', 2),
#  ...]

# %% [markdown]
# ### Sections vs Designs

# %%
design_secs = {}
for paper in covid_papers:
    body = paper['data']['body_text']
    relevant = set()
    for paragraph in body:
        text = paragraph['text']
        if(any(design in text.lower() for design in design_list)):
            relevant.add(paragraph['section'])
    for section in relevant:
        section = tokenize(section)
        if section in design_secs:
            design_secs[section] += 1
        else:
            design_secs[section] = 1

# %% [markdown]
# ### Frequency table of sections where at least one of the designs appeared the most times

# %%
sorted(design_secs.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('', 8),
#  ('discussion', 7),
#  ('introduction', 3),
#  ('method', 2),
#  ('eligibility criteria', 2),
#  ('inclusion and exclusion criteria', 2),
#  ('traditional chinese medicine in the treatment of patients infected with sars-cov: clinical evidence',
#   2),
#  ('study design and participant', 2),
#  ('treatment', 2),
#  ('controls. 215', 1),
#  ('literature search', 1),
#  ('quality of included studie', 1),
#  ('statistical analyse', 1),
#  ('(which was not peer-reviewed)', 1),
#  ('background', 1),
#  ('ongoing human trials for covid-19', 1),
#  ('strengths and limitations of this study', 1),
#  ('data sources and data extraction', 1),
#  ('description of studie', 1),
#  ('methods:', 1),
#  ('covid-19 case definitions:', 1),
#  ('therapeutic', 1),
#  ('study identification and selection', 1),
#  ('potential therapeutic', 1),
#  ('previous epidemics caused by coronaviruse', 1),
#  ("guideline's structural setup and refining the topics and coverage of this guideline",
#   1),
#  ('drug treatment 6.3.1 antiviral treatment', 1),
#  ('2.6.1 general notes ::: 2.6 literature searching and preparation of evidence profiles ::: 2 guideline methodology',
#   1),
#  ('6.3.1 antiviral treatment ::: 6.3 drug treatment ::: 6 treatment and control',
#   1),
#  ('the emergence of covid-19 caused by sars-cov-2', 1),
#  ('study selection and data extraction', 1),
#  ('discussion and rationale:', 1),
#  ('information source', 1),
#  ('remdesivir', 1),
#  ('arbidol', 1),
#  ('ademdum', 1),
#  ('methodologic consideration', 1),
#  ('treatment of coronaviruse', 1),
#  ('added value of this study', 1),
#  ('158', 1),
#  ('perspective', 1),
#  ('melatonin effects in cytokine levels in human', 1),
#  ("the largest clinical data[48] from china's centers for disease control and prevention",
#   1),
#  ('oncological impact of deferral', 1),
#  ('omission of rt:', 1),
#  ('chloroquine/hydroxychloroquine', 1),
#  ('corticosteroids and nsaid', 1)]
