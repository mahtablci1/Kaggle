# %% [markdown]
# # Abstract
# The objective of this notebook will be to perform keyword analysis on the papers for Covid-19 risk factors.

# %%
import re
import glob
import json
from os import path
import pandas as np
import pandas as pd
from datetime import datetime

# %%
papers_df = pd.read_csv('../output/papers_df.csv', 
                        index_col=0, 
                        keep_default_na=False,
                       parse_dates=['publish_time'])

# %%
transmission_keywords = ['transmi', 'sneez', 'contact trac', 'reproduc', 'environ']

# %%
smoke_keywords = ['smok']

# %%
covid_keywords = ['COVID-19', 'HCoV-19', 'CORD-19' ,'2019-nCoV', 'Wuhan coronavirus', 'SARS-CoV-2', 'SARS-COV-2']
covid_keywords = [word.lower() for word in covid_keywords]

# %%
# covid_papers = papers_df[papers_df['text_body'].apply(lambda x : 
#                                                 any(key in x.lower() for
#                                                     key in covid_keywords)
#                                                )]

# %%
json_files = glob.glob(f'../data/**/*.json', recursive=True)

# %%
paper_dicts = []
for file in json_files:
    name = path.basename(file)
    with open(file) as f:
        data = json.load(f)
    paper_obj = {'id':name,
                 'data':data}
    paper_dicts.append(paper_obj)

# %%
def tokenize(text):
    text = text.lower().strip()
    if len(text) == 0:
        return ''
    if text[-1] == 's':
        text = text[:-1]
    return text

# %%
sections = {}
for paper in paper_dicts:
    body = paper['data']['body_text']
    paper_sections = set()
    for paragraph in body:
        if 'section' in paragraph:
            paper_sections.add(paragraph['section'])
    for section in paper_sections:
        section = tokenize(section)
        if section in sections:
            sections[section] += 1
        else:
            sections[section] = 1

# %%
sorted(sections.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('introduction', 27243),
#  ('discussion', 23709),
#  ('conclusion', 14315),
#  ('', 11781),
#  ('result', 7043),
#  ('statistical analysi', 4409),
#  ('background', 4070),
#  ('materials and method', 2475),
#  ('method', 2447),
#  ('1. introduction', 1410),
#  ('statistical analysis ::: materials and method', 1268),
#  ('results and discussion', 1252),
#  ('competing interest', 1242),
#  ('author contribution', 1134),
#  ('summary', 1081),
#  ('ethics statement', 1076),
#  ('concluding remark', 860),
#  ('statistical analysis ::: method', 844),
#  ('funding', 818),
#  ("authors' contribution", 792),
#  ('acknowledgment', 682),
#  ('data analysi', 674),
#  ('statistical analyse', 631),
#  ('conflict of interest', 605),
#  ('conflicts of interest', 546),
#  ('4. discussion', 540),
#  ('ethics statement ::: materials and method', 536),
#  ('conflict of interest statement', 532),
#  ('study design', 506),
#  ('statistic', 489),
#  ('animal', 483),
#  ('western blot analysi', 469),
#  ('data collection', 455),
#  ('diagnosi', 451),
#  ('treatment', 448),
#  ('abbreviation', 441),
#  ('supplementary material', 440),
#  ('cells and viruse', 424),
#  ('viruse', 413),
#  ('the study', 403),
#  ('5. conclusion', 400),
#  ('limitation', 395),
#  ('flow cytometry', 392),
#  ('authors’ contribution', 391),
#  ('cell culture', 382),
#  ('study population', 381),
#  ('supporting information', 360),
#  ('epidemiology', 357),
#  ('phylogenetic analysi', 318),
#  ('western blotting', 311),
#  ('discussion and conclusion', 299),
#  ('declaration of competing interest', 295),
#  ('data availability', 291),
#  ('author summary', 290),
#  ('material', 290),
#  ('ethical approval', 281),
#  ('sample collection', 276),
#  ('pre-publication history', 276),
#  ('mice', 275),
#  ('viru', 269),
#  ('elisa', 268),
#  ('objective', 265),
#  ('additional information', 263),
#  ('case report', 259),
#  ('western blot', 251),
#  ('a b s t r a c t', 236),
#  ('patient', 234),
#  ('electron microscopy', 234),
#  ('statistical method', 229),
#  ('additional file', 227),
#  ('experimental design', 225),
#  ('ethics statement ::: method', 222),
#  ('antibodie', 219),
#  ('prevention', 219),
#  ('definition', 217),
#  ('4. conclusion', 217),
#  ('i. introduction', 213),
#  ('data', 210),
#  ('plasmid', 208),
#  ('2.', 207),
#  ('cell', 200),
#  ('data analysis ::: method', 200),
#  ('plasmid construction', 199),
#  ('declaration of interest', 197),
#  ('pathogenesi', 197),
#  ('material and method', 194),
#  ('conflict of interest statement ::: author contribution', 192),
#  ('virus isolation', 191),
#  ('sequence analysi', 191),
#  ('clinical sign', 189),
#  ('data source', 186),
#  ('main', 186),
#  ('immunohistochemistry', 185),
#  ('rna extraction', 183),
#  ('future direction', 182),
#  ('participant', 179),
#  ('supplementary data', 179),
#  ('(which was not peer-reviewed)', 178),
#  ('perspective', 177),
#  ('ethical consideration', 173),
#  ('cells and viru', 173),
#  ('western blot analysis ::: materials and method', 171),
#  ('acknowledgement', 169),
#  ('statistical analyses ::: materials and method', 169),
#  ('clinical feature', 168),
#  ('sample', 164),
#  ('histopathology', 162),
#  ('future perspective', 160),
#  ('influenza', 159),
#  ('immunofluorescence', 158),
#  ('contributor', 157),
#  ('flow cytometry ::: materials and method', 155),
#  ('reagent', 154),
#  ('review', 153),
#  ('outcome', 152),
#  ('serology', 152),
#  ('accession number', 152),
#  ('cytotoxicity assay', 152),
#  ('differential diagnosi', 152),
#  ('experimental procedure', 149),
#  ('data availability statement', 148),
#  ('disclosure', 148),
#  ('conclusions and perspective', 147),
#  ('article in pres', 146),
#  ('conflicts of interest:', 145),
#  ('cell culture ::: materials and method', 145),
#  ('ethic', 144),
#  ('vaccine', 143),
#  ('viruses and cell', 143),
#  ('supplemental material', 142),
#  ('statistical analyses ::: method', 142),
#  ('animals ::: materials and method', 140),
#  ('study design ::: method', 139),
#  ('western blotting ::: materials and method', 138),
#  ('data collection ::: method', 137),
#  ('role of the funding source', 135),
#  ('cells and viruses ::: materials and method', 135),
#  ('subject', 134),
#  ('cell viability assay', 134),
#  ('analysi', 132),
#  ('viral infection', 131),
#  ('procedure', 129),
#  ('statistics ::: materials and method', 129),
#  ('cell line', 127),
#  ('plaque assay', 126),
#  ('etiology', 125),
#  ('vaccination', 125),
#  ('bacteria', 124),
#  ('introducción', 123),
#  ('contents lists available at sciencedirect', 122),
#  ('a b', 121),
#  ('protein expression and purification', 121),
#  ('chemistry', 121),
#  ('virus and cell', 120),
#  ('data analysis ::: materials and method', 120),
#  ('4.', 119),
#  ('virus titration', 119),
#  ('5.', 118),
#  ('compliance with ethical standard', 118),
#  ('clinical presentation', 118),
#  ('prognosi', 118),
#  ('management', 117),
#  ('table 2', 117),
#  ('immunofluorescence assay', 115),
#  ('sensitivity analysi', 115),
#  ('histology', 115),
#  ('nucleotide sequence accession number', 112),
#  ('disclaimer', 111),
#  ('3.', 111),
#  ('patients and method', 111),
#  ('methodology', 110),
#  ('rt-pcr', 110),
#  ('patient characteristic', 107),
#  ('finding', 106),
#  ('clinical manifestation', 106),
#  ('case presentation', 106),
#  ('adenoviru', 106),
#  ('elisa ::: materials and method', 105),
#  ('real-time pcr', 104),
#  ('literature review', 104),
#  ('enzyme-linked immunosorbent assay (elisa)', 104),
#  ('reference', 103),
#  ('tuberculosi', 103),
#  ('1.', 102),
#  ('conclusions and future perspective', 101),
#  ('abstract', 100),
#  ('sampling', 100),
#  ('3. discussion', 100),
#  ('confocal microscopy', 99),
#  ('transmission', 99),
#  ('limitations ::: discussion', 98),
#  ('phylogenetic analysis ::: materials and method', 98),
#  ('pathology', 97),
#  ('bacterial infection', 97),
#  ('fig. 2.', 97),
#  ('setting', 96),
#  ('rotaviru', 95),
#  ('nucleic acid extraction', 95),
#  ('summary and conclusion', 95),
#  ('respiratory syncytial viru', 95),
#  ('6. conclusion', 95),
#  ('sample collection ::: materials and method', 95),
#  ('recommendation', 93),
#  ('viruses ::: materials and method', 93),
#  ('immunoblotting', 92),
#  ('mice ::: materials and method', 92),
#  ('pathophysiology', 91),
#  ('•', 90),
#  ('study population ::: method', 90),
#  ('plasmids ::: materials and method', 90),
#  ('figure 2', 89),
#  ('key point', 89),
#  ('chemical', 89),
#  ('quantitative real-time pcr', 89),
#  ('highlight', 89),
#  ('search strategy', 87),
#  ('search strategy and selection criteria', 87),
#  ('influenza viru', 87),
#  ('statistics ::: method', 87),
#  ('3. result', 87),
#  ('transmission electron microscopy', 86),
#  ('figure 2.', 86),
#  ('virus infection', 86),
#  ('coronaviruse', 86),
#  ('immunofluorescence microscopy', 86),
#  ('model', 85),
#  ('primer', 85),
#  ('statistical analysis ::: material and method', 85),
#  ('conclusions and future direction', 84),
#  ('availability of data and material', 84),
#  ('coronaviru', 84),
#  ('sample preparation', 83),
#  ('neutralization assay', 83),
#  ('infectious disease', 83),
#  ('malaria', 82),
#  ('clinical sample', 81),
#  ('ethical statement', 79),
#  ('table 1', 79),
#  ('real-time rt-pcr', 78),
#  ('antibodies ::: materials and method', 78),
#  ('consent for publication', 77),
#  ('luciferase assay', 77),
#  ('cells ::: materials and method', 77),
#  ('phylogenetic analyse', 76),
#  ('study design and participant', 76),
#  ('disclosure of potential conflicts of interest', 76),
#  ('case description', 76),
#  ('microbiology', 76),
#  ('compound', 75),
#  ('cell culture and transfection', 75),
#  ('risk factor', 75),
#  ('participants ::: method', 75),
#  ('intervention', 74),
#  ('sequencing', 74),
#  ('note', 74),
#  ('measure', 74),
#  ('supplemental information', 74),
#  ('clinical specimen', 74),
#  ('experimental animal', 74),
#  ('western blot ::: materials and method', 74),
#  ('flow cytometry analysi', 73),
#  ('immunization', 73),
#  ('expert commentary', 73),
#  ('five-year view', 73),
#  ('materials ::: materials and method', 73),
#  ('antiviral activity', 72),
#  ('animals ::: method', 72),
#  ('added value of this study', 71),
#  ('infection', 71),
#  ('history', 70),
#  ('statistical analysis. ::: materials and method', 70),
#  ('funding source', 69),
#  ('conclusion and perspective', 69),
#  ('open acces', 69),
#  ('laboratory diagnosi', 69),
#  ('keyword', 68),
#  ('other viruse', 68),
#  ('parasite', 68),
#  ('therapy', 68),
#  ('statistical methods ::: method', 68),
#  ('electron microscopy ::: materials and method', 68),
#  ('study design ::: materials and method', 68),
#  ('conflicto de interese', 68),
#  ('animal experiment', 67),
#  ('challenge', 67),
#  ('design', 67),
#  ('virology', 67),
#  ('general', 67),
#  ('key issue', 67),
#  ('ethics approval and consent to participate', 66),
#  ('case definition', 66),
#  ('control', 66),
#  ('figure 1.', 66),
#  ('11', 65),
#  ('laboratory method', 65),
#  ('table 3', 65),
#  ('ethics ::: method', 65),
#  ('5', 64),
#  ('implications of all the available evidence', 64),
#  ('list of abbreviation', 63),
#  ('study limitation', 63),
#  ('research in context', 62),
#  ('clinical finding', 62),
#  ('statistical analysis.', 62),
#  ('strengths and limitation', 62),
#  ('west nile viru', 62),
#  ('diagnostic', 62),
#  ('human immunodeficiency viru', 62),
#  ('western blot analysis ::: method', 62),
#  ('results:', 61),
#  ('figure 3', 61),
#  ('primer design', 61),
#  ('data availability ::: method', 61),
#  ('neoplasia', 61),
#  ('conclusion:', 60),
#  ('in brief', 60),
#  ('study participant', 60),
#  ('histopathology and immunohistochemistry', 60),
#  ('overview', 59),
#  ('demographic', 59),
#  ('study area', 59),
#  ('construction of plasmid', 59),
#  ('flow cytometric analysi', 59),
#  ('immunofluorescence assay (ifa)', 59),
#  ('antibiotic', 59),
#  ('physical examination', 59),
#  ('conflict of interest ::: author contribution', 59),
#  ('sar', 58),
#  ('animal model', 58),
#  ('virus detection', 58),
#  ('enzyme-linked immunosorbent assay', 58),
#  ('specimen', 58),
#  ('phylogenetic analysis ::: result', 58),
#  ('rna extraction ::: materials and method', 58),
#  ('7.', 57),
#  ('specimen collection', 57),
#  ('star+method', 57),
#  ('key message', 57),
#  ('interferon', 57),
#  ('fungi', 57),
#  ('analysis ::: method', 57),
#  ('immunofluorescence ::: materials and method', 57),
#  ('flow cytometry ::: method', 57),
#  ('disclosure statement', 56),
#  ('dna extraction', 56),
#  ('outlook', 56),
#  ('western blotting analysi', 56),
#  ('sequence analysis ::: materials and method', 56),
#  ('patient characteristics ::: result', 56),
#  ('the model', 55),
#  ('clinical characteristic', 55),
#  ('laboratory testing', 55),
#  ('indirect immunofluorescence assay', 55),
#  ('antiviral assay', 55),
#  ('prevention and control', 55),
#  ('data ::: method', 55),
#  ('western blotting ::: method', 55),
#  ('study population ::: materials and method', 55),
#  ('quantification and statistical analysi', 54),
#  ('implementation', 54),
#  ('mass spectrometry', 54),
#  ('complication', 54),
#  ('experimental', 54),
#  ('antibodies and reagent', 54),
#  ('influenza viruse', 54),
#  ('6.', 54),
#  ('cytomegaloviru', 54),
#  ('7. conclusion', 54),
#  ('reagents ::: materials and method', 54),
#  ('3', 53),
#  ('peptide synthesi', 53),
#  ('other', 53),
#  ('questionnaire', 53),
#  ('editorial', 53),
#  ('transfection', 53),
#  ('cells and viruses ::: method', 53),
#  ('4', 52),
#  ('data extraction', 52),
#  ('sample collection ::: method', 52),
#  ('microscopy', 51),
#  ('ethics approval', 51),
#  ('measle', 51),
#  ('rabie', 51),
#  ('recombination analysi', 51),
#  ('plant material', 51),
#  ('rna interference', 51),
#  ('10', 50),
#  ('methods:', 50),
#  ('quantitative rt-pcr', 50),
#  ('immunoprecipitation', 50),
#  ('study subject', 50),
#  ('herpes simplex viru', 50),
#  ('severe acute respiratory syndrome', 50),
#  ('study population ::: result', 50),
#  ('conclusions ::: discussion', 50),
#  ('plasmid construction ::: materials and method', 50),
#  ('tratamiento', 50),
#  ('indirect immunofluorescence assay (ifa)', 49),
#  ('human metapneumoviru', 49),
#  ('escherichia coli', 49),
#  ('mtt assay', 49),
#  ('northern blot analysi', 49),
#  ('rhinoviru', 49),
#  ('confl icts of interest', 49),
#  ('availability and requirement', 48),
#  ('case 2', 48),
#  ('transparency declaration', 48),
#  ('dna sequencing', 48),
#  ('virus strain', 48),
#  ('clinical observation', 48),
#  ('cells and virus ::: materials and method', 48),
#  ('gene', 47),
#  ('consent', 47),
#  ('sample size', 47),
#  ('future prospect', 47),
#  ('elispot assay', 47),
#  ('ribavirin', 47),
#  ('adenoviruse', 47),
#  ('viral disease', 47),
#  ('cell viability assay ::: materials and method', 47),
#  ('experimental design ::: materials and method', 47),
#  ('9', 46),
#  ('conclusions:', 46),
#  ('quantitative pcr', 46),
#  ('immunofluorescence staining', 46),
#  ('outcome measure', 46),
#  ('study site', 46),
#  ('microarray analysi', 46),
#  ('safety', 46),
#  ('pcr', 46),
#  ('bioinformatics analysi', 46),
#  ('conclusions and outlook', 46),
#  ('pneumonia', 46),
#  ('immunohistochemistry ::: materials and method', 46),
#  ('ethical considerations ::: method', 46),
#  ('ethical approval ::: materials and method', 46),
#  ('table 4', 46),
#  ('data sharing', 45),
#  ('study selection', 45),
#  ('fluorescence microscopy', 45),
#  ('transmission electron microscopy (tem)', 45),
#  ('measurement', 45),
#  ('instrument', 45),
#  ('cancer', 45),
#  ('fungal infection', 45),
#  ('classification', 45),
#  ('protozoa', 45),
#  ('viruses and cells ::: materials and method', 45),
#  ('mice ::: method', 45),
#  ('inclusion and exclusion criteria', 44),
#  ('case', 44),
#  ('figure 4', 44),
#  ('implication', 44),
#  ('dear editor,', 44),
#  ('noroviru', 44),
#  ('confocal microscopy ::: materials and method', 44),
#  ('figure 1', 43),
#  ('laboratory finding', 43),
#  ('supplementary information', 43),
#  ('molecular docking', 43),
#  ('inclusion criteria', 43),
#  ('luciferase reporter assay', 43),
#  ('plasmid construct', 43),
#  ('miscellaneou', 43),
#  ('clostridium difficile', 43),
#  ('polymerase chain reaction', 43),
#  ('patients ::: method', 43),
#  ('6', 42),
#  ('7', 42),
#  ('site-directed mutagenesi', 42),
#  ('elisa assay', 42),
#  ('bioinformatic', 42),
#  ('additional material', 42),
#  ('dna vaccine', 42),
#  ('conclusion and future direction', 42),
#  ('immunofluorescence analysi', 42),
#  ('indirect immunofluorescence', 42),
#  ('data collection and analysi', 42),
#  ('surveillance', 42),
#  ('corticosteroid', 42),
#  ('staphylococcus aureu', 42),
#  ('19', 41),
#  ('interpretation', 41),
#  ('simulation', 41),
#  ('reagents and antibodie', 41),
#  ('infection control', 41),
#  ('immunoblot analysi', 41),
#  ('glossary', 41),
#  ('conclusion and future perspective', 41),
#  ('plaque reduction assay', 41),
#  ('hepatitis b', 41),
#  ('ethical approval ::: method', 41),
#  ('image analysi', 40),
#  ('patients and sample', 40),
#  ('herpesviruse', 40),
#  ('monoclonal antibodie', 40),
#  ('outstanding question', 40),
#  ('data sources ::: method', 40),
#  ('patients ::: materials and method', 40),
#  ('data collection ::: materials and method', 40),
#  ('protein expression and purification ::: materials and method', 40),
#  ('conclusione', 40),
#  ('15', 39),
#  ('introduction:', 39),
#  ('exclusion criteria', 39),
#  ('crystallization', 39),
#  ('specificity', 39),
#  ('| statistical analysi', 39),
#  ('virus neutralization assay', 39),
#  ('rna extraction and cdna synthesi', 39),
#  ('necropsy', 39),
#  ('declarations of interest', 39),
#  ('application', 39),
#  ('cell lines ::: materials and method', 39),
#  ('real-time pcr ::: materials and method', 39),
#  ('conclusion ::: discussion', 39),
#  ('general consideration', 39),
#  ('further reading', 39),
#  ('1', 38),
#  ('communication', 38),
#  ('serum sample', 38),
#  ('experimental infection', 38),
#  ('rna isolation', 38),
#  ('respiratory viruse', 38),
#  ('comment', 38),
#  ('protein', 38),
#  ('cell culture ::: method', 38),
#  ('accession numbers ::: materials and method', 38),
#  ('immunoblotting ::: materials and method', 38),
#  ('virus ::: materials and method', 38),
#  ('feline infectious peritoniti', 38),
#  ('diagnóstico', 38),
#  ('fig. 5.', 38),
#  ('references and recommended reading', 38),
#  ('variable', 37),
#  ('cell viability', 37),
#  ('immunocytochemistry', 37),
#  ('viruses and cell line', 37),
#  ('group', 37),
#  ('asthma', 37),
#  ('animal studie', 37),
#  ('multilingual abstract', 37),
#  ('clinical evaluation', 37),
#  ('sds-page and western blot analysi', 37),
#  ('historical perspective', 37),
#  ('anthrax', 37),
#  ('clinical pathology', 37),
#  ('phylogenetic analysis ::: method', 37),
#  ('virus isolation ::: materials and method', 37),
#  ('8. conclusion', 37),
#  ('virus titration ::: materials and method', 37),
#  ('traitement', 37),
#  ('expert opinion', 37),
#  ('parameter', 36),
#  ('clinical outcome', 36),
#  ('funding information', 36),
#  ('virus preparation', 36),
#  ('case 1', 36),
#  ('symptom', 36),
#  ('hiv', 36),
#  ('bacterial strain', 36),
#  ('sequence and phylogenetic analysi', 36),
#  ('data analyse', 36),
#  ('western blot assay', 36),
#  ('histopathology ::: materials and method', 36),
#  ('immunofluorescence assay ::: materials and method', 36),
#  ('d i s c u s s i o n', 36),
#  ('mycobacterium tuberculosi', 36),
#  ('8', 35),
#  ('mathematical model', 35),
#  ('supplementary materials:', 35),
#  ('age', 35),
#  ('culture', 35),
#  ('demographic characteristic', 35),
#  ('clinical data', 35),
#  ('conclusions and future prospect', 35),
#  ('microarray', 35),
#  ('pathogen', 35),
#  ('| introduction', 35),
#  ('immunity', 35),
#  ('salmonellosi', 35),
#  ('severe acute respiratory syndrome (sars)', 35),
#  ('elisa ::: method', 35),
#  ('viruses ::: method', 35),
#  ('nucleic acid extraction ::: materials and method', 35),
#  ('quantitative real-time pcr ::: materials and method', 35),
#  ('13', 34),
#  ('dataset', 34),
#  ('molecular dynamics simulation', 34),
#  ('qrt-pcr', 34),
#  ('drug', 34),
#  ('co-immunoprecipitation', 34),
#  ('availability of supporting data', 34),
#  ('sds-page and western blot', 34),
#  ('j o u r n a l p r e -p r o o f', 34),
#  ('cytokine', 34),
#  ('ebola viru', 34),
#  ('statistical analysis ::: patients and method', 34),
#  ('plaque assay ::: materials and method', 34),
#  ('nucleotide sequence accession numbers ::: materials and method', 34),
#  ('related work', 33),
#  ('protein purification', 33),
#  ('patient and public involvement', 33),
#  ('| d iscuss i on', 33),
#  ('peptide', 33),
#  ('concluding remarks and future perspective', 33),
#  ('histopathological analysi', 33),
#  ('leptospirosi', 33),
#  ('sample collection and processing', 33),
#  ('structure', 33),
#  ('epstein-barr viru', 33),
#  ('cat', 33),
#  ('molecular analysi', 33),
#  ('replication', 33),
#  ('mers-cov', 33),
#  ('investigation', 33),
#  ('■ introduction', 33),
#  ('discusión', 33),
#  ('treatment and prevention', 33),
#  ('bioinformatic analysi', 32),
#  ('laboratory procedure', 32),
#  ('synthesi', 32),
#  ('mortality', 32),
#  ('strengths and limitations of this study', 32),
#  ('8.', 32),
#  ('study procedure', 32),
#  ('availability', 32),
#  ('study setting', 32),
#  ('dengue', 32),
#  ('data and software availability', 32),
#  ('cause', 32),
#  ('antiviral', 32),
#  ('mechanism of action', 32),
#  ('trauma', 32),
#  ('hepatitis c', 32),
#  ('cytotoxicity assay ::: materials and method', 32),
#  ('setting ::: method', 32),
#  ('search strategy ::: method', 32),
#  ('sensitivity analysis ::: result', 32),
#  ('immunofluorescence microscopy ::: materials and method', 32),
#  ('data availability ::: materials and method', 32),
#  ('epidemiología', 32),
#  ('compliance with ethics guideline', 32),
#  ('viral pneumonia', 32),
#  ('name', 31),
#  ('chemicals and reagent', 31),
#  ('| discussion', 31),
#  ('reverse transcription', 31),
#  ('antibody detection', 31),
#  ('limitations of the study', 31),
#  ('rsv', 31),
#  ('conclusions and discussion', 31),
#  ('inflammation', 31),
#  ('in situ hybridization', 31),
#  ('study design and setting', 31),
#  ('nmr spectroscopy', 31),
#  ('dna viruse', 31),
#  ('transparency document', 31),
#  ('toxoplasmosi', 31),
#  ('immunohistochemistry ::: method', 31),
#  ('rt-pcr ::: materials and method', 31),
#  ('2. materials and method', 31),
#  ('5. discussion', 31),
#  ('discussion:', 30),
#  ('hand hygiene', 30),
#  ('subcellular fractionation', 30),
#  ('sample processing', 30),
#  ('cell lines and viruse', 30),
#  ('| introduc ti on', 30),
#  ('sequencing and phylogenetic analysi', 30),
#  ('experimental section', 30),
#  ('imaging', 30),
#  ('genbank accession number', 30),
#  ('analytical ultracentrifugation', 30),
#  ('salmonella', 30),
#  ('immunization of mice', 30),
#  ('emerging infectious disease', 30),
#  ('conclusions and recommendation', 30),
#  ('bacterial disease', 30),
#  ('subjects ::: method', 30),
#  ('western blotting analysis ::: materials and method', 30),
#  ('nucleic acid extraction ::: method', 30),
#  ('disclosure of interest', 30),
#  ('strengths and limitations ::: discussion', 30),
#  ('reporting summary ::: method', 30),
#  ('18', 29),
#  ('21', 29),
#  ('analyse', 29),
#  ('laboratory test', 29),
#  ('literature search', 29),
#  ('sars-cov', 29),
#  ('funding statement', 29),
#  ('follow-up', 29),
#  ('methods and material', 29),
#  ('histological analysi', 29),
#  ('serological assay', 29),
#  ('clinical symptom', 29),
#  ('ferret', 29),
#  ('ethical issue', 29),
#  ('cell proliferation assay', 29),
#  ('primer and probe design', 29),
#  ('sds-page and western blotting', 29),
#  ('aim', 29),
#  ('virus identification', 29),
#  ('viral rna extraction', 29),
#  ('bacteriology', 29),
#  ('genetic', 29),
#  ('retroviruse', 29),
#  ('10.', 29),
#  ('9.', 29),
#  ('financial support', 29),
#  ('statistical methods ::: materials and method', 29),
#  ('plasmids ::: method', 29),
#  ('cell culture and transfection ::: materials and method', 29),
#  ('chemicals ::: materials and method', 29),
#  ('i n t r o d u c t i o n', 29),
#  ('16', 28),
#  ('12', 28),
#  ('22', 28),
#  ('study design and patient', 28),
#  ('incubation period', 28),
#  ('population', 28),
#  ('personal protective equipment', 28),
#  ('sequence data', 28),
#  ('coronaviridae', 28),
#  ('hematology', 28),
#  ('statistical', 28),
#  ('quantitative real-time rt-pcr', 28),
#  ('clinical assessment', 28),
#  ('rna viruse', 28),
#  ('protease inhibitor', 28),
#  ('immune response', 28),
#  ('histology and immunohistochemistry', 28),
#  ('patients and specimen', 28),
#  ('yellow fever', 28),
#  ('rabies viru', 28),
#  ('avian influenza', 28),
#  ('hepatitis c viru', 28),
#  ('in vitro transcription and translation', 28),
#  ('cells and viruses. ::: materials and method', 28),
#  ('samples ::: materials and method', 28),
#  ('1. background', 28),
#  ('laboratory methods ::: method', 28),
#  ('virus infection ::: materials and method', 28),
#  ('indirect immunofluorescence assay ::: materials and method', 28),
#  ('ethical statement ::: materials and method', 28),
#  ('flow cytometry analysis ::: materials and method', 28),
#  ('■ conclusion', 28),
#  ('manifestaciones clínica', 28),
#  ('main text', 27),
#  ('executive summary', 27),
#  ('rt-qpcr', 27),
#  ('3.2.', 27),
#  ('hemagglutination assay', 27),
#  ('flaviviruse', 27),
#  ('virus and cell culture', 27),
#  ('adjuvant', 27),
#  ('study design and population', 27),
#  ('dengue viru', 27),
#  ('immunohistochemistry (ihc)', 27),
#  ('animals and experimental design', 27),
#  ('hantaviru', 27),
#  ('intracellular cytokine staining', 27),
#  ('virus purification', 27),
#  ('lessons learned', 27),
#  ('incidence', 27),
#  ('enteroviruse', 27),
#  ('definitions ::: method', 27),
#  ('histology ::: materials and method', 27),
#  ('transfection ::: materials and method', 27),
#  ('enzyme-linked immunosorbent assay (elisa) ::: materials and method', 27),
#  ('luciferase assay ::: materials and method', 27),
#  ('etiología', 27),
#  ('parasitic infection', 27),
#  ('resultado', 27),
#  ('numerical simulation', 26),
#  ('model validation', 26),
#  ('eligibility criteria', 26),
#  ('adverse event', 26),
#  ('strain', 26),
#  ('experimental protocol', 26),
#  ('cost', 26),
#  ('antiviral activity assay', 26),
#  ('cytotoxicity', 26),
#  ('structure determination', 26),
#  ('sensitivity', 26),
#  ('cell and viru', 26),
#  ('research', 26),
#  ('genotyping', 26),
#  ('time-of-addition assay', 26),
#  ('hemagglutination inhibition assay', 26),
#  ('the way forward', 26),
#  ('smallpox', 26),
#  ('dog', 26),
#  ('diet', 26),
#  ('housing', 26),
#  ('environmental factor', 26),
#  ('electrophoretic mobility shift assay', 26),
#  ('polymerase chain reaction (pcr)', 26),
#  ('summary and perspective', 26),
#  ('clinical examination', 26),
#  ('cells ::: method', 26),
#  ('western blot ::: method', 26),
#  ('transmission electron microscopy ::: materials and method', 26),
#  ('microarray analysis ::: materials and method', 26),
#  ('virus and cells ::: materials and method', 26),
#  ('3. results and discussion', 26),
#  ('nucleotide sequence accession number. ::: genome announcement', 26),
#  ('nutrition', 26),
#  ('brucellosi', 26),
#  ('parasitic disease', 26),
#  ('surgery', 26),
#  ('indication', 26),
#  ('17', 25),
#  ('model description', 25),
#  ('2', 25),
#  ('parameter estimation', 25),
#  ('in vitro transcription', 25),
#  ('specie', 25),
#  ('immunostaining', 25),
#  ('sequence alignment', 25),
#  ('patient population', 25),
#  ('paramyxoviridae', 25),
#  ('humoral immune response', 25),
#  ('methods and finding', 25),
#  ('descriptive statistic', 25),
#  ('neutrophil', 25),
#  ('herpesviridae', 25),
#  ('concluding remarks and future direction', 25),
#  ('antimicrobial resistance', 25),
#  ('seasonality', 25),
#  ('pig', 25),
#  ('histopathological examination', 25),
#  ('neutralization test', 25),
#  ('method detail', 25),
#  ('diagnostic testing', 25),
#  ('liposome', 25),
#  ('materials and reagent', 25),
#  ('streptococcus pneumoniae', 25),
#  ('samples ::: method', 25),
#  ('measures ::: method', 25),
#  ('animal experiments ::: materials and method', 25),
#  ('quantitative rt-pcr ::: materials and method', 25),
#  ('study area ::: materials and method', 25),
#  ('flow cytometric analysis ::: materials and method', 25),
#  ('immunoprecipitation ::: materials and method', 25),
#  ('ethics statement. ::: materials and method', 25),
#  ('hepatitis b viru', 25),
#  ('respiratory system', 25),
#  ('bacterial pneumonia', 25),
#  ('data and code availability', 24),
#  ('simulation result', 24),
#  ('quality assessment', 24),
#  ('primer name', 24),
#  ('13.', 24),
#  ('zika viru', 24),
#  ('conclusion and discussion', 24),
#  ('conclusions and implication', 24),
#  ('study sample', 24),
#  ('study characteristic', 24),
#  ('risk assessment', 24),
#  ('contact for reagent and resource sharing', 24),
#  ('monitoring', 24),
#  ('genome organization', 24),
#  ('environment', 24),
#  ('probiotic', 24),
#  ('autophagy', 24),
#  ('subunit vaccine', 24),
#  ('dendritic cell', 24),
#  ('participant characteristic', 24),
#  ('database', 24),
#  ('study protocol', 24),
#  ('cells and reagent', 24),
#  ('antibody response', 24),
#  ('co-infection', 24),
#  ('clinical trial', 24),
#  ('helicobacter pylori', 24),
#  ('human', 24),
#  ('viruses and cell culture', 24),
#  ('astroviru', 24),
#  ('conclusion and outlook', 24),
#  ('resumen', 24),
#  ('education', 24),
#  ('antigen', 24),
#  ('cystic fibrosi', 24),
#  ('fluid therapy', 24),
#  ('prevalence', 24),
#  ('radiology', 24),
#  ('preparation', 24),
#  ('listeria monocytogene', 24),
#  ('résumé', 24),
#  ('viruses and cells ::: method', 24),
#  ('subjects ::: materials and method', 24),
#  ('ethics ::: materials and method', 24),
#  ('real-time rt-pcr ::: materials and method', 24),
#  ('2.9. statistical analysis ::: 2. materials and method', 24),
#  ('conflict of interest declaration', 24),
#  ('diagnostic imaging', 24),
#  ('author manuscript', 24),
#  ('27', 23),
#  ('data and method', 23),
#  ('treatment and prognosi', 23),
#  ('patient selection', 23),
#  ('data collection and processing', 23),
#  ('baseline characteristic', 23),
#  ('contribution', 23),
#  ('model formulation', 23),
#  ('rna extraction and rt-pcr', 23),
#  ('circular dichroism spectroscopy', 23),
#  ('flaviviridae', 23),
#  ('respiratory syncytial virus (rsv)', 23),
#  ('introduction and background', 23),
#  ('ack n owled g em ent', 23),
#  ('data management and analysi', 23),
#  ('indirect elisa', 23),
#  ('macrophage', 23),
#  ('radiography', 23),
#  ('rna preparation', 23),
#  ('viral load', 23),
#  ('cell culture and virus infection', 23),
#  ('genome sequencing', 23),
#  ('gene expression analysi', 23),
#  ('respiratory disease', 23),
#  ('future research', 23),
#  ('clinical disease', 23),
#  ('the future', 23),
#  ('real-time quantitative pcr', 23),
#  ('diagnosis and treatment', 23),
#  ('toll-like receptor', 23),
#  ('respiratory infection', 23),
#  ('microneutralization assay', 23),
#  ('laboratory investigation', 23),
#  ('cardiovascular system', 23),
#  ('anti-inflammatory activity', 23),
#  ('rat', 23),
#  ('circular dichroism', 23),
#  ('rhinoviruse', 23),
#  ('parainfluenza viru', 23),
#  ('sequence analysis ::: method', 23),
#  ('quantitative pcr ::: materials and method', 23),
#  ('virus ::: method', 23),
#  ('3. conclusion', 23),
#  ('experimental design ::: method', 23),
#  ('conclusión', 23),
#  ('acute bronchiti', 23),
#  ('diagnostic evaluation', 23),
#  ("déclaration d'intérêt", 23),
#  ('measles viru', 23),
#  ('mycoplasma pneumoniae', 23),
#  ('fungal disease', 23),
#  ('cell cycle analysi', 22),
#  ('clinical implication', 22),
#  ('v. conclusion', 22),
#  ('sample size calculation', 22),
#  ('pharmacokinetic', 22),
#  ('observation', 22),
#  ('immunofluorescence and confocal microscopy', 22),
#  ('picornaviridae', 22),
#  ('apoptosi', 22),
#  ('evaluation', 22),
#  ('sampling procedure', 22),
#  ('indirect immunofluorescence microscopy', 22),
#  ('real-time quantitative rt-pcr', 22),
#  ('laboratory analysi', 22),
#  ('morphology', 22),
#  ('cells, viruses, and reagent', 22),
#  ('sequence', 22),
#  ('serological test', 22),
#  ('primers and probe', 22),
#  ('viral culture', 22),
#  ('final remark', 22),
#  ('declaration of conflicting interest', 22),
#  ('viral', 22),
#  ('immunology', 22),
#  ('crystallization and data collection', 22),
#  ('antibacterial activity', 22),
#  ('viruses and infection', 22),
#  ('supplemental data', 22),
#  ('plague', 22),
#  ('toxicity', 22),
#  ('case study', 22),
#  ('financial & competing interests disclosure', 22),
#  ('therapie', 22),
#  ('vaccine development', 22),
#  ('12.', 22),
#  ('hepatitis viruse', 22),
#  ('commentary', 22),
#  ('sepsi', 22),
#  ('cholera', 22),
#  ('cryptosporidiosi', 22),
#  ('laboratory testing ::: method', 22),
#  ('design ::: method', 22),
#  ('rna extraction ::: method', 22),
#  ('study limitations ::: discussion', 22),
#  ('sampling ::: method', 22),
#  ('fluorescence microscopy ::: materials and method', 22),
#  ('sampling ::: materials and method', 22),
#  ('clinical characteristics ::: result', 22),
#  ('antibodies and reagents ::: materials and method', 22),
#  ('rna interference ::: materials and method', 22),
#  ...]

# %%
# Out:
# 52097

# %%
class Paper:
    def __init__(self, )
